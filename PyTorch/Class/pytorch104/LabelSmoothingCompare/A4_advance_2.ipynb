# %% [markdown]
# # MIS 583 Assignment 4: Self-supervised and transfer learning on CIFAR10

# %% [markdown]
# Before we start, please put your name and SID in following format: <br>
# : LASTNAME Firstname, ?00000000   //   e.g.) 李晨愷 M114020035

# %% [markdown]
# **Your Answer:**
# Hi I'm 鄔仁迪, B104020009.

# %%
import pandas as pd

experience_name = 'label_smoothing_2'
label_smoothing = 0.2

# Define columns for the DataFrame
columns = ['Experiment Type', 'Epoch', 'Train Accuracy', 'Train Loss', 'Valid Accuracy', 'Valid Loss']

# Initialize an empty DataFrame with these columns
experience_report = pd.DataFrame(columns=columns)

experience_report
# Out:
# Empty DataFrame
# Columns: [Experiment Type, Epoch, Train Accuracy, Train Loss, Valid Accuracy, Valid Loss]
# Index: []

# %%
import torch
import numpy as np
import random

# Function to set the seed
def set_seed(seed_value=42):
    """Set seed for reproducibility."""
    torch.manual_seed(seed_value)
    torch.cuda.manual_seed(seed_value)
    torch.cuda.manual_seed_all(seed_value)  # if you are using multi-GPU.
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed_value)
    random.seed(seed_value)

set_seed()

# %% [markdown]
# ## Google Colab Setup
# Next we need to run a few commands to set up our environment on Google Colab. If you are running this notebook on a local machine you can skip this section.
#
# Run the following cell to mount your Google Drive. Follow the link, sign in to your Google account (the same account you used to store this notebook!) and copy the authorization code into the text box that appears below.

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# fill in the path in your Google Drive in the string below. Note: do not escape slashes or spaces
# import os
# datadir = "C:/Users/eddie/GitHub/Deep-Learning/PyTorch/Class/pytorch104"
# if not os.path.exists(datadir):
#  !ln -s "/content/drive/My Drive/Your/A4/path/" $datadir # TODO: Fill your A3 path
# os.chdir(datadir)
# !pwd

# %% [markdown]
# # Data Setup (5 points)
#
# The first thing to do is implement a dataset class to load rotated CIFAR10 images with matching labels. Since there is already a CIFAR10 dataset class implemented in `torchvision`, we will extend this class and modify the `__get_item__` method appropriately to load rotated images.
#
# Each rotation label should be an integer in the set {0, 1, 2, 3} which correspond to rotations of 0, 90, 180, or 270 degrees respectively.

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import random


def rotate_img(img, rot):
    if rot == 0: # 0 degrees rotation
        return img
    #######################################################################
    #        TODO: Implement rotate_img() - return the rotated img        #                           
    #######################################################################
    angles = {0: 0, 1: 90, 2: 180, 3: 270}
    if rot in angles:
        return transforms.functional.rotate(img, angles[rot])
    else:
        raise ValueError('rotation should be 0, 90, 180, or 270 degrees')

    #######################################################################
    #                           End of your code                          #
    #######################################################################

class CIFAR10Rotation(torchvision.datasets.CIFAR10):

    def __init__(self, root, train, download, transform) -> None:
        super().__init__(root=root, train=train, download=download, transform=transform)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index: int):
        image, cls_label = super().__getitem__(index)

        # randomly select image rotation
        rotation_label = random.choice([0, 1, 2, 3])
        image_rotated = rotate_img(image, rotation_label)

        rotation_label = torch.tensor(rotation_label).long()
        return image, image_rotated, rotation_label, torch.tensor(cls_label).long()

# %%
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

batch_size = 128

trainset = CIFAR10Rotation(root='../data', train=True,
                                        download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=0)

testset = CIFAR10Rotation(root='../data', train=False,
                                       download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=0)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# Show some example images and rotated images with labels:

# %%
import matplotlib.pyplot as plt

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

rot_classes = ('0', '90', '180', '270')


def imshow(img):
    # unnormalize
    img = transforms.Normalize((0, 0, 0), (1/0.2023, 1/0.1994, 1/0.2010))(img)
    img = transforms.Normalize((-0.4914, -0.4822, -0.4465), (1, 1, 1))(img)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


dataiter = iter(trainloader)
images, rot_images, rot_labels, labels = next(dataiter)

# print images and rotated images
img_grid = imshow(torchvision.utils.make_grid(images[:4], padding=0))
print('Class labels: ', ' '.join(f'{classes[labels[j]]:5s}' for j in range(4)))
img_grid = imshow(torchvision.utils.make_grid(rot_images[:4], padding=0))
print('Rotation labels: ', ' '.join(f'{rot_classes[rot_labels[j]]:5s}' for j in range(4)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Class labels:  frog  plane deer  car
# Rotation labels:  0     0     180   90

# %% [markdown]
# # Evaluation code

# %%
import time

def run_test(net, testloader, criterion, task):
    correct = 0
    total = 0
    avg_test_loss = 0.0
    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for images, images_rotated, labels, cls_labels in testloader:
            if task == 'rotation':
              images, labels = images_rotated.to(device), labels.to(device)
            elif task == 'classification':
              images, labels = images.to(device), cls_labels.to(device)
            #######################################################################
            # TODO: Calculate outputs by running images through the network       #
            # The class with the highest energy is what we choose as prediction   #
            #######################################################################
            # Calculate outputs by running images through the network
            outputs = net(images)

            # The class with the highest score is what we choose as our prediction
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            #######################################################################
            #                           End of your code                          #
            #######################################################################
            avg_test_loss += criterion(outputs, labels)  / len(testloader)
    print('TESTING:')
    print(f'Accuracy of the network on the 10000 test images: {100 * correct / total:.2f} %')
    print(f'Average loss on the 10000 test images: {avg_test_loss:.3f}')

    return avg_test_loss, 100 * correct / total

# %%
def adjust_learning_rate(optimizer, epoch, init_lr, decay_epochs=30):
    """Sets the learning rate to the initial LR decayed by 10 every 30 epochs"""
    lr = init_lr * (0.1 ** (epoch // decay_epochs))
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %% [markdown]
# # Train a ResNet18 on the rotation task (9 points)
#
# In this section, we will train a ResNet18 model **from scratch** on the rotation task. The input is a rotated image and the model predicts the rotation label. See the Data Setup section for details.

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %% [markdown]
# ### Notice: You should not use pretrained weights from ImageNet.

# %%
import torch.nn as nn
import torch.nn.functional as F

from torchvision.models import resnet18

net = resnet18(weights = None, num_classes=4) # Do not modify this line.
net = net.to(device)

# %%
import torch.nn as nn
import torch.optim as optim
################################################################################
# TODO: Define loss and optmizer functions                                     #
# Try any loss or optimizer function and learning rate to get better result    #
# hint: torch.nn and torch.optim                                               #
################################################################################
# Loss and optimizer
criterion = nn.CrossEntropyLoss(label_smoothing=label_smoothing)
learning_rate = 0.001
optimizer = optim.Adam(net.parameters(), lr=learning_rate)
################################################################################
#                               End of your code                               #
################################################################################
criterion = criterion.to(device)

# %%
# Both the self-supervised rotation task and supervised CIFAR10 classification are
# trained with the CrossEntropyLoss, so we can use the training loop code.

def train(net, criterion, optimizer, num_epochs, decay_epochs, init_lr, task, experiment_type=None):
    global experience_report
    for epoch in range(num_epochs):  # loop over the dataset multiple times
        # Initialize epoch variables
        total_loss = 0.0
        total_correct = 0.0
        total_samples = 0.0

        running_loss = 0.0
        running_correct = 0.0
        running_total = 0.0
        start_time = time.time()

        net.train()

        for i, (imgs, imgs_rotated, rotation_label, cls_label) in enumerate(trainloader, 0):
            adjust_learning_rate(optimizer, epoch, init_lr, decay_epochs)
            ######################################################################################################
            # TODO: Set the data to the correct device; Different task will use different inputs and labels      #  
            # TODO: Zero the parameter gradients                                                                 #
            # TODO: forward + backward + optimize                                                                #
            # TODO: Get predicted results                                                                        #
            ######################################################################################################
            # Set data to the correct device
            if task == 'rotation':
                inputs, labels = imgs_rotated.to(device), rotation_label.to(device)
            elif task == 'classification':
                inputs, labels = imgs.to(device), cls_label.to(device)

            optimizer.zero_grad()  # Zero the parameter gradients

            # Forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # Get predicted results for accuracy calculation
            _, predicted = torch.max(outputs.data, 1)
            ######################################################################################################
            #                               End of your code                                                     #
            ######################################################################################################

            # print statistics
            print_freq = 100
            running_loss += loss.item()

            # calc acc
            running_total += labels.size(0)
            running_correct += (predicted == labels).sum().item()

            # Update total counts for epoch averages
            total_loss += loss.item()
            total_samples += labels.size(0)
            total_correct += (predicted == labels).sum().item()

            if i % print_freq == (print_freq - 1):    # print every 2000 mini-batches
                print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / print_freq:.3f} acc: {100*running_correct / running_total:.2f} time: {time.time() - start_time:.2f}')
                running_loss, running_correct, running_total = 0.0, 0.0, 0.0
                start_time = time.time()
        ######################################################################################################
        # TODO: Run the run_test() function after each epoch; Set the model to the evaluation mode.          #
        ######################################################################################################
        # Calculate average training loss and accuracy for the epoch
        avg_train_loss = total_loss / len(trainloader)
        avg_train_acc = 100 * total_correct / total_samples

        # Evaluate the model after each epoch
        net.eval()
        test_loss, test_acc = run_test(net, testloader, criterion, task)

        # Append the epoch's results to the report DataFrame
        if experience_report is not None and experiment_type is not None:
            new_row = pd.DataFrame({
                'Experiment Type': [experiment_type],
                'Epoch': [epoch + 1],
                'Train Accuracy': [avg_train_acc.cpu().numpy()] if torch.is_tensor(avg_train_acc) else [avg_train_acc],
                'Train Loss': [avg_train_loss.cpu().numpy()] if torch.is_tensor(avg_train_loss) else [avg_train_loss],
                'Valid Accuracy': [test_acc.cpu().numpy()] if torch.is_tensor(test_acc) else [test_acc],
                'Valid Loss': [test_loss.cpu().numpy()] if torch.is_tensor(test_loss) else [test_loss]
            })
            experience_report = pd.concat([experience_report, new_row], ignore_index=True)
        ######################################################################################################
        #                               End of your code                                                     #
        ######################################################################################################

    # Save the report DataFrame after the experiment
    if experience_report is not None and experiment_type is not None:
        experience_report.to_csv(f'{experience_name}.csv', index=False)

    print('Finished Training')

# %%
from datetime import datetime

train(net, criterion, optimizer, num_epochs=45, decay_epochs=15, init_lr=0.01, task='rotation', experiment_type='Self-Supervise Rotation Model')
################################
#     TODO: Save the model     #  
################################
# Get current date and time
# Save the model
model_path = f"{experience_name}.pth"
torch.save(net.state_dict(), model_path)
################################
#      End of your code        #  
################################
# Out:
# [1,   100] loss: 1.551 acc: 31.23 time: 42.20
# [1,   200] loss: 1.350 acc: 41.93 time: 8.31
# [1,   300] loss: 1.286 acc: 47.20 time: 7.47
# TESTING:
# Accuracy of the network on the 10000 test images: 48.16 %
# Average loss on the 10000 test images: 1.265
# [2,   100] loss: 1.231 acc: 50.73 time: 11.56
# [2,   200] loss: 1.217 acc: 52.28 time: 8.15
# [2,   300] loss: 1.200 acc: 53.16 time: 8.00
# TESTING:
# Accuracy of the network on the 10000 test images: 57.28 %
# Average loss on the 10000 test images: 1.192
# [3,   100] loss: 1.174 acc: 55.49 time: 8.41
# [3,   200] loss: 1.173 acc: 55.72 time: 8.58
# [3,   300] loss: 1.164 acc: 56.11 time: 8.37
# TESTING:
# Accuracy of the network on the 10000 test images: 55.95 %
# Average loss on the 10000 test images: 1.176
# [4,   100] loss: 1.149 acc: 58.38 time: 8.53
# [4,   200] loss: 1.144 acc: 58.11 time: 15.12
# [4,   300] loss: 1.135 acc: 58.88 time: 13.97
# TESTING:
# Accuracy of the network on the 10000 test images: 61.20 %
# Average loss on the 10000 test images: 1.110
# [5,   100] loss: 1.125 acc: 60.38 time: 8.87
# [5,   200] loss: 1.121 acc: 60.04 time: 9.00
# [5,   300] loss: 1.113 acc: 60.80 time: 8.76
# TESTING:
# Accuracy of the network on the 10000 test images: 62.05 %
# Average loss on the 10000 test images: 1.090
# [6,   100] loss: 1.098 acc: 61.84 time: 8.88
# [6,   200] loss: 1.100 acc: 61.69 time: 8.93
# [6,   300] loss: 1.097 acc: 62.54 time: 8.90
# TESTING:
# Accuracy of the network on the 10000 test images: 63.98 %
# Average loss on the 10000 test images: 1.081
# [7,   100] loss: 1.087 acc: 62.71 time: 9.19
# [7,   200] loss: 1.085 acc: 63.38 time: 8.73
# [7,   300] loss: 1.075 acc: 63.74 time: 10.01
# TESTING:
# Accuracy of the network on the 10000 test images: 64.52 %
# Average loss on the 10000 test images: 1.070
# [8,   100] loss: 1.079 acc: 63.44 time: 9.59
# [8,   200] loss: 1.064 acc: 65.14 time: 8.59
# [8,   300] loss: 1.063 acc: 64.42 time: 8.68
# TESTING:
# Accuracy of the network on the 10000 test images: 64.58 %
# Average loss on the 10000 test images: 1.067
# [9,   100] loss: 1.060 acc: 64.97 time: 7.53
# [9,   200] loss: 1.062 acc: 64.91 time: 7.80
# [9,   300] loss: 1.057 acc: 65.55 time: 7.45
# TESTING:
# Accuracy of the network on the 10000 test images: 67.27 %
# Average loss on the 10000 test images: 1.035
# [10,   100] loss: 1.051 acc: 65.98 time: 7.53
# [10,   200] loss: 1.045 acc: 66.48 time: 9.19
# [10,   300] loss: 1.043 acc: 67.09 time: 15.05
# TESTING:
# Accuracy of the network on the 10000 test images: 68.52 %
# Average loss on the 10000 test images: 1.027
# [11,   100] loss: 1.044 acc: 66.56 time: 8.06
# [11,   200] loss: 1.043 acc: 66.53 time: 7.38
# [11,   300] loss: 1.036 acc: 67.43 time: 7.76
# TESTING:
# Accuracy of the network on the 10000 test images: 67.89 %
# Average loss on the 10000 test images: 1.025
# [12,   100] loss: 1.032 acc: 67.34 time: 7.18
# [12,   200] loss: 1.026 acc: 67.69 time: 7.25
# [12,   300] loss: 1.027 acc: 68.04 time: 7.55
# TESTING:
# Accuracy of the network on the 10000 test images: 68.04 %
# Average loss on the 10000 test images: 1.029
# [13,   100] loss: 1.022 acc: 68.42 time: 7.54
# [13,   200] loss: 1.013 acc: 69.41 time: 7.42
# [13,   300] loss: 1.016 acc: 69.52 time: 7.18
# TESTING:
# Accuracy of the network on the 10000 test images: 70.46 %
# Average loss on the 10000 test images: 0.998
# [14,   100] loss: 1.013 acc: 69.41 time: 7.13
# [14,   200] loss: 1.007 acc: 69.58 time: 7.37
# [14,   300] loss: 1.004 acc: 69.89 time: 7.04
# TESTING:
# Accuracy of the network on the 10000 test images: 70.47 %
# Average loss on the 10000 test images: 0.994
# [15,   100] loss: 0.991 acc: 70.66 time: 8.27
# [15,   200] loss: 0.997 acc: 70.25 time: 7.81
# [15,   300] loss: 1.000 acc: 70.02 time: 7.01
# TESTING:
# Accuracy of the network on the 10000 test images: 71.41 %
# Average loss on the 10000 test images: 0.986
# [16,   100] loss: 0.970 acc: 72.44 time: 7.57
# [16,   200] loss: 0.957 acc: 73.59 time: 7.48
# [16,   300] loss: 0.949 acc: 74.19 time: 8.16
# TESTING:
# Accuracy of the network on the 10000 test images: 74.98 %
# Average loss on the 10000 test images: 0.935
# [17,   100] loss: 0.948 acc: 74.60 time: 7.28
# [17,   200] loss: 0.948 acc: 73.83 time: 7.20
# [17,   300] loss: 0.948 acc: 74.27 time: 7.41
# TESTING:
# Accuracy of the network on the 10000 test images: 75.84 %
# Average loss on the 10000 test images: 0.929
# [18,   100] loss: 0.943 acc: 74.65 time: 8.48
# [18,   200] loss: 0.939 acc: 74.76 time: 8.00
# [18,   300] loss: 0.943 acc: 74.60 time: 7.57
# TESTING:
# Accuracy of the network on the 10000 test images: 75.58 %
# Average loss on the 10000 test images: 0.927
# [19,   100] loss: 0.941 acc: 74.87 time: 7.59
# [19,   200] loss: 0.938 acc: 74.98 time: 7.04
# [19,   300] loss: 0.931 acc: 75.30 time: 7.31
# TESTING:
# Accuracy of the network on the 10000 test images: 76.61 %
# Average loss on the 10000 test images: 0.921
# [20,   100] loss: 0.925 acc: 75.97 time: 7.54
# [20,   200] loss: 0.939 acc: 74.73 time: 8.13
# [20,   300] loss: 0.936 acc: 75.03 time: 7.14
# TESTING:
# Accuracy of the network on the 10000 test images: 76.39 %
# Average loss on the 10000 test images: 0.917
# [21,   100] loss: 0.931 acc: 75.55 time: 7.48
# [21,   200] loss: 0.927 acc: 75.59 time: 7.72
# [21,   300] loss: 0.922 acc: 76.24 time: 7.63
# TESTING:
# Accuracy of the network on the 10000 test images: 76.66 %
# Average loss on the 10000 test images: 0.916
# [22,   100] loss: 0.918 acc: 76.20 time: 7.58
# [22,   200] loss: 0.923 acc: 76.34 time: 8.07
# [22,   300] loss: 0.922 acc: 75.97 time: 7.99
# TESTING:
# Accuracy of the network on the 10000 test images: 77.03 %
# Average loss on the 10000 test images: 0.912
# [23,   100] loss: 0.919 acc: 75.99 time: 7.52
# [23,   200] loss: 0.924 acc: 75.70 time: 7.75
# [23,   300] loss: 0.920 acc: 76.34 time: 7.30
# TESTING:
# Accuracy of the network on the 10000 test images: 76.95 %
# Average loss on the 10000 test images: 0.911
# [24,   100] loss: 0.920 acc: 76.40 time: 8.03
# [24,   200] loss: 0.917 acc: 76.51 time: 7.50
# [24,   300] loss: 0.915 acc: 76.80 time: 8.41
# TESTING:
# Accuracy of the network on the 10000 test images: 77.04 %
# Average loss on the 10000 test images: 0.911
# [25,   100] loss: 0.914 acc: 76.72 time: 7.76
# [25,   200] loss: 0.916 acc: 76.39 time: 7.84
# [25,   300] loss: 0.915 acc: 76.62 time: 8.29
# TESTING:
# Accuracy of the network on the 10000 test images: 77.70 %
# Average loss on the 10000 test images: 0.901
# [26,   100] loss: 0.908 acc: 77.38 time: 7.42
# [26,   200] loss: 0.917 acc: 77.04 time: 7.34
# [26,   300] loss: 0.911 acc: 77.12 time: 7.90
# TESTING:
# Accuracy of the network on the 10000 test images: 77.42 %
# Average loss on the 10000 test images: 0.907
# [27,   100] loss: 0.907 acc: 77.69 time: 7.42
# [27,   200] loss: 0.913 acc: 76.56 time: 7.16
# [27,   300] loss: 0.911 acc: 77.16 time: 7.77
# TESTING:
# Accuracy of the network on the 10000 test images: 77.50 %
# Average loss on the 10000 test images: 0.906
# [28,   100] loss: 0.902 acc: 77.74 time: 7.41
# [28,   200] loss: 0.912 acc: 76.99 time: 7.68
# [28,   300] loss: 0.906 acc: 77.09 time: 7.18
# TESTING:
# Accuracy of the network on the 10000 test images: 77.62 %
# Average loss on the 10000 test images: 0.900
# [29,   100] loss: 0.906 acc: 77.48 time: 7.72
# [29,   200] loss: 0.903 acc: 77.67 time: 7.55
# [29,   300] loss: 0.905 acc: 77.45 time: 7.28
# TESTING:
# Accuracy of the network on the 10000 test images: 78.14 %
# Average loss on the 10000 test images: 0.896
# [30,   100] loss: 0.895 acc: 78.16 time: 7.28
# [30,   200] loss: 0.904 acc: 77.37 time: 7.69
# [30,   300] loss: 0.909 acc: 77.32 time: 8.27
# TESTING:
# Accuracy of the network on the 10000 test images: 77.95 %
# Average loss on the 10000 test images: 0.897
# [31,   100] loss: 0.897 acc: 78.31 time: 7.35
# [31,   200] loss: 0.895 acc: 78.38 time: 7.68
# [31,   300] loss: 0.893 acc: 78.55 time: 8.26
# TESTING:
# Accuracy of the network on the 10000 test images: 78.33 %
# Average loss on the 10000 test images: 0.894
# [32,   100] loss: 0.897 acc: 78.10 time: 7.76
# [32,   200] loss: 0.895 acc: 78.38 time: 7.78
# [32,   300] loss: 0.897 acc: 78.36 time: 7.22
# TESTING:
# Accuracy of the network on the 10000 test images: 78.24 %
# Average loss on the 10000 test images: 0.892
# [33,   100] loss: 0.893 acc: 78.30 time: 7.52
# [33,   200] loss: 0.892 acc: 78.49 time: 7.76
# [33,   300] loss: 0.895 acc: 78.12 time: 8.17
# TESTING:
# Accuracy of the network on the 10000 test images: 78.31 %
# Average loss on the 10000 test images: 0.893
# [34,   100] loss: 0.899 acc: 78.27 time: 7.64
# [34,   200] loss: 0.893 acc: 78.55 time: 7.67
# [34,   300] loss: 0.894 acc: 78.42 time: 8.23
# TESTING:
# Accuracy of the network on the 10000 test images: 78.36 %
# Average loss on the 10000 test images: 0.891
# [35,   100] loss: 0.886 acc: 79.13 time: 7.54
# [35,   200] loss: 0.897 acc: 78.28 time: 7.28
# [35,   300] loss: 0.891 acc: 78.63 time: 7.47
# TESTING:
# Accuracy of the network on the 10000 test images: 78.64 %
# Average loss on the 10000 test images: 0.888
# [36,   100] loss: 0.897 acc: 78.01 time: 7.32
# [36,   200] loss: 0.888 acc: 79.00 time: 7.84
# [36,   300] loss: 0.894 acc: 78.34 time: 7.88
# TESTING:
# Accuracy of the network on the 10000 test images: 78.77 %
# Average loss on the 10000 test images: 0.887
# [37,   100] loss: 0.887 acc: 79.07 time: 7.28
# [37,   200] loss: 0.890 acc: 78.64 time: 8.05
# [37,   300] loss: 0.893 acc: 78.52 time: 7.86
# TESTING:
# Accuracy of the network on the 10000 test images: 78.30 %
# Average loss on the 10000 test images: 0.889
# [38,   100] loss: 0.892 acc: 78.48 time: 7.33
# [38,   200] loss: 0.895 acc: 77.96 time: 8.10
# [38,   300] loss: 0.888 acc: 78.73 time: 7.61
# TESTING:
# Accuracy of the network on the 10000 test images: 78.49 %
# Average loss on the 10000 test images: 0.890
# [39,   100] loss: 0.898 acc: 78.18 time: 7.61
# [39,   200] loss: 0.886 acc: 78.73 time: 8.23
# [39,   300] loss: 0.886 acc: 78.71 time: 7.70
# TESTING:
# Accuracy of the network on the 10000 test images: 78.48 %
# Average loss on the 10000 test images: 0.891
# [40,   100] loss: 0.883 acc: 78.85 time: 7.68
# [40,   200] loss: 0.893 acc: 78.09 time: 8.51
# [40,   300] loss: 0.884 acc: 79.07 time: 7.69
# TESTING:
# Accuracy of the network on the 10000 test images: 78.72 %
# Average loss on the 10000 test images: 0.887
# [41,   100] loss: 0.887 acc: 78.60 time: 7.39
# [41,   200] loss: 0.891 acc: 78.62 time: 8.38
# [41,   300] loss: 0.890 acc: 78.55 time: 7.39
# TESTING:
# Accuracy of the network on the 10000 test images: 78.79 %
# Average loss on the 10000 test images: 0.886
# [42,   100] loss: 0.893 acc: 78.26 time: 8.01
# [42,   200] loss: 0.888 acc: 78.55 time: 9.08
# [42,   300] loss: 0.885 acc: 79.18 time: 8.35
# TESTING:
# Accuracy of the network on the 10000 test images: 78.36 %
# Average loss on the 10000 test images: 0.889
# [43,   100] loss: 0.891 acc: 78.77 time: 8.79
# [43,   200] loss: 0.890 acc: 78.22 time: 8.26
# [43,   300] loss: 0.890 acc: 78.36 time: 7.72
# TESTING:
# Accuracy of the network on the 10000 test images: 78.78 %
# Average loss on the 10000 test images: 0.890
# [44,   100] loss: 0.887 acc: 78.62 time: 8.33
# [44,   200] loss: 0.889 acc: 78.78 time: 7.86
# [44,   300] loss: 0.884 acc: 78.70 time: 8.88
# TESTING:
# Accuracy of the network on the 10000 test images: 79.07 %
# Average loss on the 10000 test images: 0.885
# [45,   100] loss: 0.890 acc: 78.30 time: 7.75
# [45,   200] loss: 0.887 acc: 78.84 time: 8.57
# [45,   300] loss: 0.888 acc: 78.86 time: 8.78
# TESTING:
# Accuracy of the network on the 10000 test images: 79.00 %
# Average loss on the 10000 test images: 0.887
# Finished Training

# %% [markdown]
# ## Fine-tuning on the pre-trained model (9 points)
#
# In this section, we will load the ResNet18 model pre-trained on the rotation task and fine-tune on the classification task. We will freeze all previous layers except for the 'layer4' block and 'fc' layer.
#
# **Then we will use the trained model from rotation task as the pretrained weights. Notice, you should not use the pretrained weights from ImageNet.**

# %%
import torch.nn as nn
import torch.nn.functional as F

from torchvision.models import resnet18

#####################################################
#     TODO: Load the pre-trained ResNet18 model     #  
#####################################################
# load the trained classifier weights
ckpt = torch.load(f"model_2023-11-02-23-22-09.pth")
net.load_state_dict(ckpt)
####################################################
#                End of your code                  #   
####################################################
# Out:
# <All keys matched successfully>

# %%
#################################################################################################
#   TODO: Freeze all previous layers; only keep the 'layer4' block and 'fc' layer trainable     #
#################################################################################################
# Freeze all parameters
net.requires_grad_(False)

# Adjusting the fully connected layer to have 10 outputs for 10 classes
net.fc = nn.Linear(net.fc.in_features, 10)  # Re-define the fc layer

# Unfreeze the last block (layer4) and the fully connected (fc) layer
net.layer4.requires_grad_(True)
net.fc.requires_grad_(True)

# Make sure to move the model to the device after modifying it
net.to(device)
#################################################################################################
#                                          End of your code                                     #
#################################################################################################
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
# Print all the trainable parameters
params_to_update = net.parameters()
print("Params to learn:")
params_to_update = []
for name,param in net.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name)
# Out:
# Params to learn:
# 	 layer4.0.conv1.weight
# 	 layer4.0.bn1.weight
# 	 layer4.0.bn1.bias
# 	 layer4.0.conv2.weight
# 	 layer4.0.bn2.weight
# 	 layer4.0.bn2.bias
# 	 layer4.0.downsample.0.weight
# 	 layer4.0.downsample.1.weight
# 	 layer4.0.downsample.1.bias
# 	 layer4.1.conv1.weight
# 	 layer4.1.bn1.weight
# 	 layer4.1.bn1.bias
# 	 layer4.1.conv2.weight
# 	 layer4.1.bn2.weight
# 	 layer4.1.bn2.bias
# 	 fc.weight
# 	 fc.bias

# %%
# TODO: Define criterion and optimizer
# Note that your optimizer only needs to update the parameters that are trainable.
criterion = nn.CrossEntropyLoss(label_smoothing=label_smoothing)

# Optimizer: Update only the parameters of layer4 and fc
optimizer = optim.Adam([
    {'params': net.layer4.parameters()},
    {'params': net.fc.parameters()}
], lr=0.001)

criterion.to(device)
# Out:
# CrossEntropyLoss()

# %%
train(net, criterion, optimizer, num_epochs=50, decay_epochs=10, init_lr=0.01, task='classification', experiment_type='Fine-tuning Pre-trained Model')
# Out:
# [1,   100] loss: 2.034 acc: 30.35 time: 7.94
# [1,   200] loss: 1.858 acc: 42.53 time: 7.74
# [1,   300] loss: 1.823 acc: 43.71 time: 7.30
# TESTING:
# Accuracy of the network on the 10000 test images: 49.59 %
# Average loss on the 10000 test images: 1.738
# [2,   100] loss: 1.776 acc: 46.57 time: 7.59
# [2,   200] loss: 1.748 acc: 48.87 time: 7.32
# [2,   300] loss: 1.756 acc: 47.96 time: 7.21
# TESTING:
# Accuracy of the network on the 10000 test images: 51.70 %
# Average loss on the 10000 test images: 1.701
# [3,   100] loss: 1.727 acc: 50.03 time: 7.02
# [3,   200] loss: 1.724 acc: 50.79 time: 7.06
# [3,   300] loss: 1.716 acc: 51.13 time: 7.27
# TESTING:
# Accuracy of the network on the 10000 test images: 52.73 %
# Average loss on the 10000 test images: 1.689
# [4,   100] loss: 1.711 acc: 51.15 time: 7.08
# [4,   200] loss: 1.711 acc: 51.07 time: 7.37
# [4,   300] loss: 1.706 acc: 52.04 time: 7.52
# TESTING:
# Accuracy of the network on the 10000 test images: 54.54 %
# Average loss on the 10000 test images: 1.660
# [5,   100] loss: 1.697 acc: 51.95 time: 7.13
# [5,   200] loss: 1.692 acc: 52.62 time: 6.76
# [5,   300] loss: 1.690 acc: 52.45 time: 6.98
# TESTING:
# Accuracy of the network on the 10000 test images: 54.26 %
# Average loss on the 10000 test images: 1.666
# [6,   100] loss: 1.691 acc: 52.59 time: 7.34
# [6,   200] loss: 1.685 acc: 52.75 time: 7.00
# [6,   300] loss: 1.688 acc: 52.56 time: 7.15
# TESTING:
# Accuracy of the network on the 10000 test images: 53.28 %
# Average loss on the 10000 test images: 1.670
# [7,   100] loss: 1.687 acc: 52.83 time: 7.23
# [7,   200] loss: 1.681 acc: 53.41 time: 7.08
# [7,   300] loss: 1.680 acc: 53.82 time: 7.13
# TESTING:
# Accuracy of the network on the 10000 test images: 54.23 %
# Average loss on the 10000 test images: 1.659
# [8,   100] loss: 1.668 acc: 53.38 time: 7.15
# [8,   200] loss: 1.669 acc: 53.73 time: 6.86
# [8,   300] loss: 1.674 acc: 53.15 time: 6.84
# TESTING:
# Accuracy of the network on the 10000 test images: 55.17 %
# Average loss on the 10000 test images: 1.644
# [9,   100] loss: 1.661 acc: 54.02 time: 7.14
# [9,   200] loss: 1.672 acc: 53.52 time: 6.81
# [9,   300] loss: 1.679 acc: 53.26 time: 7.24
# TESTING:
# Accuracy of the network on the 10000 test images: 56.20 %
# Average loss on the 10000 test images: 1.621
# [10,   100] loss: 1.663 acc: 54.02 time: 7.16
# [10,   200] loss: 1.664 acc: 54.12 time: 6.87
# [10,   300] loss: 1.667 acc: 53.80 time: 7.08
# TESTING:
# Accuracy of the network on the 10000 test images: 55.81 %
# Average loss on the 10000 test images: 1.639
# [11,   100] loss: 1.639 acc: 55.59 time: 7.16
# [11,   200] loss: 1.624 acc: 56.42 time: 7.09
# [11,   300] loss: 1.624 acc: 56.25 time: 6.66
# TESTING:
# Accuracy of the network on the 10000 test images: 58.33 %
# Average loss on the 10000 test images: 1.583
# [12,   100] loss: 1.623 acc: 56.85 time: 6.82
# [12,   200] loss: 1.620 acc: 56.72 time: 6.78
# [12,   300] loss: 1.622 acc: 56.38 time: 6.68
# TESTING:
# Accuracy of the network on the 10000 test images: 58.45 %
# Average loss on the 10000 test images: 1.580
# [13,   100] loss: 1.603 acc: 57.48 time: 7.31
# [13,   200] loss: 1.614 acc: 56.89 time: 7.27
# [13,   300] loss: 1.617 acc: 56.61 time: 6.61
# TESTING:
# Accuracy of the network on the 10000 test images: 58.79 %
# Average loss on the 10000 test images: 1.578
# [14,   100] loss: 1.614 acc: 56.55 time: 7.03
# [14,   200] loss: 1.608 acc: 57.23 time: 7.11
# [14,   300] loss: 1.612 acc: 57.11 time: 7.22
# TESTING:
# Accuracy of the network on the 10000 test images: 59.04 %
# Average loss on the 10000 test images: 1.578
# [15,   100] loss: 1.607 acc: 57.23 time: 6.86
# [15,   200] loss: 1.615 acc: 56.95 time: 7.23
# [15,   300] loss: 1.614 acc: 56.88 time: 7.08
# TESTING:
# Accuracy of the network on the 10000 test images: 59.27 %
# Average loss on the 10000 test images: 1.575
# [16,   100] loss: 1.610 acc: 57.29 time: 7.17
# [16,   200] loss: 1.604 acc: 57.79 time: 6.77
# [16,   300] loss: 1.617 acc: 56.55 time: 7.17
# TESTING:
# Accuracy of the network on the 10000 test images: 59.20 %
# Average loss on the 10000 test images: 1.574
# [17,   100] loss: 1.598 acc: 57.95 time: 6.70
# [17,   200] loss: 1.596 acc: 57.77 time: 7.38
# [17,   300] loss: 1.607 acc: 57.20 time: 7.07
# TESTING:
# Accuracy of the network on the 10000 test images: 59.16 %
# Average loss on the 10000 test images: 1.575
# [18,   100] loss: 1.598 acc: 57.66 time: 7.65
# [18,   200] loss: 1.603 acc: 57.48 time: 7.46
# [18,   300] loss: 1.607 acc: 57.20 time: 6.87
# TESTING:
# Accuracy of the network on the 10000 test images: 58.94 %
# Average loss on the 10000 test images: 1.575
# [19,   100] loss: 1.605 acc: 57.51 time: 6.97
# [19,   200] loss: 1.607 acc: 57.33 time: 6.97
# [19,   300] loss: 1.605 acc: 57.38 time: 6.78
# TESTING:
# Accuracy of the network on the 10000 test images: 59.40 %
# Average loss on the 10000 test images: 1.572
# [20,   100] loss: 1.603 acc: 57.24 time: 7.22
# [20,   200] loss: 1.601 acc: 57.85 time: 7.37
# [20,   300] loss: 1.606 acc: 57.29 time: 7.69
# TESTING:
# Accuracy of the network on the 10000 test images: 59.05 %
# Average loss on the 10000 test images: 1.576
# [21,   100] loss: 1.604 acc: 57.73 time: 7.19
# [21,   200] loss: 1.604 acc: 57.41 time: 6.68
# [21,   300] loss: 1.596 acc: 58.42 time: 7.05
# TESTING:
# Accuracy of the network on the 10000 test images: 59.36 %
# Average loss on the 10000 test images: 1.570
# [22,   100] loss: 1.595 acc: 57.71 time: 6.97
# [22,   200] loss: 1.598 acc: 57.43 time: 6.71
# [22,   300] loss: 1.602 acc: 57.52 time: 7.03
# TESTING:
# Accuracy of the network on the 10000 test images: 59.31 %
# Average loss on the 10000 test images: 1.569
# [23,   100] loss: 1.603 acc: 57.37 time: 7.22
# [23,   200] loss: 1.600 acc: 58.05 time: 6.88
# [23,   300] loss: 1.591 acc: 58.07 time: 6.91
# TESTING:
# Accuracy of the network on the 10000 test images: 59.49 %
# Average loss on the 10000 test images: 1.569
# [24,   100] loss: 1.597 acc: 57.72 time: 7.20
# [24,   200] loss: 1.604 acc: 57.68 time: 7.22
# [24,   300] loss: 1.598 acc: 57.49 time: 7.04
# TESTING:
# Accuracy of the network on the 10000 test images: 59.48 %
# Average loss on the 10000 test images: 1.566
# [25,   100] loss: 1.592 acc: 57.95 time: 7.59
# [25,   200] loss: 1.601 acc: 57.88 time: 7.13
# [25,   300] loss: 1.597 acc: 57.88 time: 7.24
# TESTING:
# Accuracy of the network on the 10000 test images: 59.55 %
# Average loss on the 10000 test images: 1.567
# [26,   100] loss: 1.596 acc: 58.12 time: 7.31
# [26,   200] loss: 1.599 acc: 57.39 time: 6.94
# [26,   300] loss: 1.596 acc: 58.59 time: 7.28
# TESTING:
# Accuracy of the network on the 10000 test images: 59.28 %
# Average loss on the 10000 test images: 1.569
# [27,   100] loss: 1.582 acc: 59.05 time: 7.14
# [27,   200] loss: 1.591 acc: 57.81 time: 7.40
# [27,   300] loss: 1.599 acc: 57.99 time: 7.21
# TESTING:
# Accuracy of the network on the 10000 test images: 59.56 %
# Average loss on the 10000 test images: 1.566
# [28,   100] loss: 1.596 acc: 57.77 time: 6.93
# [28,   200] loss: 1.603 acc: 57.55 time: 6.85
# [28,   300] loss: 1.592 acc: 58.16 time: 7.01
# TESTING:
# Accuracy of the network on the 10000 test images: 59.60 %
# Average loss on the 10000 test images: 1.567
# [29,   100] loss: 1.599 acc: 57.91 time: 7.08
# [29,   200] loss: 1.601 acc: 57.12 time: 6.63
# [29,   300] loss: 1.598 acc: 57.90 time: 6.96
# TESTING:
# Accuracy of the network on the 10000 test images: 59.72 %
# Average loss on the 10000 test images: 1.566
# [30,   100] loss: 1.594 acc: 57.77 time: 6.94
# [30,   200] loss: 1.599 acc: 58.05 time: 7.15
# [30,   300] loss: 1.590 acc: 58.17 time: 6.77
# TESTING:
# Accuracy of the network on the 10000 test images: 59.63 %
# Average loss on the 10000 test images: 1.566
# [31,   100] loss: 1.592 acc: 58.16 time: 7.09
# [31,   200] loss: 1.595 acc: 58.07 time: 7.01
# [31,   300] loss: 1.600 acc: 57.38 time: 6.95
# TESTING:
# Accuracy of the network on the 10000 test images: 59.34 %
# Average loss on the 10000 test images: 1.568
# [32,   100] loss: 1.588 acc: 58.41 time: 6.83
# [32,   200] loss: 1.603 acc: 57.36 time: 7.02
# [32,   300] loss: 1.597 acc: 57.94 time: 6.53
# TESTING:
# Accuracy of the network on the 10000 test images: 59.58 %
# Average loss on the 10000 test images: 1.567
# [33,   100] loss: 1.595 acc: 57.97 time: 7.25
# [33,   200] loss: 1.603 acc: 57.50 time: 7.30
# [33,   300] loss: 1.591 acc: 58.11 time: 7.10
# TESTING:
# Accuracy of the network on the 10000 test images: 59.47 %
# Average loss on the 10000 test images: 1.567
# [34,   100] loss: 1.595 acc: 57.77 time: 6.82
# [34,   200] loss: 1.597 acc: 57.54 time: 7.20
# [34,   300] loss: 1.598 acc: 57.71 time: 6.90
# TESTING:
# Accuracy of the network on the 10000 test images: 59.55 %
# Average loss on the 10000 test images: 1.567
# [35,   100] loss: 1.600 acc: 58.08 time: 7.22
# [35,   200] loss: 1.586 acc: 58.21 time: 7.65
# [35,   300] loss: 1.597 acc: 57.89 time: 7.96
# TESTING:
# Accuracy of the network on the 10000 test images: 59.66 %
# Average loss on the 10000 test images: 1.566
# [36,   100] loss: 1.594 acc: 58.22 time: 6.97
# [36,   200] loss: 1.596 acc: 57.84 time: 7.19
# [36,   300] loss: 1.598 acc: 58.23 time: 7.16
# TESTING:
# Accuracy of the network on the 10000 test images: 59.57 %
# Average loss on the 10000 test images: 1.568
# [37,   100] loss: 1.589 acc: 58.52 time: 7.14
# [37,   200] loss: 1.596 acc: 58.01 time: 6.96
# [37,   300] loss: 1.596 acc: 57.84 time: 7.01
# TESTING:
# Accuracy of the network on the 10000 test images: 59.72 %
# Average loss on the 10000 test images: 1.565
# [38,   100] loss: 1.592 acc: 58.41 time: 6.88
# [38,   200] loss: 1.596 acc: 58.40 time: 6.83
# [38,   300] loss: 1.590 acc: 58.79 time: 7.07
# TESTING:
# Accuracy of the network on the 10000 test images: 59.75 %
# Average loss on the 10000 test images: 1.566
# [39,   100] loss: 1.596 acc: 58.12 time: 6.99
# [39,   200] loss: 1.596 acc: 57.89 time: 6.86
# [39,   300] loss: 1.602 acc: 57.72 time: 6.52
# TESTING:
# Accuracy of the network on the 10000 test images: 59.48 %
# Average loss on the 10000 test images: 1.568
# [40,   100] loss: 1.602 acc: 57.19 time: 7.21
# [40,   200] loss: 1.593 acc: 58.02 time: 7.17
# [40,   300] loss: 1.593 acc: 58.51 time: 6.78
# TESTING:
# Accuracy of the network on the 10000 test images: 59.44 %
# Average loss on the 10000 test images: 1.569
# [41,   100] loss: 1.602 acc: 57.42 time: 6.97
# [41,   200] loss: 1.595 acc: 57.74 time: 6.86
# [41,   300] loss: 1.591 acc: 58.24 time: 6.66
# TESTING:
# Accuracy of the network on the 10000 test images: 59.54 %
# Average loss on the 10000 test images: 1.566
# [42,   100] loss: 1.603 acc: 57.04 time: 7.19
# [42,   200] loss: 1.598 acc: 58.07 time: 7.17
# [42,   300] loss: 1.580 acc: 59.06 time: 7.01
# TESTING:
# Accuracy of the network on the 10000 test images: 59.47 %
# Average loss on the 10000 test images: 1.566
# [43,   100] loss: 1.594 acc: 57.41 time: 6.83
# [43,   200] loss: 1.600 acc: 57.61 time: 7.00
# [43,   300] loss: 1.598 acc: 57.70 time: 7.04
# TESTING:
# Accuracy of the network on the 10000 test images: 59.58 %
# Average loss on the 10000 test images: 1.568
# [44,   100] loss: 1.597 acc: 57.72 time: 6.76
# [44,   200] loss: 1.593 acc: 58.37 time: 7.25
# [44,   300] loss: 1.590 acc: 58.23 time: 7.22
# TESTING:
# Accuracy of the network on the 10000 test images: 59.45 %
# Average loss on the 10000 test images: 1.567
# [45,   100] loss: 1.592 acc: 58.52 time: 6.92
# [45,   200] loss: 1.592 acc: 58.30 time: 7.31
# [45,   300] loss: 1.598 acc: 57.91 time: 6.60
# TESTING:
# Accuracy of the network on the 10000 test images: 59.30 %
# Average loss on the 10000 test images: 1.569
# [46,   100] loss: 1.593 acc: 58.09 time: 7.16
# [46,   200] loss: 1.588 acc: 58.66 time: 6.64
# [46,   300] loss: 1.595 acc: 58.39 time: 6.83
# TESTING:
# Accuracy of the network on the 10000 test images: 59.35 %
# Average loss on the 10000 test images: 1.568
# [47,   100] loss: 1.588 acc: 58.73 time: 7.26
# [47,   200] loss: 1.597 acc: 58.11 time: 7.13
# [47,   300] loss: 1.604 acc: 57.20 time: 6.94
# TESTING:
# Accuracy of the network on the 10000 test images: 59.30 %
# Average loss on the 10000 test images: 1.569
# [48,   100] loss: 1.599 acc: 57.67 time: 7.27
# [48,   200] loss: 1.597 acc: 57.83 time: 6.80
# [48,   300] loss: 1.593 acc: 58.70 time: 7.00
# TESTING:
# Accuracy of the network on the 10000 test images: 59.34 %
# Average loss on the 10000 test images: 1.569
# [49,   100] loss: 1.584 acc: 58.23 time: 6.79
# [49,   200] loss: 1.594 acc: 58.39 time: 6.80
# [49,   300] loss: 1.589 acc: 58.53 time: 6.96
# TESTING:
# Accuracy of the network on the 10000 test images: 59.45 %
# Average loss on the 10000 test images: 1.568
# [50,   100] loss: 1.599 acc: 57.53 time: 7.03
# [50,   200] loss: 1.597 acc: 58.36 time: 6.74
# [50,   300] loss: 1.586 acc: 58.68 time: 6.88
# TESTING:
# Accuracy of the network on the 10000 test images: 59.56 %
# Average loss on the 10000 test images: 1.567
# Finished Training

# %% [markdown]
# ## Fine-tuning on the randomly initialized model (9 points)
# In this section, we will randomly initialize a ResNet18 model and fine-tune on the classification task. We will freeze all previous layers except for the 'layer4' block and 'fc' layer.

# %%
import torch.nn as nn
import torch.nn.functional as F

from torchvision.models import resnet18
#################################################
# TODO: Randomly initialize a ResNet18 model    #
#################################################
# Randomly initialize a ResNet18 model
net = resnet18(pretrained=False)
#################################################
#              End of your code                 #
#################################################

# %%
#################################################################################################
# TODO: Freeze all previous layers; only keep the 'layer4' block and 'fc' layer trainable       #
# To do this, you should set requires_grad=False for the frozen layers.                         #
#################################################################################################
# Adjusting the fully connected layer for 10 classes
net.fc = nn.Linear(net.fc.in_features, 10)

# Freeze all layers in the randomly initialized model
net.requires_grad_(False)

# Unfreeze the last block (layer4) and the fully connected (fc) layer
net.layer4.requires_grad_(True)
net.fc.requires_grad_(True)

# Move the model to the device
net.to(device)
#################################################################################################
#                                          End of your code                                     #
#################################################################################################
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
# Print all the trainable parameters
params_to_update = net.parameters()
print("Params to learn:")
params_to_update = []
for name,param in net.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name)
# Out:
# Params to learn:
# 	 layer4.0.conv1.weight
# 	 layer4.0.bn1.weight
# 	 layer4.0.bn1.bias
# 	 layer4.0.conv2.weight
# 	 layer4.0.bn2.weight
# 	 layer4.0.bn2.bias
# 	 layer4.0.downsample.0.weight
# 	 layer4.0.downsample.1.weight
# 	 layer4.0.downsample.1.bias
# 	 layer4.1.conv1.weight
# 	 layer4.1.bn1.weight
# 	 layer4.1.bn1.bias
# 	 layer4.1.conv2.weight
# 	 layer4.1.bn2.weight
# 	 layer4.1.bn2.bias
# 	 fc.weight
# 	 fc.bias

# %%
# TODO: Define criterion and optimizer
# Note that your optimizer only needs to update the parameters that are trainable.
criterion = nn.CrossEntropyLoss(label_smoothing=label_smoothing)

# Optimizer: Update only the parameters of layer4 and fc
optimizer = optim.Adam([
    {'params': net.layer4.parameters()},
    {'params': net.fc.parameters()}
], lr=0.001)

criterion.to(device)
# Out:
# CrossEntropyLoss()

# %%
train(net, criterion, optimizer, num_epochs=50, decay_epochs=10, init_lr=0.01, task='classification', experiment_type='Fine-tuning Randomly Initialized Model')
# Out:
# [1,   100] loss: 2.358 acc: 24.05 time: 6.95
# [1,   200] loss: 2.104 acc: 29.56 time: 7.02
# [1,   300] loss: 2.075 acc: 31.05 time: 6.90
# TESTING:
# Accuracy of the network on the 10000 test images: 34.90 %
# Average loss on the 10000 test images: 1.990
# [2,   100] loss: 2.032 acc: 32.90 time: 6.97
# [2,   200] loss: 2.015 acc: 33.78 time: 6.98
# [2,   300] loss: 2.010 acc: 34.21 time: 7.30
# TESTING:
# Accuracy of the network on the 10000 test images: 37.21 %
# Average loss on the 10000 test images: 1.956
# [3,   100] loss: 1.989 acc: 35.02 time: 7.03
# [3,   200] loss: 1.980 acc: 35.79 time: 6.82
# [3,   300] loss: 1.989 acc: 35.08 time: 7.23
# TESTING:
# Accuracy of the network on the 10000 test images: 39.12 %
# Average loss on the 10000 test images: 1.925
# [4,   100] loss: 1.974 acc: 36.82 time: 6.94
# [4,   200] loss: 1.972 acc: 36.18 time: 7.22
# [4,   300] loss: 1.972 acc: 36.40 time: 7.17
# TESTING:
# Accuracy of the network on the 10000 test images: 39.85 %
# Average loss on the 10000 test images: 1.920
# [5,   100] loss: 1.955 acc: 37.43 time: 7.19
# [5,   200] loss: 1.958 acc: 37.56 time: 6.96
# [5,   300] loss: 1.954 acc: 37.65 time: 7.11
# TESTING:
# Accuracy of the network on the 10000 test images: 40.26 %
# Average loss on the 10000 test images: 1.918
# [6,   100] loss: 1.951 acc: 37.71 time: 6.82
# [6,   200] loss: 1.951 acc: 37.08 time: 6.93
# [6,   300] loss: 1.949 acc: 37.77 time: 7.06
# TESTING:
# Accuracy of the network on the 10000 test images: 40.82 %
# Average loss on the 10000 test images: 1.903
# [7,   100] loss: 1.946 acc: 37.91 time: 6.70
# [7,   200] loss: 1.939 acc: 38.50 time: 6.70
# [7,   300] loss: 1.935 acc: 39.22 time: 6.81
# TESTING:
# Accuracy of the network on the 10000 test images: 40.61 %
# Average loss on the 10000 test images: 1.898
# [8,   100] loss: 1.942 acc: 38.12 time: 7.08
# [8,   200] loss: 1.938 acc: 38.70 time: 7.00
# [8,   300] loss: 1.929 acc: 38.76 time: 7.09
# TESTING:
# Accuracy of the network on the 10000 test images: 40.54 %
# Average loss on the 10000 test images: 1.898
# [9,   100] loss: 1.930 acc: 38.39 time: 6.97
# [9,   200] loss: 1.936 acc: 38.52 time: 7.18
# [9,   300] loss: 1.932 acc: 39.00 time: 7.16
# TESTING:
# Accuracy of the network on the 10000 test images: 41.28 %
# Average loss on the 10000 test images: 1.885
# [10,   100] loss: 1.921 acc: 39.41 time: 6.89
# [10,   200] loss: 1.923 acc: 39.03 time: 6.88
# [10,   300] loss: 1.926 acc: 39.62 time: 6.90
# TESTING:
# Accuracy of the network on the 10000 test images: 40.56 %
# Average loss on the 10000 test images: 1.899
# [11,   100] loss: 1.907 acc: 40.37 time: 7.20
# [11,   200] loss: 1.904 acc: 40.36 time: 7.19
# [11,   300] loss: 1.891 acc: 41.32 time: 7.04
# TESTING:
# Accuracy of the network on the 10000 test images: 42.97 %
# Average loss on the 10000 test images: 1.863
# [12,   100] loss: 1.885 acc: 41.91 time: 7.13
# [12,   200] loss: 1.890 acc: 41.45 time: 6.88
# [12,   300] loss: 1.891 acc: 40.91 time: 6.67
# TESTING:
# Accuracy of the network on the 10000 test images: 43.40 %
# Average loss on the 10000 test images: 1.858
# [13,   100] loss: 1.886 acc: 41.05 time: 7.09
# [13,   200] loss: 1.882 acc: 41.58 time: 6.95
# [13,   300] loss: 1.878 acc: 41.91 time: 6.85
# TESTING:
# Accuracy of the network on the 10000 test images: 43.56 %
# Average loss on the 10000 test images: 1.855
# [14,   100] loss: 1.880 acc: 41.57 time: 7.35
# [14,   200] loss: 1.883 acc: 41.27 time: 6.83
# [14,   300] loss: 1.874 acc: 42.36 time: 6.60
# TESTING:
# Accuracy of the network on the 10000 test images: 43.56 %
# Average loss on the 10000 test images: 1.855
# [15,   100] loss: 1.871 acc: 42.28 time: 7.07
# [15,   200] loss: 1.877 acc: 41.49 time: 7.17
# [15,   300] loss: 1.865 acc: 43.11 time: 7.18
# TESTING:
# Accuracy of the network on the 10000 test images: 43.62 %
# Average loss on the 10000 test images: 1.851
# [16,   100] loss: 1.863 acc: 42.64 time: 7.32
# [16,   200] loss: 1.872 acc: 42.48 time: 6.77
# [16,   300] loss: 1.876 acc: 42.23 time: 7.13
# TESTING:
# Accuracy of the network on the 10000 test images: 43.77 %
# Average loss on the 10000 test images: 1.849
# [17,   100] loss: 1.857 acc: 43.17 time: 6.82
# [17,   200] loss: 1.865 acc: 42.80 time: 6.88
# [17,   300] loss: 1.860 acc: 42.70 time: 7.23
# TESTING:
# Accuracy of the network on the 10000 test images: 43.88 %
# Average loss on the 10000 test images: 1.848
# [18,   100] loss: 1.864 acc: 42.53 time: 6.84
# [18,   200] loss: 1.866 acc: 42.58 time: 6.83
# [18,   300] loss: 1.862 acc: 42.48 time: 7.11
# TESTING:
# Accuracy of the network on the 10000 test images: 44.03 %
# Average loss on the 10000 test images: 1.845
# [19,   100] loss: 1.863 acc: 42.77 time: 6.96
# [19,   200] loss: 1.863 acc: 42.97 time: 7.04
# [19,   300] loss: 1.852 acc: 43.77 time: 6.94
# TESTING:
# Accuracy of the network on the 10000 test images: 44.08 %
# Average loss on the 10000 test images: 1.841
# [20,   100] loss: 1.857 acc: 43.31 time: 7.00
# [20,   200] loss: 1.867 acc: 42.98 time: 6.66
# [20,   300] loss: 1.855 acc: 43.27 time: 6.71
# TESTING:
# Accuracy of the network on the 10000 test images: 44.31 %
# Average loss on the 10000 test images: 1.839
# [21,   100] loss: 1.858 acc: 42.79 time: 7.30
# [21,   200] loss: 1.862 acc: 42.88 time: 7.03
# [21,   300] loss: 1.854 acc: 43.15 time: 7.06
# TESTING:
# Accuracy of the network on the 10000 test images: 44.27 %
# Average loss on the 10000 test images: 1.840
# [22,   100] loss: 1.848 acc: 43.41 time: 6.90
# [22,   200] loss: 1.862 acc: 42.90 time: 6.82
# [22,   300] loss: 1.855 acc: 43.36 time: 6.71
# TESTING:
# Accuracy of the network on the 10000 test images: 44.27 %
# Average loss on the 10000 test images: 1.839
# [23,   100] loss: 1.850 acc: 43.62 time: 6.96
# [23,   200] loss: 1.851 acc: 43.57 time: 6.90
# [23,   300] loss: 1.865 acc: 42.98 time: 7.03
# TESTING:
# Accuracy of the network on the 10000 test images: 44.40 %
# Average loss on the 10000 test images: 1.836
# [24,   100] loss: 1.853 acc: 43.62 time: 6.89
# [24,   200] loss: 1.851 acc: 43.66 time: 6.96
# [24,   300] loss: 1.856 acc: 43.55 time: 7.23
# TESTING:
# Accuracy of the network on the 10000 test images: 44.17 %
# Average loss on the 10000 test images: 1.838
# [25,   100] loss: 1.849 acc: 43.56 time: 7.00
# [25,   200] loss: 1.855 acc: 43.38 time: 7.01
# [25,   300] loss: 1.860 acc: 42.77 time: 6.80
# TESTING:
# Accuracy of the network on the 10000 test images: 44.46 %
# Average loss on the 10000 test images: 1.837
# [26,   100] loss: 1.844 acc: 43.80 time: 7.04
# [26,   200] loss: 1.857 acc: 43.84 time: 6.92
# [26,   300] loss: 1.856 acc: 43.16 time: 6.73
# TESTING:
# Accuracy of the network on the 10000 test images: 44.55 %
# Average loss on the 10000 test images: 1.836
# [27,   100] loss: 1.849 acc: 43.48 time: 6.73
# [27,   200] loss: 1.848 acc: 43.90 time: 7.14
# [27,   300] loss: 1.846 acc: 44.16 time: 6.99
# TESTING:
# Accuracy of the network on the 10000 test images: 44.32 %
# Average loss on the 10000 test images: 1.836
# [28,   100] loss: 1.849 acc: 43.39 time: 6.75
# [28,   200] loss: 1.855 acc: 43.14 time: 6.86
# [28,   300] loss: 1.861 acc: 42.77 time: 6.82
# TESTING:
# Accuracy of the network on the 10000 test images: 44.31 %
# Average loss on the 10000 test images: 1.836
# [29,   100] loss: 1.852 acc: 43.61 time: 6.87
# [29,   200] loss: 1.848 acc: 43.47 time: 6.73
# [29,   300] loss: 1.852 acc: 43.59 time: 7.16
# TESTING:
# Accuracy of the network on the 10000 test images: 44.17 %
# Average loss on the 10000 test images: 1.836
# [30,   100] loss: 1.859 acc: 43.17 time: 6.88
# [30,   200] loss: 1.846 acc: 43.84 time: 7.08
# [30,   300] loss: 1.845 acc: 44.15 time: 6.77
# TESTING:
# Accuracy of the network on the 10000 test images: 44.46 %
# Average loss on the 10000 test images: 1.836
# [31,   100] loss: 1.851 acc: 44.01 time: 7.09
# [31,   200] loss: 1.844 acc: 44.19 time: 7.36
# [31,   300] loss: 1.851 acc: 43.77 time: 7.11
# TESTING:
# Accuracy of the network on the 10000 test images: 44.40 %
# Average loss on the 10000 test images: 1.835
# [32,   100] loss: 1.853 acc: 43.14 time: 6.94
# [32,   200] loss: 1.847 acc: 43.55 time: 6.95
# [32,   300] loss: 1.855 acc: 43.32 time: 7.27
# TESTING:
# Accuracy of the network on the 10000 test images: 44.40 %
# Average loss on the 10000 test images: 1.834
# [33,   100] loss: 1.858 acc: 42.90 time: 7.02
# [33,   200] loss: 1.839 acc: 44.22 time: 7.01
# [33,   300] loss: 1.849 acc: 43.77 time: 6.87
# TESTING:
# Accuracy of the network on the 10000 test images: 44.34 %
# Average loss on the 10000 test images: 1.834
# [34,   100] loss: 1.856 acc: 43.36 time: 6.67
# [34,   200] loss: 1.851 acc: 44.12 time: 6.91
# [34,   300] loss: 1.844 acc: 44.09 time: 6.97
# TESTING:
# Accuracy of the network on the 10000 test images: 44.57 %
# Average loss on the 10000 test images: 1.835
# [35,   100] loss: 1.851 acc: 43.93 time: 7.21
# [35,   200] loss: 1.846 acc: 43.81 time: 6.78
# [35,   300] loss: 1.849 acc: 43.38 time: 7.23
# TESTING:
# Accuracy of the network on the 10000 test images: 44.54 %
# Average loss on the 10000 test images: 1.834
# [36,   100] loss: 1.846 acc: 44.15 time: 7.08
# [36,   200] loss: 1.836 acc: 45.07 time: 7.15
# [36,   300] loss: 1.865 acc: 42.55 time: 7.07
# TESTING:
# Accuracy of the network on the 10000 test images: 44.32 %
# Average loss on the 10000 test images: 1.835
# [37,   100] loss: 1.844 acc: 43.67 time: 7.04
# [37,   200] loss: 1.842 acc: 44.18 time: 7.30
# [37,   300] loss: 1.853 acc: 43.64 time: 6.90
# TESTING:
# Accuracy of the network on the 10000 test images: 44.30 %
# Average loss on the 10000 test images: 1.836
# [38,   100] loss: 1.846 acc: 44.04 time: 6.67
# [38,   200] loss: 1.851 acc: 44.16 time: 6.99
# [38,   300] loss: 1.849 acc: 43.37 time: 6.94
# TESTING:
# Accuracy of the network on the 10000 test images: 44.35 %
# Average loss on the 10000 test images: 1.835
# [39,   100] loss: 1.843 acc: 44.09 time: 6.72
# [39,   200] loss: 1.852 acc: 43.53 time: 7.02
# [39,   300] loss: 1.847 acc: 44.20 time: 7.00
# TESTING:
# Accuracy of the network on the 10000 test images: 44.21 %
# Average loss on the 10000 test images: 1.835
# [40,   100] loss: 1.854 acc: 43.16 time: 7.03
# [40,   200] loss: 1.852 acc: 43.56 time: 6.86
# [40,   300] loss: 1.848 acc: 43.42 time: 7.37
# TESTING:
# Accuracy of the network on the 10000 test images: 44.39 %
# Average loss on the 10000 test images: 1.837
# [41,   100] loss: 1.847 acc: 44.26 time: 6.77
# [41,   200] loss: 1.854 acc: 43.20 time: 6.84
# [41,   300] loss: 1.858 acc: 43.27 time: 7.17
# TESTING:
# Accuracy of the network on the 10000 test images: 44.14 %
# Average loss on the 10000 test images: 1.836
# [42,   100] loss: 1.845 acc: 44.43 time: 7.44
# [42,   200] loss: 1.855 acc: 43.56 time: 7.03
# [42,   300] loss: 1.856 acc: 43.33 time: 6.84
# TESTING:
# Accuracy of the network on the 10000 test images: 44.26 %
# Average loss on the 10000 test images: 1.836
# [43,   100] loss: 1.844 acc: 43.56 time: 7.31
# [43,   200] loss: 1.855 acc: 43.90 time: 6.81
# [43,   300] loss: 1.855 acc: 43.19 time: 6.97
# TESTING:
# Accuracy of the network on the 10000 test images: 44.26 %
# Average loss on the 10000 test images: 1.837
# [44,   100] loss: 1.852 acc: 43.47 time: 7.06
# [44,   200] loss: 1.854 acc: 43.39 time: 7.09
# [44,   300] loss: 1.845 acc: 43.83 time: 6.78
# TESTING:
# Accuracy of the network on the 10000 test images: 44.43 %
# Average loss on the 10000 test images: 1.835
# [45,   100] loss: 1.854 acc: 43.77 time: 7.16
# [45,   200] loss: 1.851 acc: 43.61 time: 7.11
# [45,   300] loss: 1.851 acc: 43.35 time: 7.20
# TESTING:
# Accuracy of the network on the 10000 test images: 44.25 %
# Average loss on the 10000 test images: 1.836
# [46,   100] loss: 1.858 acc: 43.51 time: 6.66
# [46,   200] loss: 1.850 acc: 43.08 time: 6.61
# [46,   300] loss: 1.845 acc: 43.49 time: 7.02
# TESTING:
# Accuracy of the network on the 10000 test images: 44.29 %
# Average loss on the 10000 test images: 1.837
# [47,   100] loss: 1.850 acc: 43.55 time: 6.93
# [47,   200] loss: 1.849 acc: 43.72 time: 6.60
# [47,   300] loss: 1.846 acc: 43.94 time: 7.07
# TESTING:
# Accuracy of the network on the 10000 test images: 44.55 %
# Average loss on the 10000 test images: 1.835
# [48,   100] loss: 1.855 acc: 42.84 time: 7.31
# [48,   200] loss: 1.857 acc: 43.33 time: 7.10
# [48,   300] loss: 1.848 acc: 43.58 time: 7.18
# TESTING:
# Accuracy of the network on the 10000 test images: 44.46 %
# Average loss on the 10000 test images: 1.835
# [49,   100] loss: 1.854 acc: 43.05 time: 6.82
# [49,   200] loss: 1.859 acc: 43.34 time: 6.65
# [49,   300] loss: 1.845 acc: 44.45 time: 6.88
# TESTING:
# Accuracy of the network on the 10000 test images: 44.31 %
# Average loss on the 10000 test images: 1.834
# [50,   100] loss: 1.853 acc: 43.74 time: 7.03
# [50,   200] loss: 1.853 acc: 43.18 time: 7.12
# [50,   300] loss: 1.852 acc: 43.32 time: 6.77
# TESTING:
# Accuracy of the network on the 10000 test images: 44.57 %
# Average loss on the 10000 test images: 1.835
# Finished Training

# %% [markdown]
# ## Supervised training on the pre-trained model (9 points)
# In this section, we will load the ResNet18 model pre-trained on the rotation task and re-train the whole model on the classification task.
#
# **Then we will use the trained model from rotation task as the pretrained weights. Notice, you should not use the pretrained weights from ImageNet.**

# %%
import torch.nn as nn
import torch.nn.functional as F

from torchvision.models import resnet18

#####################################################
#     TODO: Load the pre-trained ResNet18 model     #  
#####################################################
# load the trained classifier weights
net = resnet18(weights=None, num_classes=4)
ckpt = torch.load(f"model_2023-11-02-23-22-09.pth")
net.load_state_dict(ckpt)

# Adjusting the fully connected layer for 10 classes
net.fc = nn.Linear(net.fc.in_features, 10)
net = net.to(device)
#####################################################
#                End of your code                   #   
#####################################################

# %%
# TODO: Define criterion and optimizer
criterion = nn.CrossEntropyLoss(label_smoothing=label_smoothing)

# Optimizer: Update only the parameters of layer4 and fc
optimizer = optim.Adam(lr=0.001, params=net.parameters())

criterion.to(device)
# Out:
# CrossEntropyLoss()

# %%
train(net, criterion, optimizer, num_epochs=50, decay_epochs=10, init_lr=0.01, task='classification', experiment_type='Supervised Pre-trained Model')
# Out:
# [1,   100] loss: 1.790 acc: 45.03 time: 7.14
# [1,   200] loss: 1.578 acc: 60.21 time: 7.08
# [1,   300] loss: 1.519 acc: 63.52 time: 7.74
# TESTING:
# Accuracy of the network on the 10000 test images: 69.66 %
# Average loss on the 10000 test images: 1.422
# [2,   100] loss: 1.437 acc: 68.15 time: 8.31
# [2,   200] loss: 1.421 acc: 69.46 time: 8.09
# [2,   300] loss: 1.391 acc: 71.29 time: 7.91
# TESTING:
# Accuracy of the network on the 10000 test images: 73.48 %
# Average loss on the 10000 test images: 1.359
# [3,   100] loss: 1.351 acc: 73.38 time: 8.31
# [3,   200] loss: 1.353 acc: 72.98 time: 7.78
# [3,   300] loss: 1.342 acc: 74.31 time: 7.58
# TESTING:
# Accuracy of the network on the 10000 test images: 74.95 %
# Average loss on the 10000 test images: 1.322
# [4,   100] loss: 1.306 acc: 75.91 time: 8.70
# [4,   200] loss: 1.300 acc: 76.70 time: 7.95
# [4,   300] loss: 1.293 acc: 76.44 time: 7.65
# TESTING:
# Accuracy of the network on the 10000 test images: 76.34 %
# Average loss on the 10000 test images: 1.298
# [5,   100] loss: 1.282 acc: 77.27 time: 8.14
# [5,   200] loss: 1.280 acc: 77.82 time: 8.40
# [5,   300] loss: 1.279 acc: 77.56 time: 7.57
# TESTING:
# Accuracy of the network on the 10000 test images: 78.13 %
# Average loss on the 10000 test images: 1.267
# [6,   100] loss: 1.256 acc: 78.85 time: 8.31
# [6,   200] loss: 1.254 acc: 78.84 time: 7.42
# [6,   300] loss: 1.256 acc: 78.43 time: 7.73
# TESTING:
# Accuracy of the network on the 10000 test images: 77.32 %
# Average loss on the 10000 test images: 1.278
# [7,   100] loss: 1.232 acc: 79.91 time: 8.54
# [7,   200] loss: 1.238 acc: 79.84 time: 8.08
# [7,   300] loss: 1.235 acc: 80.01 time: 7.76
# TESTING:
# Accuracy of the network on the 10000 test images: 77.88 %
# Average loss on the 10000 test images: 1.272
# [8,   100] loss: 1.215 acc: 81.28 time: 8.55
# [8,   200] loss: 1.215 acc: 81.08 time: 8.04
# [8,   300] loss: 1.219 acc: 80.97 time: 8.21
# TESTING:
# Accuracy of the network on the 10000 test images: 78.92 %
# Average loss on the 10000 test images: 1.252
# [9,   100] loss: 1.210 acc: 81.58 time: 9.08
# [9,   200] loss: 1.210 acc: 80.82 time: 8.09
# [9,   300] loss: 1.197 acc: 81.88 time: 7.82
# TESTING:
# Accuracy of the network on the 10000 test images: 79.87 %
# Average loss on the 10000 test images: 1.230
# [10,   100] loss: 1.192 acc: 82.35 time: 7.99
# [10,   200] loss: 1.197 acc: 82.24 time: 8.09
# [10,   300] loss: 1.198 acc: 82.23 time: 7.88
# TESTING:
# Accuracy of the network on the 10000 test images: 80.20 %
# Average loss on the 10000 test images: 1.231
# [11,   100] loss: 1.148 acc: 84.90 time: 8.34
# [11,   200] loss: 1.130 acc: 85.53 time: 8.15
# [11,   300] loss: 1.128 acc: 85.78 time: 7.87
# TESTING:
# Accuracy of the network on the 10000 test images: 83.05 %
# Average loss on the 10000 test images: 1.173
# [12,   100] loss: 1.115 acc: 86.48 time: 8.50
# [12,   200] loss: 1.116 acc: 86.57 time: 8.49
# [12,   300] loss: 1.108 acc: 86.75 time: 8.49
# TESTING:
# Accuracy of the network on the 10000 test images: 83.27 %
# Average loss on the 10000 test images: 1.172
# [13,   100] loss: 1.108 acc: 86.85 time: 8.93
# [13,   200] loss: 1.104 acc: 86.73 time: 8.38
# [13,   300] loss: 1.115 acc: 86.25 time: 7.98
# TESTING:
# Accuracy of the network on the 10000 test images: 83.57 %
# Average loss on the 10000 test images: 1.164
# [14,   100] loss: 1.100 acc: 87.30 time: 8.25
# [14,   200] loss: 1.099 acc: 87.34 time: 8.68
# [14,   300] loss: 1.098 acc: 87.31 time: 7.96
# TESTING:
# Accuracy of the network on the 10000 test images: 83.79 %
# Average loss on the 10000 test images: 1.163
# [15,   100] loss: 1.098 acc: 87.16 time: 8.20
# [15,   200] loss: 1.087 acc: 88.05 time: 7.97
# [15,   300] loss: 1.107 acc: 86.73 time: 8.35
# TESTING:
# Accuracy of the network on the 10000 test images: 83.78 %
# Average loss on the 10000 test images: 1.164
# [16,   100] loss: 1.086 acc: 88.16 time: 7.92
# [16,   200] loss: 1.102 acc: 87.20 time: 9.14
# [16,   300] loss: 1.096 acc: 87.12 time: 7.89
# TESTING:
# Accuracy of the network on the 10000 test images: 84.02 %
# Average loss on the 10000 test images: 1.160
# [17,   100] loss: 1.094 acc: 87.41 time: 7.84
# [17,   200] loss: 1.091 acc: 87.62 time: 8.10
# [17,   300] loss: 1.095 acc: 87.39 time: 8.32
# TESTING:
# Accuracy of the network on the 10000 test images: 84.06 %
# Average loss on the 10000 test images: 1.160
# [18,   100] loss: 1.082 acc: 88.31 time: 8.67
# [18,   200] loss: 1.086 acc: 88.08 time: 8.41
# [18,   300] loss: 1.085 acc: 87.88 time: 7.90
# TESTING:
# Accuracy of the network on the 10000 test images: 84.09 %
# Average loss on the 10000 test images: 1.159
# [19,   100] loss: 1.084 acc: 88.39 time: 9.41
# [19,   200] loss: 1.085 acc: 88.00 time: 7.76
# [19,   300] loss: 1.081 acc: 88.16 time: 8.29
# TESTING:
# Accuracy of the network on the 10000 test images: 84.40 %
# Average loss on the 10000 test images: 1.158
# [20,   100] loss: 1.079 acc: 88.66 time: 8.38
# [20,   200] loss: 1.074 acc: 88.66 time: 9.38
# [20,   300] loss: 1.085 acc: 87.76 time: 8.26
# TESTING:
# Accuracy of the network on the 10000 test images: 84.47 %
# Average loss on the 10000 test images: 1.157
# [21,   100] loss: 1.066 acc: 89.01 time: 8.63
# [21,   200] loss: 1.071 acc: 89.05 time: 8.17
# [21,   300] loss: 1.075 acc: 88.64 time: 8.23
# TESTING:
# Accuracy of the network on the 10000 test images: 84.42 %
# Average loss on the 10000 test images: 1.155
# [22,   100] loss: 1.069 acc: 89.04 time: 8.47
# [22,   200] loss: 1.073 acc: 88.63 time: 8.37
# [22,   300] loss: 1.071 acc: 88.75 time: 8.44
# TESTING:
# Accuracy of the network on the 10000 test images: 84.55 %
# Average loss on the 10000 test images: 1.154
# [23,   100] loss: 1.069 acc: 88.90 time: 8.48
# [23,   200] loss: 1.066 acc: 89.05 time: 8.21
# [23,   300] loss: 1.075 acc: 88.70 time: 8.52
# TESTING:
# Accuracy of the network on the 10000 test images: 84.49 %
# Average loss on the 10000 test images: 1.153
# [24,   100] loss: 1.064 acc: 89.46 time: 8.75
# [24,   200] loss: 1.071 acc: 89.09 time: 8.16
# [24,   300] loss: 1.073 acc: 88.81 time: 8.16
# TESTING:
# Accuracy of the network on the 10000 test images: 84.70 %
# Average loss on the 10000 test images: 1.154
# [25,   100] loss: 1.067 acc: 89.02 time: 7.78
# [25,   200] loss: 1.072 acc: 89.02 time: 7.93
# [25,   300] loss: 1.069 acc: 89.09 time: 8.29
# TESTING:
# Accuracy of the network on the 10000 test images: 84.54 %
# Average loss on the 10000 test images: 1.154
# [26,   100] loss: 1.070 acc: 88.81 time: 8.61
# [26,   200] loss: 1.069 acc: 89.12 time: 8.34
# [26,   300] loss: 1.070 acc: 89.12 time: 8.69
# TESTING:
# Accuracy of the network on the 10000 test images: 84.62 %
# Average loss on the 10000 test images: 1.153
# [27,   100] loss: 1.067 acc: 89.01 time: 8.52
# [27,   200] loss: 1.064 acc: 89.10 time: 8.99
# [27,   300] loss: 1.068 acc: 88.93 time: 8.07
# TESTING:
# Accuracy of the network on the 10000 test images: 84.63 %
# Average loss on the 10000 test images: 1.153
# [28,   100] loss: 1.073 acc: 88.75 time: 8.85
# [28,   200] loss: 1.062 acc: 89.40 time: 8.12
# [28,   300] loss: 1.071 acc: 89.05 time: 8.18
# TESTING:
# Accuracy of the network on the 10000 test images: 84.62 %
# Average loss on the 10000 test images: 1.153
# [29,   100] loss: 1.064 acc: 89.27 time: 8.51
# [29,   200] loss: 1.066 acc: 88.90 time: 8.42
# [29,   300] loss: 1.068 acc: 89.07 time: 8.05
# TESTING:
# Accuracy of the network on the 10000 test images: 84.46 %
# Average loss on the 10000 test images: 1.153
# [30,   100] loss: 1.077 acc: 88.71 time: 8.31
# [30,   200] loss: 1.064 acc: 89.31 time: 8.90
# [30,   300] loss: 1.063 acc: 89.18 time: 8.63
# TESTING:
# Accuracy of the network on the 10000 test images: 84.59 %
# Average loss on the 10000 test images: 1.153
# [31,   100] loss: 1.068 acc: 88.84 time: 8.83
# [31,   200] loss: 1.066 acc: 89.45 time: 8.36
# [31,   300] loss: 1.059 acc: 89.35 time: 8.37
# TESTING:
# Accuracy of the network on the 10000 test images: 84.45 %
# Average loss on the 10000 test images: 1.153
# [32,   100] loss: 1.064 acc: 89.63 time: 8.55
# [32,   200] loss: 1.061 acc: 89.51 time: 8.25
# [32,   300] loss: 1.069 acc: 88.93 time: 8.14
# TESTING:
# Accuracy of the network on the 10000 test images: 84.52 %
# Average loss on the 10000 test images: 1.153
# [33,   100] loss: 1.063 acc: 89.51 time: 7.85
# [33,   200] loss: 1.063 acc: 89.59 time: 8.08
# [33,   300] loss: 1.058 acc: 89.61 time: 8.33
# TESTING:
# Accuracy of the network on the 10000 test images: 84.44 %
# Average loss on the 10000 test images: 1.153
# [34,   100] loss: 1.062 acc: 89.37 time: 7.68
# [34,   200] loss: 1.069 acc: 88.95 time: 8.72
# [34,   300] loss: 1.069 acc: 88.98 time: 8.71
# TESTING:
# Accuracy of the network on the 10000 test images: 84.50 %
# Average loss on the 10000 test images: 1.153
# [35,   100] loss: 1.068 acc: 89.00 time: 8.53
# [35,   200] loss: 1.063 acc: 89.12 time: 9.09
# [35,   300] loss: 1.067 acc: 89.08 time: 8.59
# TESTING:
# Accuracy of the network on the 10000 test images: 84.51 %
# Average loss on the 10000 test images: 1.153
# [36,   100] loss: 1.068 acc: 88.83 time: 8.39
# [36,   200] loss: 1.068 acc: 89.03 time: 7.94
# [36,   300] loss: 1.056 acc: 89.61 time: 8.22
# TESTING:
# Accuracy of the network on the 10000 test images: 84.38 %
# Average loss on the 10000 test images: 1.154
# [37,   100] loss: 1.061 acc: 89.28 time: 7.95
# [37,   200] loss: 1.063 acc: 89.36 time: 8.52
# [37,   300] loss: 1.067 acc: 88.97 time: 8.57
# TESTING:
# Accuracy of the network on the 10000 test images: 84.59 %
# Average loss on the 10000 test images: 1.153
# [38,   100] loss: 1.063 acc: 89.18 time: 8.51
# [38,   200] loss: 1.063 acc: 89.16 time: 8.29
# [38,   300] loss: 1.067 acc: 89.25 time: 8.27
# TESTING:
# Accuracy of the network on the 10000 test images: 84.63 %
# Average loss on the 10000 test images: 1.153
# [39,   100] loss: 1.061 acc: 89.33 time: 8.17
# [39,   200] loss: 1.056 acc: 89.77 time: 8.34
# [39,   300] loss: 1.073 acc: 88.71 time: 8.50
# TESTING:
# Accuracy of the network on the 10000 test images: 84.60 %
# Average loss on the 10000 test images: 1.152
# [40,   100] loss: 1.061 acc: 89.12 time: 8.40
# [40,   200] loss: 1.067 acc: 89.29 time: 8.66
# [40,   300] loss: 1.061 acc: 89.31 time: 8.74
# TESTING:
# Accuracy of the network on the 10000 test images: 84.60 %
# Average loss on the 10000 test images: 1.153
# [41,   100] loss: 1.060 acc: 89.38 time: 8.98
# [41,   200] loss: 1.066 acc: 89.11 time: 8.05
# [41,   300] loss: 1.063 acc: 89.22 time: 8.17
# TESTING:
# Accuracy of the network on the 10000 test images: 84.58 %
# Average loss on the 10000 test images: 1.153
# [42,   100] loss: 1.063 acc: 89.41 time: 8.86
# [42,   200] loss: 1.065 acc: 89.20 time: 8.22
# [42,   300] loss: 1.063 acc: 89.39 time: 8.36
# TESTING:
# Accuracy of the network on the 10000 test images: 84.42 %
# Average loss on the 10000 test images: 1.154
# [43,   100] loss: 1.060 acc: 89.43 time: 9.02
# [43,   200] loss: 1.068 acc: 88.90 time: 9.49
# [43,   300] loss: 1.070 acc: 88.89 time: 8.43
# TESTING:
# Accuracy of the network on the 10000 test images: 84.62 %
# Average loss on the 10000 test images: 1.153
# [44,   100] loss: 1.065 acc: 89.20 time: 8.73
# [44,   200] loss: 1.064 acc: 89.36 time: 9.08
# [44,   300] loss: 1.069 acc: 88.92 time: 8.00
# TESTING:
# Accuracy of the network on the 10000 test images: 84.55 %
# Average loss on the 10000 test images: 1.153
# [45,   100] loss: 1.071 acc: 88.90 time: 8.59
# [45,   200] loss: 1.061 acc: 89.38 time: 9.10
# [45,   300] loss: 1.061 acc: 89.31 time: 8.16
# TESTING:
# Accuracy of the network on the 10000 test images: 84.45 %
# Average loss on the 10000 test images: 1.153
# [46,   100] loss: 1.071 acc: 88.65 time: 8.05
# [46,   200] loss: 1.066 acc: 89.08 time: 8.63
# [46,   300] loss: 1.062 acc: 89.26 time: 8.19
# TESTING:
# Accuracy of the network on the 10000 test images: 84.47 %
# Average loss on the 10000 test images: 1.153
# [47,   100] loss: 1.063 acc: 89.17 time: 8.86
# [47,   200] loss: 1.068 acc: 88.74 time: 8.54
# [47,   300] loss: 1.059 acc: 89.58 time: 8.15
# TESTING:
# Accuracy of the network on the 10000 test images: 84.49 %
# Average loss on the 10000 test images: 1.154
# [48,   100] loss: 1.066 acc: 89.06 time: 8.48
# [48,   200] loss: 1.067 acc: 89.30 time: 8.63
# [48,   300] loss: 1.068 acc: 88.77 time: 8.35
# TESTING:
# Accuracy of the network on the 10000 test images: 84.62 %
# Average loss on the 10000 test images: 1.153
# [49,   100] loss: 1.060 acc: 89.60 time: 7.93
# [49,   200] loss: 1.065 acc: 89.09 time: 8.73
# [49,   300] loss: 1.060 acc: 89.57 time: 8.62
# TESTING:
# Accuracy of the network on the 10000 test images: 84.54 %
# Average loss on the 10000 test images: 1.153
# [50,   100] loss: 1.064 acc: 89.40 time: 8.47
# [50,   200] loss: 1.061 acc: 89.55 time: 8.06
# [50,   300] loss: 1.067 acc: 89.40 time: 8.54
# TESTING:
# Accuracy of the network on the 10000 test images: 84.55 %
# Average loss on the 10000 test images: 1.153
# Finished Training

# %% [markdown]
# ## Supervised training on the randomly initialized model (9 points)
# In this section, we will randomly initialize a ResNet18 model and re-train the whole model on the classification task.

# %%
import torch.nn as nn
import torch.nn.functional as F

from torchvision.models import resnet18

#################################################
# TODO: Randomly initialize a ResNet18 model    #
#################################################
net = resnet18(weights=None, num_classes=10)
net = net.to(device)
#################################################
#              End of your code                 #
#################################################

# %%
# TODO: Define criterion and optimizer
criterion = nn.CrossEntropyLoss(label_smoothing=label_smoothing)

# Optimizer: Update only the parameters of layer4 and fc
optimizer = optim.Adam(lr=0.001, params=net.parameters())

criterion.to(device)
# Out:
# CrossEntropyLoss()

# %%
train(net, criterion, optimizer, num_epochs=50, decay_epochs=10, init_lr=0.01, task='classification', experiment_type='Supervised Randomly Initialized Model')
# Out:
# [1,   100] loss: 2.425 acc: 20.09 time: 9.11
# [1,   200] loss: 2.067 acc: 30.88 time: 8.79
# [1,   300] loss: 1.952 acc: 37.26 time: 8.55
# TESTING:
# Accuracy of the network on the 10000 test images: 45.66 %
# Average loss on the 10000 test images: 1.872
# [2,   100] loss: 1.841 acc: 44.22 time: 8.53
# [2,   200] loss: 1.797 acc: 46.80 time: 9.72
# [2,   300] loss: 1.734 acc: 50.30 time: 17.51
# TESTING:
# Accuracy of the network on the 10000 test images: 54.24 %
# Average loss on the 10000 test images: 1.698
# [3,   100] loss: 1.675 acc: 53.77 time: 10.36
# [3,   200] loss: 1.638 acc: 56.19 time: 10.57
# [3,   300] loss: 1.612 acc: 58.15 time: 10.44
# TESTING:
# Accuracy of the network on the 10000 test images: 60.94 %
# Average loss on the 10000 test images: 1.552
# [4,   100] loss: 1.548 acc: 61.90 time: 10.20
# [4,   200] loss: 1.548 acc: 61.80 time: 9.51
# [4,   300] loss: 1.520 acc: 62.95 time: 9.76
# TESTING:
# Accuracy of the network on the 10000 test images: 65.94 %
# Average loss on the 10000 test images: 1.489
# [5,   100] loss: 1.488 acc: 65.46 time: 10.07
# [5,   200] loss: 1.482 acc: 65.54 time: 9.99
# [5,   300] loss: 1.473 acc: 66.14 time: 10.03
# TESTING:
# Accuracy of the network on the 10000 test images: 69.17 %
# Average loss on the 10000 test images: 1.419
# [6,   100] loss: 1.431 acc: 68.42 time: 9.99
# [6,   200] loss: 1.414 acc: 69.65 time: 10.38
# [6,   300] loss: 1.411 acc: 69.73 time: 10.71
# TESTING:
# Accuracy of the network on the 10000 test images: 68.82 %
# Average loss on the 10000 test images: 1.430
# [7,   100] loss: 1.381 acc: 70.84 time: 10.36
# [7,   200] loss: 1.377 acc: 71.73 time: 9.73
# [7,   300] loss: 1.372 acc: 72.16 time: 8.54
# TESTING:
# Accuracy of the network on the 10000 test images: 70.49 %
# Average loss on the 10000 test images: 1.406
# [8,   100] loss: 1.341 acc: 73.39 time: 8.85
# [8,   200] loss: 1.347 acc: 73.59 time: 8.91
# [8,   300] loss: 1.342 acc: 73.72 time: 9.06
# TESTING:
# Accuracy of the network on the 10000 test images: 74.03 %
# Average loss on the 10000 test images: 1.340
# [9,   100] loss: 1.320 acc: 75.07 time: 8.99
# [9,   200] loss: 1.329 acc: 74.38 time: 9.22
# [9,   300] loss: 1.329 acc: 74.39 time: 9.07
# TESTING:
# Accuracy of the network on the 10000 test images: 71.96 %
# Average loss on the 10000 test images: 1.389
# [10,   100] loss: 1.302 acc: 76.32 time: 8.98
# [10,   200] loss: 1.302 acc: 75.74 time: 8.99
# [10,   300] loss: 1.302 acc: 76.28 time: 27.84
# TESTING:
# Accuracy of the network on the 10000 test images: 76.12 %
# Average loss on the 10000 test images: 1.302
# [11,   100] loss: 1.237 acc: 79.70 time: 7.71
# [11,   200] loss: 1.223 acc: 80.46 time: 8.11
# [11,   300] loss: 1.213 acc: 80.82 time: 8.66
# TESTING:
# Accuracy of the network on the 10000 test images: 80.37 %
# Average loss on the 10000 test images: 1.218
# [12,   100] loss: 1.197 acc: 81.46 time: 8.22
# [12,   200] loss: 1.199 acc: 81.84 time: 8.56
# [12,   300] loss: 1.201 acc: 81.41 time: 8.32
# TESTING:
# Accuracy of the network on the 10000 test images: 80.91 %
# Average loss on the 10000 test images: 1.213
# [13,   100] loss: 1.192 acc: 82.38 time: 8.28
# [13,   200] loss: 1.180 acc: 82.50 time: 9.21
# [13,   300] loss: 1.185 acc: 82.56 time: 8.02
# TESTING:
# Accuracy of the network on the 10000 test images: 81.40 %
# Average loss on the 10000 test images: 1.205
# [14,   100] loss: 1.185 acc: 82.20 time: 8.57
# [14,   200] loss: 1.174 acc: 83.16 time: 8.44
# [14,   300] loss: 1.179 acc: 82.98 time: 8.17
# TESTING:
# Accuracy of the network on the 10000 test images: 81.39 %
# Average loss on the 10000 test images: 1.202
# [15,   100] loss: 1.164 acc: 83.84 time: 8.30
# [15,   200] loss: 1.173 acc: 82.99 time: 9.50
# [15,   300] loss: 1.171 acc: 83.03 time: 8.56
# TESTING:
# Accuracy of the network on the 10000 test images: 81.84 %
# Average loss on the 10000 test images: 1.196
# [16,   100] loss: 1.164 acc: 83.43 time: 8.54
# [16,   200] loss: 1.161 acc: 83.59 time: 8.86
# [16,   300] loss: 1.169 acc: 83.23 time: 8.11
# TESTING:
# Accuracy of the network on the 10000 test images: 81.77 %
# Average loss on the 10000 test images: 1.200
# [17,   100] loss: 1.160 acc: 84.03 time: 8.51
# [17,   200] loss: 1.158 acc: 83.78 time: 7.82
# [17,   300] loss: 1.159 acc: 84.02 time: 7.98
# TESTING:
# Accuracy of the network on the 10000 test images: 82.08 %
# Average loss on the 10000 test images: 1.192
# [18,   100] loss: 1.140 acc: 84.58 time: 7.88
# [18,   200] loss: 1.154 acc: 84.17 time: 7.91
# [18,   300] loss: 1.157 acc: 83.89 time: 8.06
# TESTING:
# Accuracy of the network on the 10000 test images: 81.92 %
# Average loss on the 10000 test images: 1.196
# [19,   100] loss: 1.144 acc: 84.69 time: 8.33
# [19,   200] loss: 1.144 acc: 84.79 time: 7.91
# [19,   300] loss: 1.145 acc: 84.50 time: 8.13
# TESTING:
# Accuracy of the network on the 10000 test images: 82.15 %
# Average loss on the 10000 test images: 1.189
# [20,   100] loss: 1.140 acc: 84.87 time: 8.44
# [20,   200] loss: 1.145 acc: 84.80 time: 8.25
# [20,   300] loss: 1.137 acc: 84.99 time: 8.65
# TESTING:
# Accuracy of the network on the 10000 test images: 82.13 %
# Average loss on the 10000 test images: 1.193
# [21,   100] loss: 1.122 acc: 85.89 time: 8.96
# [21,   200] loss: 1.132 acc: 85.16 time: 8.69
# [21,   300] loss: 1.127 acc: 85.48 time: 8.41
# TESTING:
# Accuracy of the network on the 10000 test images: 82.67 %
# Average loss on the 10000 test images: 1.182
# [22,   100] loss: 1.129 acc: 85.49 time: 8.30
# [22,   200] loss: 1.116 acc: 86.29 time: 8.22
# [22,   300] loss: 1.118 acc: 85.95 time: 8.08
# TESTING:
# Accuracy of the network on the 10000 test images: 82.69 %
# Average loss on the 10000 test images: 1.180
# [23,   100] loss: 1.117 acc: 86.20 time: 8.72
# [23,   200] loss: 1.127 acc: 85.41 time: 8.62
# [23,   300] loss: 1.127 acc: 85.66 time: 8.46
# TESTING:
# Accuracy of the network on the 10000 test images: 82.78 %
# Average loss on the 10000 test images: 1.179
# [24,   100] loss: 1.125 acc: 86.02 time: 14.32
# [24,   200] loss: 1.118 acc: 86.14 time: 19.93
# [24,   300] loss: 1.111 acc: 86.32 time: 15.66
# TESTING:
# Accuracy of the network on the 10000 test images: 82.96 %
# Average loss on the 10000 test images: 1.179
# [25,   100] loss: 1.116 acc: 86.05 time: 8.69
# [25,   200] loss: 1.121 acc: 85.99 time: 8.49
# [25,   300] loss: 1.126 acc: 85.52 time: 8.14
# TESTING:
# Accuracy of the network on the 10000 test images: 82.93 %
# Average loss on the 10000 test images: 1.178
# [26,   100] loss: 1.121 acc: 86.00 time: 8.70
# [26,   200] loss: 1.118 acc: 86.11 time: 7.80
# [26,   300] loss: 1.118 acc: 86.23 time: 7.93
# TESTING:
# Accuracy of the network on the 10000 test images: 82.97 %
# Average loss on the 10000 test images: 1.179
# [27,   100] loss: 1.114 acc: 86.28 time: 8.32
# [27,   200] loss: 1.113 acc: 86.77 time: 7.87
# [27,   300] loss: 1.119 acc: 85.66 time: 8.31
# TESTING:
# Accuracy of the network on the 10000 test images: 82.68 %
# Average loss on the 10000 test images: 1.183
# [28,   100] loss: 1.118 acc: 86.20 time: 7.92
# [28,   200] loss: 1.112 acc: 86.54 time: 8.12
# [28,   300] loss: 1.113 acc: 86.48 time: 8.07
# TESTING:
# Accuracy of the network on the 10000 test images: 82.90 %
# Average loss on the 10000 test images: 1.178
# [29,   100] loss: 1.122 acc: 85.67 time: 8.35
# [29,   200] loss: 1.116 acc: 86.17 time: 8.56
# [29,   300] loss: 1.110 acc: 86.72 time: 8.20
# TESTING:
# Accuracy of the network on the 10000 test images: 83.04 %
# Average loss on the 10000 test images: 1.179
# [30,   100] loss: 1.114 acc: 86.23 time: 7.93
# [30,   200] loss: 1.110 acc: 86.82 time: 8.14
# [30,   300] loss: 1.111 acc: 86.66 time: 7.94
# TESTING:
# Accuracy of the network on the 10000 test images: 82.86 %
# Average loss on the 10000 test images: 1.180
# [31,   100] loss: 1.109 acc: 86.91 time: 8.11
# [31,   200] loss: 1.109 acc: 86.45 time: 8.92
# [31,   300] loss: 1.104 acc: 87.04 time: 8.25
# TESTING:
# Accuracy of the network on the 10000 test images: 82.76 %
# Average loss on the 10000 test images: 1.180
# [32,   100] loss: 1.109 acc: 86.51 time: 8.66
# [32,   200] loss: 1.107 acc: 86.72 time: 9.26
# [32,   300] loss: 1.108 acc: 86.85 time: 8.35
# TESTING:
# Accuracy of the network on the 10000 test images: 82.83 %
# Average loss on the 10000 test images: 1.180
# [33,   100] loss: 1.112 acc: 86.43 time: 8.30
# [33,   200] loss: 1.105 acc: 86.72 time: 8.92
# [33,   300] loss: 1.110 acc: 86.56 time: 8.14
# TESTING:
# Accuracy of the network on the 10000 test images: 83.08 %
# Average loss on the 10000 test images: 1.179
# [34,   100] loss: 1.114 acc: 86.32 time: 8.50
# [34,   200] loss: 1.108 acc: 86.65 time: 8.54
# [34,   300] loss: 1.103 acc: 87.23 time: 8.18
# TESTING:
# Accuracy of the network on the 10000 test images: 82.86 %
# Average loss on the 10000 test images: 1.180
# [35,   100] loss: 1.115 acc: 86.11 time: 8.71
# [35,   200] loss: 1.114 acc: 86.52 time: 8.71
# [35,   300] loss: 1.108 acc: 86.75 time: 8.32
# TESTING:
# Accuracy of the network on the 10000 test images: 82.89 %
# Average loss on the 10000 test images: 1.180
# [36,   100] loss: 1.111 acc: 86.77 time: 8.57
# [36,   200] loss: 1.112 acc: 86.44 time: 8.74
# [36,   300] loss: 1.120 acc: 86.15 time: 8.27
# TESTING:
# Accuracy of the network on the 10000 test images: 82.89 %
# Average loss on the 10000 test images: 1.179
# [37,   100] loss: 1.112 acc: 86.48 time: 8.19
# [37,   200] loss: 1.111 acc: 86.50 time: 8.20
# [37,   300] loss: 1.111 acc: 86.74 time: 8.24
# TESTING:
# Accuracy of the network on the 10000 test images: 82.87 %
# Average loss on the 10000 test images: 1.181
# [38,   100] loss: 1.112 acc: 86.62 time: 7.93
# [38,   200] loss: 1.114 acc: 86.20 time: 8.46
# [38,   300] loss: 1.114 acc: 86.35 time: 8.09
# TESTING:
# Accuracy of the network on the 10000 test images: 82.92 %
# Average loss on the 10000 test images: 1.179
# [39,   100] loss: 1.108 acc: 86.92 time: 9.71
# [39,   200] loss: 1.103 acc: 86.88 time: 8.64
# [39,   300] loss: 1.105 acc: 87.03 time: 8.28
# TESTING:
# Accuracy of the network on the 10000 test images: 82.93 %
# Average loss on the 10000 test images: 1.178
# [40,   100] loss: 1.113 acc: 86.19 time: 8.17
# [40,   200] loss: 1.105 acc: 86.95 time: 8.42
# [40,   300] loss: 1.113 acc: 86.29 time: 8.43
# TESTING:
# Accuracy of the network on the 10000 test images: 82.96 %
# Average loss on the 10000 test images: 1.180
# [41,   100] loss: 1.119 acc: 86.11 time: 8.75
# [41,   200] loss: 1.101 acc: 87.13 time: 8.86
# [41,   300] loss: 1.105 acc: 86.74 time: 7.95
# TESTING:
# Accuracy of the network on the 10000 test images: 82.91 %
# Average loss on the 10000 test images: 1.179
# [42,   100] loss: 1.112 acc: 86.47 time: 8.49
# [42,   200] loss: 1.109 acc: 86.51 time: 7.78
# [42,   300] loss: 1.112 acc: 86.30 time: 8.11
# TESTING:
# Accuracy of the network on the 10000 test images: 82.95 %
# Average loss on the 10000 test images: 1.179
# [43,   100] loss: 1.108 acc: 86.71 time: 8.14
# [43,   200] loss: 1.104 acc: 87.28 time: 8.96
# [43,   300] loss: 1.113 acc: 86.55 time: 8.18
# TESTING:
# Accuracy of the network on the 10000 test images: 82.97 %
# Average loss on the 10000 test images: 1.178
# [44,   100] loss: 1.105 acc: 86.82 time: 8.17
# [44,   200] loss: 1.113 acc: 86.34 time: 8.12
# [44,   300] loss: 1.109 acc: 86.90 time: 8.20
# TESTING:
# Accuracy of the network on the 10000 test images: 82.87 %
# Average loss on the 10000 test images: 1.179
# [45,   100] loss: 1.113 acc: 86.46 time: 8.84
# [45,   200] loss: 1.109 acc: 86.55 time: 8.52
# [45,   300] loss: 1.108 acc: 87.02 time: 9.56
# TESTING:
# Accuracy of the network on the 10000 test images: 82.90 %
# Average loss on the 10000 test images: 1.180
# [46,   100] loss: 1.110 acc: 86.65 time: 8.86
# [46,   200] loss: 1.113 acc: 86.12 time: 8.58
# [46,   300] loss: 1.108 acc: 86.84 time: 8.35
# TESTING:
# Accuracy of the network on the 10000 test images: 82.84 %
# Average loss on the 10000 test images: 1.179
# [47,   100] loss: 1.118 acc: 86.23 time: 8.03
# [47,   200] loss: 1.110 acc: 86.44 time: 8.75
# [47,   300] loss: 1.110 acc: 86.68 time: 8.38
# TESTING:
# Accuracy of the network on the 10000 test images: 82.92 %
# Average loss on the 10000 test images: 1.178
# [48,   100] loss: 1.112 acc: 86.80 time: 8.50
# [48,   200] loss: 1.112 acc: 86.35 time: 8.53
# [48,   300] loss: 1.106 acc: 86.73 time: 8.86
# TESTING:
# Accuracy of the network on the 10000 test images: 82.97 %
# Average loss on the 10000 test images: 1.179
# [49,   100] loss: 1.111 acc: 86.44 time: 8.62
# [49,   200] loss: 1.106 acc: 86.97 time: 8.34
# [49,   300] loss: 1.108 acc: 86.64 time: 8.35
# TESTING:
# Accuracy of the network on the 10000 test images: 82.92 %
# Average loss on the 10000 test images: 1.179
# [50,   100] loss: 1.109 acc: 86.55 time: 8.61
# [50,   200] loss: 1.113 acc: 86.56 time: 9.24
# [50,   300] loss: 1.102 acc: 86.93 time: 14.75
# TESTING:
# Accuracy of the network on the 10000 test images: 83.04 %
# Average loss on the 10000 test images: 1.179
# Finished Training

# %% [markdown]
# # Write report (37 points)
#
# 本次作業主要有3個tasks需要大家完成，在A4.pdf中有希望大家達成的baseline **(不能低於baseline最多2%，沒有達到不會給全部分數)**，report的撰寫就希望大家可以透過去調整不同的訓練方法、損失函數、優化器，或者是調整凍結不同的層來進行這次的實驗，就請大家將嘗試的結果寫在report裡，祝大家順利！
#
# - Rotation task (13 points)
# - Fine-tuning the specified layers of the pre-trained model (12 points)
# - Fine-tuning the whole pre-trained model (12 points)

# %% [markdown]
# # Extra Credit (13 points)
#
# 上面基本的code跟report最高可以拿到87分，這個加分部分並沒有要求同學們一定要做，若同學們想要獲得更高的分數可以根據以下的加分要求來獲得加分。
#
# - In Figure 5(b) from the Gidaris et al. paper, the authors show a plot of CIFAR10 classification performance vs. number of training examples per category for a supervised CIFAR10 model vs. a RotNet model with the final layers fine-tuned on CIFAR10. The plot shows that pre-training on the Rotation task can be advantageous when only a small amount of labeled data is available. Using your RotNet fine-tuning code and supervised CIFAR10 training code from the main assignment, try to create a similar plot by performing supervised fine-tuning/training on only a subset of CIFAR10.
# - Use a more advanced model than ResNet18 to try to get higher accuracy on the rotation prediction task, as well as for transfer to supervised CIFAR10 classification.
#
# - If you have a good amount of compute at your disposal, try to train a rotation prediction model on the larger ImageNette dataset (still smaller than ImageNet, though).
