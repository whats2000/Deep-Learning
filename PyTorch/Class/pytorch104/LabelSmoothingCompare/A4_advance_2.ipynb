# %% [markdown]
# # MIS 583 Assignment 4: Self-supervised and transfer learning on CIFAR10

# %% [markdown]
# Before we start, please put your name and SID in following format: <br>
# : LASTNAME Firstname, ?00000000   //   e.g.) 李晨愷 M114020035

# %% [markdown]
# **Your Answer:**
# Hi I'm 鄔仁迪, B104020009.

# %%
import pandas as pd

experience_name = 'label_smoothing_2'
label_smoothing = 0.2

# Define columns for the DataFrame
columns = ['Experiment Type', 'Epoch', 'Train Accuracy', 'Train Loss', 'Valid Accuracy', 'Valid Loss']

# Initialize an empty DataFrame with these columns
experience_report = pd.DataFrame(columns=columns)

experience_report
# Out:
# Empty DataFrame
# Columns: [Experiment Type, Epoch, Train Accuracy, Train Loss, Valid Accuracy, Valid Loss]
# Index: []

# %% [markdown]
# ## Google Colab Setup
# Next we need to run a few commands to set up our environment on Google Colab. If you are running this notebook on a local machine you can skip this section.
#
# Run the following cell to mount your Google Drive. Follow the link, sign in to your Google account (the same account you used to store this notebook!) and copy the authorization code into the text box that appears below.

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# fill in the path in your Google Drive in the string below. Note: do not escape slashes or spaces
# import os
# datadir = "C:/Users/eddie/GitHub/Deep-Learning/PyTorch/Class/pytorch104"
# if not os.path.exists(datadir):
#  !ln -s "/content/drive/My Drive/Your/A4/path/" $datadir # TODO: Fill your A3 path
# os.chdir(datadir)
# !pwd

# %% [markdown]
# # Data Setup (5 points)
#
# The first thing to do is implement a dataset class to load rotated CIFAR10 images with matching labels. Since there is already a CIFAR10 dataset class implemented in `torchvision`, we will extend this class and modify the `__get_item__` method appropriately to load rotated images.
#
# Each rotation label should be an integer in the set {0, 1, 2, 3} which correspond to rotations of 0, 90, 180, or 270 degrees respectively.

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import random


def rotate_img(img, rot):
    if rot == 0: # 0 degrees rotation
        return img
    #######################################################################
    #        TODO: Implement rotate_img() - return the rotated img        #                           
    #######################################################################
    angles = {0: 0, 1: 90, 2: 180, 3: 270}
    if rot in angles:
        return transforms.functional.rotate(img, angles[rot])
    else:
        raise ValueError('rotation should be 0, 90, 180, or 270 degrees')

    #######################################################################
    #                           End of your code                          #
    #######################################################################

class CIFAR10Rotation(torchvision.datasets.CIFAR10):

    def __init__(self, root, train, download, transform) -> None:
        super().__init__(root=root, train=train, download=download, transform=transform)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index: int):
        image, cls_label = super().__getitem__(index)

        # randomly select image rotation
        rotation_label = random.choice([0, 1, 2, 3])
        image_rotated = rotate_img(image, rotation_label)

        rotation_label = torch.tensor(rotation_label).long()
        return image, image_rotated, rotation_label, torch.tensor(cls_label).long()

# %%
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

batch_size = 128

trainset = CIFAR10Rotation(root='data', train=True,
                                        download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=0)

testset = CIFAR10Rotation(root='data', train=False,
                                       download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=0)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# Show some example images and rotated images with labels:

# %%
import matplotlib.pyplot as plt

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

rot_classes = ('0', '90', '180', '270')


def imshow(img):
    # unnormalize
    img = transforms.Normalize((0, 0, 0), (1/0.2023, 1/0.1994, 1/0.2010))(img)
    img = transforms.Normalize((-0.4914, -0.4822, -0.4465), (1, 1, 1))(img)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


dataiter = iter(trainloader)
images, rot_images, rot_labels, labels = next(dataiter)

# print images and rotated images
img_grid = imshow(torchvision.utils.make_grid(images[:4], padding=0))
print('Class labels: ', ' '.join(f'{classes[labels[j]]:5s}' for j in range(4)))
img_grid = imshow(torchvision.utils.make_grid(rot_images[:4], padding=0))
print('Rotation labels: ', ' '.join(f'{rot_classes[rot_labels[j]]:5s}' for j in range(4)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Class labels:  frog  cat   frog  deer
# Rotation labels:  270   0     180   270

# %% [markdown]
# # Evaluation code

# %%
import time

def run_test(net, testloader, criterion, task):
    correct = 0
    total = 0
    avg_test_loss = 0.0
    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for images, images_rotated, labels, cls_labels in testloader:
            if task == 'rotation':
              images, labels = images_rotated.to(device), labels.to(device)
            elif task == 'classification':
              images, labels = images.to(device), cls_labels.to(device)
            #######################################################################
            # TODO: Calculate outputs by running images through the network       #
            # The class with the highest energy is what we choose as prediction   #
            #######################################################################
            # Calculate outputs by running images through the network
            outputs = net(images)

            # The class with the highest score is what we choose as our prediction
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            #######################################################################
            #                           End of your code                          #
            #######################################################################
            avg_test_loss += criterion(outputs, labels)  / len(testloader)
    print('TESTING:')
    print(f'Accuracy of the network on the 10000 test images: {100 * correct / total:.2f} %')
    print(f'Average loss on the 10000 test images: {avg_test_loss:.3f}')

    return avg_test_loss, 100 * correct / total

# %%
def adjust_learning_rate(optimizer, epoch, init_lr, decay_epochs=30):
    """Sets the learning rate to the initial LR decayed by 10 every 30 epochs"""
    lr = init_lr * (0.1 ** (epoch // decay_epochs))
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %% [markdown]
# # Train a ResNet18 on the rotation task (9 points)
#
# In this section, we will train a ResNet18 model **from scratch** on the rotation task. The input is a rotated image and the model predicts the rotation label. See the Data Setup section for details.

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %% [markdown]
# ### Notice: You should not use pretrained weights from ImageNet.

# %%
import torch.nn as nn
import torch.nn.functional as F

from torchvision.models import resnet18

net = resnet18(weights = None, num_classes=4) # Do not modify this line.
net = net.to(device)

# %%
import torch.nn as nn
import torch.optim as optim
################################################################################
# TODO: Define loss and optmizer functions                                     #
# Try any loss or optimizer function and learning rate to get better result    #
# hint: torch.nn and torch.optim                                               #
################################################################################
# Loss and optimizer
criterion = nn.CrossEntropyLoss(label_smoothing=label_smoothing)
learning_rate = 0.001
optimizer = optim.Adam(net.parameters(), lr=learning_rate)
################################################################################
#                               End of your code                               #
################################################################################
criterion = criterion.to(device)

# %%
# Both the self-supervised rotation task and supervised CIFAR10 classification are
# trained with the CrossEntropyLoss, so we can use the training loop code.

def train(net, criterion, optimizer, num_epochs, decay_epochs, init_lr, task, experiment_type=None):
    global experience_report
    for epoch in range(num_epochs):  # loop over the dataset multiple times
        # Initialize epoch variables
        total_loss = 0.0
        total_correct = 0.0
        total_samples = 0.0

        running_loss = 0.0
        running_correct = 0.0
        running_total = 0.0
        start_time = time.time()

        net.train()

        for i, (imgs, imgs_rotated, rotation_label, cls_label) in enumerate(trainloader, 0):
            adjust_learning_rate(optimizer, epoch, init_lr, decay_epochs)
            ######################################################################################################
            # TODO: Set the data to the correct device; Different task will use different inputs and labels      #  
            # TODO: Zero the parameter gradients                                                                 #
            # TODO: forward + backward + optimize                                                                #
            # TODO: Get predicted results                                                                        #
            ######################################################################################################
            # Set data to the correct device
            if task == 'rotation':
                inputs, labels = imgs_rotated.to(device), rotation_label.to(device)
            elif task == 'classification':
                inputs, labels = imgs.to(device), cls_label.to(device)

            optimizer.zero_grad()  # Zero the parameter gradients

            # Forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # Get predicted results for accuracy calculation
            _, predicted = torch.max(outputs.data, 1)
            ######################################################################################################
            #                               End of your code                                                     #
            ######################################################################################################

            # print statistics
            print_freq = 100
            running_loss += loss.item()

            # calc acc
            running_total += labels.size(0)
            running_correct += (predicted == labels).sum().item()

            # Update total counts for epoch averages
            total_loss += loss.item()
            total_samples += labels.size(0)
            total_correct += (predicted == labels).sum().item()

            if i % print_freq == (print_freq - 1):    # print every 2000 mini-batches
                print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / print_freq:.3f} acc: {100*running_correct / running_total:.2f} time: {time.time() - start_time:.2f}')
                running_loss, running_correct, running_total = 0.0, 0.0, 0.0
                start_time = time.time()
        ######################################################################################################
        # TODO: Run the run_test() function after each epoch; Set the model to the evaluation mode.          #
        ######################################################################################################
        # Calculate average training loss and accuracy for the epoch
        avg_train_loss = total_loss / len(trainloader)
        avg_train_acc = 100 * total_correct / total_samples

        # Evaluate the model after each epoch
        net.eval()
        test_loss, test_acc = run_test(net, testloader, criterion, task)

        # Append the epoch's results to the report DataFrame
        if experience_report is not None and experiment_type is not None:
            new_row = pd.DataFrame({
                'Experiment Type': [experiment_type],
                'Epoch': [epoch + 1],
                'Train Accuracy': [avg_train_acc.cpu().numpy()] if torch.is_tensor(avg_train_acc) else [avg_train_acc],
                'Train Loss': [avg_train_loss.cpu().numpy()] if torch.is_tensor(avg_train_loss) else [avg_train_loss],
                'Valid Accuracy': [test_acc.cpu().numpy()] if torch.is_tensor(test_acc) else [test_acc],
                'Valid Loss': [test_loss.cpu().numpy()] if torch.is_tensor(test_loss) else [test_loss]
            })
            experience_report = pd.concat([experience_report, new_row], ignore_index=True)
        ######################################################################################################
        #                               End of your code                                                     #
        ######################################################################################################

    # Save the report DataFrame after the experiment
    if experience_report is not None and experiment_type is not None:
        experience_report.to_csv(f'{experience_name}.csv', index=False)

    print('Finished Training')

# %%
from datetime import datetime

train(net, criterion, optimizer, num_epochs=45, decay_epochs=15, init_lr=0.01, task='rotation', experiment_type='Self-Supervise Rotation Model')
################################
#     TODO: Save the model     #  
################################
# Get current date and time
# Save the model
model_path = f"{experience_name}.pth"
torch.save(net.state_dict(), model_path)
################################
#      End of your code        #  
################################
# Out:
# [1,   100] loss: 1.506 acc: 34.73 time: 58.64
# [1,   200] loss: 1.332 acc: 44.62 time: 7.99
# [1,   300] loss: 1.284 acc: 47.43 time: 7.06
# TESTING:
# Accuracy of the network on the 10000 test images: 51.18 %
# Average loss on the 10000 test images: 1.405
# [2,   100] loss: 1.232 acc: 50.92 time: 6.89
# [2,   200] loss: 1.227 acc: 50.61 time: 7.39
# [2,   300] loss: 1.208 acc: 52.36 time: 12.03
# TESTING:
# Accuracy of the network on the 10000 test images: 54.32 %
# Average loss on the 10000 test images: 1.192
# [3,   100] loss: 1.190 acc: 54.35 time: 16.44
# [3,   200] loss: 1.181 acc: 54.79 time: 12.76
# [3,   300] loss: 1.169 acc: 55.76 time: 20.56
# TESTING:
# Accuracy of the network on the 10000 test images: 56.25 %
# Average loss on the 10000 test images: 1.173
# [4,   100] loss: 1.155 acc: 57.02 time: 12.89
# [4,   200] loss: 1.147 acc: 57.98 time: 6.63
# [4,   300] loss: 1.148 acc: 57.35 time: 6.67
# TESTING:
# Accuracy of the network on the 10000 test images: 58.20 %
# Average loss on the 10000 test images: 1.142
# [5,   100] loss: 1.137 acc: 58.51 time: 6.58
# [5,   200] loss: 1.125 acc: 59.48 time: 6.60
# [5,   300] loss: 1.122 acc: 60.05 time: 6.99
# TESTING:
# Accuracy of the network on the 10000 test images: 61.85 %
# Average loss on the 10000 test images: 1.097
# [6,   100] loss: 1.121 acc: 59.73 time: 6.81
# [6,   200] loss: 1.097 acc: 62.25 time: 7.12
# [6,   300] loss: 1.106 acc: 61.59 time: 7.26
# TESTING:
# Accuracy of the network on the 10000 test images: 62.43 %
# Average loss on the 10000 test images: 1.097
# [7,   100] loss: 1.093 acc: 62.79 time: 6.93
# [7,   200] loss: 1.090 acc: 62.99 time: 7.70
# [7,   300] loss: 1.094 acc: 62.23 time: 7.59
# TESTING:
# Accuracy of the network on the 10000 test images: 61.37 %
# Average loss on the 10000 test images: 1.099
# [8,   100] loss: 1.080 acc: 63.80 time: 6.48
# [8,   200] loss: 1.079 acc: 64.08 time: 6.73
# [8,   300] loss: 1.076 acc: 63.88 time: 6.99
# TESTING:
# Accuracy of the network on the 10000 test images: 64.89 %
# Average loss on the 10000 test images: 1.060
# [9,   100] loss: 1.066 acc: 64.91 time: 6.73
# [9,   200] loss: 1.071 acc: 64.37 time: 8.08
# [9,   300] loss: 1.062 acc: 64.81 time: 7.48
# TESTING:
# Accuracy of the network on the 10000 test images: 64.42 %
# Average loss on the 10000 test images: 1.073
# [10,   100] loss: 1.055 acc: 65.26 time: 6.92
# [10,   200] loss: 1.054 acc: 65.52 time: 6.68
# [10,   300] loss: 1.055 acc: 65.73 time: 7.22
# TESTING:
# Accuracy of the network on the 10000 test images: 67.10 %
# Average loss on the 10000 test images: 1.032
# [11,   100] loss: 1.046 acc: 66.14 time: 7.16
# [11,   200] loss: 1.037 acc: 67.41 time: 6.52
# [11,   300] loss: 1.043 acc: 66.57 time: 6.54
# TESTING:
# Accuracy of the network on the 10000 test images: 67.45 %
# Average loss on the 10000 test images: 1.034
# [12,   100] loss: 1.026 acc: 67.95 time: 6.86
# [12,   200] loss: 1.038 acc: 67.44 time: 6.54
# [12,   300] loss: 1.026 acc: 67.70 time: 7.18
# TESTING:
# Accuracy of the network on the 10000 test images: 68.57 %
# Average loss on the 10000 test images: 1.018
# [13,   100] loss: 1.031 acc: 67.41 time: 7.52
# [13,   200] loss: 1.020 acc: 68.49 time: 6.87
# [13,   300] loss: 1.025 acc: 68.19 time: 7.56
# TESTING:
# Accuracy of the network on the 10000 test images: 70.71 %
# Average loss on the 10000 test images: 0.990
# [14,   100] loss: 1.010 acc: 69.75 time: 6.71
# [14,   200] loss: 1.009 acc: 69.32 time: 7.44
# [14,   300] loss: 1.016 acc: 69.16 time: 6.59
# TESTING:
# Accuracy of the network on the 10000 test images: 71.38 %
# Average loss on the 10000 test images: 0.986
# [15,   100] loss: 1.006 acc: 69.71 time: 7.00
# [15,   200] loss: 1.003 acc: 69.83 time: 6.57
# [15,   300] loss: 0.993 acc: 70.52 time: 7.60
# TESTING:
# Accuracy of the network on the 10000 test images: 71.63 %
# Average loss on the 10000 test images: 0.982
# [16,   100] loss: 0.984 acc: 71.54 time: 6.83
# [16,   200] loss: 0.956 acc: 73.62 time: 6.68
# [16,   300] loss: 0.956 acc: 73.95 time: 6.65
# TESTING:
# Accuracy of the network on the 10000 test images: 74.65 %
# Average loss on the 10000 test images: 0.938
# [17,   100] loss: 0.953 acc: 73.66 time: 6.96
# [17,   200] loss: 0.949 acc: 74.12 time: 6.86
# [17,   300] loss: 0.955 acc: 73.76 time: 6.78
# TESTING:
# Accuracy of the network on the 10000 test images: 75.57 %
# Average loss on the 10000 test images: 0.927
# [18,   100] loss: 0.946 acc: 74.23 time: 7.66
# [18,   200] loss: 0.948 acc: 74.30 time: 7.77
# [18,   300] loss: 0.937 acc: 75.02 time: 7.10
# TESTING:
# Accuracy of the network on the 10000 test images: 75.66 %
# Average loss on the 10000 test images: 0.927
# [19,   100] loss: 0.939 acc: 75.12 time: 7.03
# [19,   200] loss: 0.940 acc: 74.76 time: 7.41
# [19,   300] loss: 0.936 acc: 75.11 time: 7.61
# TESTING:
# Accuracy of the network on the 10000 test images: 76.33 %
# Average loss on the 10000 test images: 0.921
# [20,   100] loss: 0.937 acc: 74.97 time: 7.35
# [20,   200] loss: 0.933 acc: 75.36 time: 6.96
# [20,   300] loss: 0.934 acc: 75.33 time: 7.09
# TESTING:
# Accuracy of the network on the 10000 test images: 76.20 %
# Average loss on the 10000 test images: 0.920
# [21,   100] loss: 0.929 acc: 75.76 time: 7.27
# [21,   200] loss: 0.931 acc: 75.62 time: 7.33
# [21,   300] loss: 0.937 acc: 75.07 time: 6.97
# TESTING:
# Accuracy of the network on the 10000 test images: 76.76 %
# Average loss on the 10000 test images: 0.911
# [22,   100] loss: 0.922 acc: 76.41 time: 7.27
# [22,   200] loss: 0.917 acc: 76.27 time: 6.95
# [22,   300] loss: 0.933 acc: 74.98 time: 6.57
# TESTING:
# Accuracy of the network on the 10000 test images: 75.60 %
# Average loss on the 10000 test images: 0.920
# [23,   100] loss: 0.930 acc: 75.91 time: 7.13
# [23,   200] loss: 0.922 acc: 76.20 time: 7.04
# [23,   300] loss: 0.922 acc: 76.22 time: 7.66
# TESTING:
# Accuracy of the network on the 10000 test images: 76.68 %
# Average loss on the 10000 test images: 0.910
# [24,   100] loss: 0.928 acc: 76.14 time: 7.75
# [24,   200] loss: 0.918 acc: 76.41 time: 7.04
# [24,   300] loss: 0.922 acc: 76.09 time: 7.19
# TESTING:
# Accuracy of the network on the 10000 test images: 76.83 %
# Average loss on the 10000 test images: 0.909
# [25,   100] loss: 0.917 acc: 76.71 time: 6.92
# [25,   200] loss: 0.912 acc: 77.05 time: 6.72
# [25,   300] loss: 0.918 acc: 76.65 time: 7.31
# TESTING:
# Accuracy of the network on the 10000 test images: 77.32 %
# Average loss on the 10000 test images: 0.909
# [26,   100] loss: 0.911 acc: 77.07 time: 6.95
# [26,   200] loss: 0.921 acc: 76.21 time: 6.68
# [26,   300] loss: 0.913 acc: 76.78 time: 6.63
# TESTING:
# Accuracy of the network on the 10000 test images: 77.11 %
# Average loss on the 10000 test images: 0.905
# [27,   100] loss: 0.917 acc: 76.80 time: 7.06
# [27,   200] loss: 0.915 acc: 76.72 time: 7.61
# [27,   300] loss: 0.911 acc: 76.83 time: 7.14
# TESTING:
# Accuracy of the network on the 10000 test images: 77.55 %
# Average loss on the 10000 test images: 0.903
# [28,   100] loss: 0.906 acc: 77.23 time: 7.31
# [28,   200] loss: 0.907 acc: 76.97 time: 7.36
# [28,   300] loss: 0.909 acc: 77.21 time: 8.27
# TESTING:
# Accuracy of the network on the 10000 test images: 77.68 %
# Average loss on the 10000 test images: 0.901
# [29,   100] loss: 0.909 acc: 76.97 time: 6.90
# [29,   200] loss: 0.907 acc: 77.41 time: 7.49
# [29,   300] loss: 0.907 acc: 77.43 time: 7.63
# TESTING:
# Accuracy of the network on the 10000 test images: 78.12 %
# Average loss on the 10000 test images: 0.897
# [30,   100] loss: 0.902 acc: 77.87 time: 6.99
# [30,   200] loss: 0.901 acc: 77.98 time: 7.38
# [30,   300] loss: 0.915 acc: 76.70 time: 7.76
# TESTING:
# Accuracy of the network on the 10000 test images: 78.14 %
# Average loss on the 10000 test images: 0.894
# [31,   100] loss: 0.899 acc: 77.88 time: 7.28
# [31,   200] loss: 0.895 acc: 78.25 time: 7.74
# [31,   300] loss: 0.893 acc: 78.02 time: 6.92
# TESTING:
# Accuracy of the network on the 10000 test images: 78.61 %
# Average loss on the 10000 test images: 0.891
# [32,   100] loss: 0.898 acc: 77.98 time: 7.33
# [32,   200] loss: 0.897 acc: 77.98 time: 6.77
# [32,   300] loss: 0.898 acc: 78.24 time: 6.90
# TESTING:
# Accuracy of the network on the 10000 test images: 78.57 %
# Average loss on the 10000 test images: 0.891
# [33,   100] loss: 0.894 acc: 78.02 time: 6.75
# [33,   200] loss: 0.891 acc: 78.20 time: 6.79
# [33,   300] loss: 0.897 acc: 77.64 time: 7.38
# TESTING:
# Accuracy of the network on the 10000 test images: 78.33 %
# Average loss on the 10000 test images: 0.889
# [34,   100] loss: 0.885 acc: 78.91 time: 7.82
# [34,   200] loss: 0.898 acc: 78.20 time: 6.77
# [34,   300] loss: 0.898 acc: 77.48 time: 7.41
# TESTING:
# Accuracy of the network on the 10000 test images: 78.30 %
# Average loss on the 10000 test images: 0.892
# [35,   100] loss: 0.894 acc: 78.12 time: 7.74
# [35,   200] loss: 0.898 acc: 77.78 time: 6.96
# [35,   300] loss: 0.894 acc: 78.07 time: 6.89
# TESTING:
# Accuracy of the network on the 10000 test images: 78.37 %
# Average loss on the 10000 test images: 0.890
# [36,   100] loss: 0.896 acc: 78.21 time: 7.28
# [36,   200] loss: 0.898 acc: 77.99 time: 6.90
# [36,   300] loss: 0.896 acc: 78.06 time: 7.07
# TESTING:
# Accuracy of the network on the 10000 test images: 78.16 %
# Average loss on the 10000 test images: 0.891
# [37,   100] loss: 0.893 acc: 78.51 time: 7.98
# [37,   200] loss: 0.892 acc: 78.51 time: 6.84
# [37,   300] loss: 0.895 acc: 78.35 time: 6.81
# TESTING:
# Accuracy of the network on the 10000 test images: 78.55 %
# Average loss on the 10000 test images: 0.888
# [38,   100] loss: 0.890 acc: 78.63 time: 6.83
# [38,   200] loss: 0.889 acc: 78.74 time: 6.60
# [38,   300] loss: 0.892 acc: 78.25 time: 7.03
# TESTING:
# Accuracy of the network on the 10000 test images: 78.70 %
# Average loss on the 10000 test images: 0.888
# [39,   100] loss: 0.888 acc: 78.85 time: 7.13
# [39,   200] loss: 0.892 acc: 78.27 time: 7.06
# [39,   300] loss: 0.891 acc: 78.48 time: 7.13
# TESTING:
# Accuracy of the network on the 10000 test images: 78.46 %
# Average loss on the 10000 test images: 0.888
# [40,   100] loss: 0.887 acc: 78.80 time: 7.41
# [40,   200] loss: 0.892 acc: 78.37 time: 6.95
# [40,   300] loss: 0.892 acc: 78.30 time: 8.00
# TESTING:
# Accuracy of the network on the 10000 test images: 78.40 %
# Average loss on the 10000 test images: 0.890
# [41,   100] loss: 0.899 acc: 77.74 time: 7.67
# [41,   200] loss: 0.887 acc: 78.72 time: 7.83
# [41,   300] loss: 0.890 acc: 78.45 time: 7.46
# TESTING:
# Accuracy of the network on the 10000 test images: 78.29 %
# Average loss on the 10000 test images: 0.888
# [42,   100] loss: 0.896 acc: 77.90 time: 7.85
# [42,   200] loss: 0.888 acc: 78.68 time: 7.07
# [42,   300] loss: 0.890 acc: 78.80 time: 7.41
# TESTING:
# Accuracy of the network on the 10000 test images: 78.72 %
# Average loss on the 10000 test images: 0.885
# [43,   100] loss: 0.894 acc: 78.07 time: 7.95
# [43,   200] loss: 0.891 acc: 78.41 time: 7.15
# [43,   300] loss: 0.893 acc: 78.35 time: 6.93
# TESTING:
# Accuracy of the network on the 10000 test images: 78.65 %
# Average loss on the 10000 test images: 0.886
# [44,   100] loss: 0.888 acc: 78.58 time: 7.25
# [44,   200] loss: 0.896 acc: 77.90 time: 7.51
# [44,   300] loss: 0.888 acc: 78.94 time: 6.75
# TESTING:
# Accuracy of the network on the 10000 test images: 78.05 %
# Average loss on the 10000 test images: 0.890
# [45,   100] loss: 0.891 acc: 78.46 time: 6.71
# [45,   200] loss: 0.896 acc: 78.12 time: 7.97
# [45,   300] loss: 0.887 acc: 78.67 time: 7.15
# TESTING:
# Accuracy of the network on the 10000 test images: 78.82 %
# Average loss on the 10000 test images: 0.883
# Finished Training

# %% [markdown]
# ## Fine-tuning on the pre-trained model (9 points)
#
# In this section, we will load the ResNet18 model pre-trained on the rotation task and fine-tune on the classification task. We will freeze all previous layers except for the 'layer4' block and 'fc' layer.
#
# **Then we will use the trained model from rotation task as the pretrained weights. Notice, you should not use the pretrained weights from ImageNet.**

# %%
import torch.nn as nn
import torch.nn.functional as F

from torchvision.models import resnet18

#####################################################
#     TODO: Load the pre-trained ResNet18 model     #  
#####################################################
# load the trained classifier weights
ckpt = torch.load(f"model_2023-11-02-23-22-09.pth")
net.load_state_dict(ckpt)
####################################################
#                End of your code                  #   
####################################################
# Out:
# <All keys matched successfully>

# %%
#################################################################################################
#   TODO: Freeze all previous layers; only keep the 'layer4' block and 'fc' layer trainable     #
#################################################################################################
# Freeze all parameters
net.requires_grad_(False)

# Adjusting the fully connected layer to have 10 outputs for 10 classes
net.fc = nn.Linear(net.fc.in_features, 10)  # Re-define the fc layer

# Unfreeze the last block (layer4) and the fully connected (fc) layer
net.layer4.requires_grad_(True)
net.fc.requires_grad_(True)

# Make sure to move the model to the device after modifying it
net.to(device)
#################################################################################################
#                                          End of your code                                     #
#################################################################################################
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
# Print all the trainable parameters
params_to_update = net.parameters()
print("Params to learn:")
params_to_update = []
for name,param in net.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name)
# Out:
# Params to learn:
# 	 layer4.0.conv1.weight
# 	 layer4.0.bn1.weight
# 	 layer4.0.bn1.bias
# 	 layer4.0.conv2.weight
# 	 layer4.0.bn2.weight
# 	 layer4.0.bn2.bias
# 	 layer4.0.downsample.0.weight
# 	 layer4.0.downsample.1.weight
# 	 layer4.0.downsample.1.bias
# 	 layer4.1.conv1.weight
# 	 layer4.1.bn1.weight
# 	 layer4.1.bn1.bias
# 	 layer4.1.conv2.weight
# 	 layer4.1.bn2.weight
# 	 layer4.1.bn2.bias
# 	 fc.weight
# 	 fc.bias

# %%
# TODO: Define criterion and optimizer
# Note that your optimizer only needs to update the parameters that are trainable.
criterion = nn.CrossEntropyLoss(label_smoothing=label_smoothing)

# Optimizer: Update only the parameters of layer4 and fc
optimizer = optim.Adam([
    {'params': net.layer4.parameters()},
    {'params': net.fc.parameters()}
], lr=0.001)

criterion.to(device)
# Out:
# CrossEntropyLoss()

# %%
train(net, criterion, optimizer, num_epochs=50, decay_epochs=10, init_lr=0.01, task='classification', experiment_type='Fine-tuning Pre-trained Model')
# Out:
# [1,   100] loss: 2.026 acc: 30.76 time: 6.87
# [1,   200] loss: 1.854 acc: 42.83 time: 6.53
# [1,   300] loss: 1.808 acc: 45.26 time: 6.66
# TESTING:
# Accuracy of the network on the 10000 test images: 47.87 %
# Average loss on the 10000 test images: 1.764
# [2,   100] loss: 1.765 acc: 47.68 time: 6.51
# [2,   200] loss: 1.752 acc: 48.88 time: 6.27
# [2,   300] loss: 1.743 acc: 49.51 time: 6.24
# TESTING:
# Accuracy of the network on the 10000 test images: 53.22 %
# Average loss on the 10000 test images: 1.684
# [3,   100] loss: 1.730 acc: 50.23 time: 6.62
# [3,   200] loss: 1.725 acc: 50.34 time: 6.12
# [3,   300] loss: 1.719 acc: 50.59 time: 6.38
# TESTING:
# Accuracy of the network on the 10000 test images: 54.28 %
# Average loss on the 10000 test images: 1.666
# [4,   100] loss: 1.709 acc: 51.56 time: 6.08
# [4,   200] loss: 1.709 acc: 51.57 time: 6.38
# [4,   300] loss: 1.708 acc: 51.73 time: 6.53
# TESTING:
# Accuracy of the network on the 10000 test images: 53.48 %
# Average loss on the 10000 test images: 1.683
# [5,   100] loss: 1.694 acc: 51.98 time: 6.20
# [5,   200] loss: 1.701 acc: 52.60 time: 6.23
# [5,   300] loss: 1.690 acc: 52.74 time: 6.24
# TESTING:
# Accuracy of the network on the 10000 test images: 55.30 %
# Average loss on the 10000 test images: 1.657
# [6,   100] loss: 1.684 acc: 53.14 time: 6.13
# [6,   200] loss: 1.689 acc: 52.42 time: 6.24
# [6,   300] loss: 1.691 acc: 52.56 time: 6.35
# TESTING:
# Accuracy of the network on the 10000 test images: 55.37 %
# Average loss on the 10000 test images: 1.641
# [7,   100] loss: 1.680 acc: 53.61 time: 6.07
# [7,   200] loss: 1.675 acc: 53.55 time: 6.09
# [7,   300] loss: 1.674 acc: 53.53 time: 6.01
# TESTING:
# Accuracy of the network on the 10000 test images: 55.45 %
# Average loss on the 10000 test images: 1.646
# [8,   100] loss: 1.668 acc: 54.01 time: 6.49
# [8,   200] loss: 1.671 acc: 53.59 time: 5.98
# [8,   300] loss: 1.676 acc: 53.39 time: 8.44
# TESTING:
# Accuracy of the network on the 10000 test images: 55.77 %
# Average loss on the 10000 test images: 1.639
# [9,   100] loss: 1.657 acc: 54.79 time: 11.94
# [9,   200] loss: 1.666 acc: 53.60 time: 8.97
# [9,   300] loss: 1.666 acc: 54.12 time: 6.54
# TESTING:
# Accuracy of the network on the 10000 test images: 55.73 %
# Average loss on the 10000 test images: 1.645
# [10,   100] loss: 1.661 acc: 54.21 time: 6.22
# [10,   200] loss: 1.658 acc: 54.66 time: 5.82
# [10,   300] loss: 1.653 acc: 55.27 time: 5.96
# TESTING:
# Accuracy of the network on the 10000 test images: 57.02 %
# Average loss on the 10000 test images: 1.612
# [11,   100] loss: 1.629 acc: 56.36 time: 5.98
# [11,   200] loss: 1.628 acc: 55.67 time: 6.34
# [11,   300] loss: 1.627 acc: 56.41 time: 6.22
# TESTING:
# Accuracy of the network on the 10000 test images: 58.46 %
# Average loss on the 10000 test images: 1.585
# [12,   100] loss: 1.617 acc: 56.88 time: 6.48
# [12,   200] loss: 1.610 acc: 57.08 time: 6.08
# [12,   300] loss: 1.612 acc: 57.09 time: 6.38
# TESTING:
# Accuracy of the network on the 10000 test images: 58.95 %
# Average loss on the 10000 test images: 1.579
# [13,   100] loss: 1.604 acc: 57.52 time: 6.16
# [13,   200] loss: 1.616 acc: 56.94 time: 5.87
# [13,   300] loss: 1.614 acc: 56.94 time: 5.85
# TESTING:
# Accuracy of the network on the 10000 test images: 59.19 %
# Average loss on the 10000 test images: 1.574
# [14,   100] loss: 1.613 acc: 57.12 time: 6.41
# [14,   200] loss: 1.610 acc: 57.07 time: 5.68
# [14,   300] loss: 1.600 acc: 57.80 time: 6.07
# TESTING:
# Accuracy of the network on the 10000 test images: 59.04 %
# Average loss on the 10000 test images: 1.577
# [15,   100] loss: 1.616 acc: 56.77 time: 12.48
# [15,   200] loss: 1.601 acc: 57.60 time: 10.42
# [15,   300] loss: 1.611 acc: 57.35 time: 7.37
# TESTING:
# Accuracy of the network on the 10000 test images: 59.08 %
# Average loss on the 10000 test images: 1.573
# [16,   100] loss: 1.607 acc: 57.45 time: 7.01
# [16,   200] loss: 1.604 acc: 57.70 time: 6.73
# [16,   300] loss: 1.606 acc: 57.70 time: 6.73
# TESTING:
# Accuracy of the network on the 10000 test images: 59.29 %
# Average loss on the 10000 test images: 1.572
# [17,   100] loss: 1.613 acc: 56.68 time: 8.72
# [17,   200] loss: 1.611 acc: 57.36 time: 7.53
# [17,   300] loss: 1.594 acc: 57.99 time: 6.56
# TESTING:
# Accuracy of the network on the 10000 test images: 59.27 %
# Average loss on the 10000 test images: 1.569
# [18,   100] loss: 1.609 acc: 57.54 time: 6.60
# [18,   200] loss: 1.609 acc: 57.11 time: 6.51
# [18,   300] loss: 1.601 acc: 57.44 time: 6.60
# TESTING:
# Accuracy of the network on the 10000 test images: 59.57 %
# Average loss on the 10000 test images: 1.571
# [19,   100] loss: 1.604 acc: 57.78 time: 6.28
# [19,   200] loss: 1.602 acc: 57.59 time: 5.96
# [19,   300] loss: 1.606 acc: 57.58 time: 5.86
# TESTING:
# Accuracy of the network on the 10000 test images: 59.66 %
# Average loss on the 10000 test images: 1.567
# [20,   100] loss: 1.599 acc: 58.11 time: 6.09
# [20,   200] loss: 1.602 acc: 57.51 time: 6.17
# [20,   300] loss: 1.597 acc: 57.72 time: 6.16
# TESTING:
# Accuracy of the network on the 10000 test images: 59.72 %
# Average loss on the 10000 test images: 1.571
# [21,   100] loss: 1.596 acc: 58.07 time: 6.10
# [21,   200] loss: 1.601 acc: 57.99 time: 5.83
# [21,   300] loss: 1.597 acc: 57.71 time: 6.04
# TESTING:
# Accuracy of the network on the 10000 test images: 59.73 %
# Average loss on the 10000 test images: 1.568
# [22,   100] loss: 1.597 acc: 57.65 time: 6.40
# [22,   200] loss: 1.599 acc: 57.70 time: 6.02
# [22,   300] loss: 1.591 acc: 58.82 time: 6.01
# TESTING:
# Accuracy of the network on the 10000 test images: 59.80 %
# Average loss on the 10000 test images: 1.565
# [23,   100] loss: 1.592 acc: 58.07 time: 5.82
# [23,   200] loss: 1.597 acc: 57.83 time: 6.02
# [23,   300] loss: 1.595 acc: 58.05 time: 5.85
# TESTING:
# Accuracy of the network on the 10000 test images: 59.56 %
# Average loss on the 10000 test images: 1.566
# [24,   100] loss: 1.592 acc: 58.22 time: 6.50
# [24,   200] loss: 1.600 acc: 57.66 time: 6.05
# [24,   300] loss: 1.589 acc: 58.51 time: 6.21
# TESTING:
# Accuracy of the network on the 10000 test images: 59.99 %
# Average loss on the 10000 test images: 1.563
# [25,   100] loss: 1.593 acc: 57.99 time: 5.84
# [25,   200] loss: 1.592 acc: 58.19 time: 6.70
# [25,   300] loss: 1.588 acc: 58.33 time: 6.32
# TESTING:
# Accuracy of the network on the 10000 test images: 59.74 %
# Average loss on the 10000 test images: 1.564
# [26,   100] loss: 1.588 acc: 58.35 time: 6.20
# [26,   200] loss: 1.595 acc: 58.17 time: 7.05
# [26,   300] loss: 1.605 acc: 57.77 time: 6.51
# TESTING:
# Accuracy of the network on the 10000 test images: 59.79 %
# Average loss on the 10000 test images: 1.563
# [27,   100] loss: 1.583 acc: 58.51 time: 6.22
# [27,   200] loss: 1.597 acc: 57.92 time: 6.20
# [27,   300] loss: 1.595 acc: 57.98 time: 5.96
# TESTING:
# Accuracy of the network on the 10000 test images: 59.62 %
# Average loss on the 10000 test images: 1.567
# [28,   100] loss: 1.594 acc: 58.23 time: 6.23
# [28,   200] loss: 1.594 acc: 57.94 time: 6.20
# [28,   300] loss: 1.585 acc: 58.71 time: 5.94
# TESTING:
# Accuracy of the network on the 10000 test images: 59.67 %
# Average loss on the 10000 test images: 1.565
# [29,   100] loss: 1.599 acc: 58.12 time: 6.07
# [29,   200] loss: 1.591 acc: 58.02 time: 6.02
# [29,   300] loss: 1.590 acc: 57.82 time: 5.92
# TESTING:
# Accuracy of the network on the 10000 test images: 59.80 %
# Average loss on the 10000 test images: 1.565
# [30,   100] loss: 1.588 acc: 58.52 time: 6.24
# [30,   200] loss: 1.589 acc: 58.35 time: 6.17
# [30,   300] loss: 1.595 acc: 57.43 time: 6.16
# TESTING:
# Accuracy of the network on the 10000 test images: 59.52 %
# Average loss on the 10000 test images: 1.568
# [31,   100] loss: 1.591 acc: 58.19 time: 6.46
# [31,   200] loss: 1.597 acc: 58.14 time: 6.33
# [31,   300] loss: 1.582 acc: 58.80 time: 5.97
# TESTING:
# Accuracy of the network on the 10000 test images: 59.49 %
# Average loss on the 10000 test images: 1.566
# [32,   100] loss: 1.596 acc: 57.96 time: 5.99
# [32,   200] loss: 1.593 acc: 58.13 time: 6.18
# [32,   300] loss: 1.586 acc: 58.22 time: 6.27
# TESTING:
# Accuracy of the network on the 10000 test images: 59.67 %
# Average loss on the 10000 test images: 1.566
# [33,   100] loss: 1.591 acc: 58.93 time: 6.47
# [33,   200] loss: 1.595 acc: 57.41 time: 5.81
# [33,   300] loss: 1.593 acc: 58.25 time: 5.99
# TESTING:
# Accuracy of the network on the 10000 test images: 59.89 %
# Average loss on the 10000 test images: 1.565
# [34,   100] loss: 1.581 acc: 59.05 time: 5.97
# [34,   200] loss: 1.588 acc: 59.15 time: 6.22
# [34,   300] loss: 1.595 acc: 57.81 time: 6.28
# TESTING:
# Accuracy of the network on the 10000 test images: 59.90 %
# Average loss on the 10000 test images: 1.563
# [35,   100] loss: 1.595 acc: 57.97 time: 6.29
# [35,   200] loss: 1.600 acc: 57.49 time: 6.15
# [35,   300] loss: 1.594 acc: 57.88 time: 6.10
# TESTING:
# Accuracy of the network on the 10000 test images: 59.70 %
# Average loss on the 10000 test images: 1.565
# [36,   100] loss: 1.599 acc: 57.35 time: 6.04
# [36,   200] loss: 1.593 acc: 58.41 time: 6.18
# [36,   300] loss: 1.592 acc: 58.63 time: 6.42
# TESTING:
# Accuracy of the network on the 10000 test images: 59.72 %
# Average loss on the 10000 test images: 1.563
# [37,   100] loss: 1.592 acc: 58.16 time: 6.17
# [37,   200] loss: 1.596 acc: 58.30 time: 6.23
# [37,   300] loss: 1.585 acc: 58.45 time: 5.97
# TESTING:
# Accuracy of the network on the 10000 test images: 59.69 %
# Average loss on the 10000 test images: 1.564
# [38,   100] loss: 1.595 acc: 58.09 time: 5.93
# [38,   200] loss: 1.587 acc: 58.35 time: 5.96
# [38,   300] loss: 1.590 acc: 58.33 time: 6.14
# TESTING:
# Accuracy of the network on the 10000 test images: 59.77 %
# Average loss on the 10000 test images: 1.564
# [39,   100] loss: 1.592 acc: 58.09 time: 6.36
# [39,   200] loss: 1.590 acc: 58.87 time: 5.81
# [39,   300] loss: 1.606 acc: 57.10 time: 6.19
# TESTING:
# Accuracy of the network on the 10000 test images: 60.08 %
# Average loss on the 10000 test images: 1.563
# [40,   100] loss: 1.593 acc: 57.87 time: 6.23
# [40,   200] loss: 1.591 acc: 58.05 time: 6.10
# [40,   300] loss: 1.592 acc: 58.48 time: 6.08
# TESTING:
# Accuracy of the network on the 10000 test images: 59.94 %
# Average loss on the 10000 test images: 1.563
# [41,   100] loss: 1.589 acc: 58.16 time: 6.19
# [41,   200] loss: 1.600 acc: 57.77 time: 5.71
# [41,   300] loss: 1.587 acc: 58.31 time: 5.94
# TESTING:
# Accuracy of the network on the 10000 test images: 60.01 %
# Average loss on the 10000 test images: 1.564
# [42,   100] loss: 1.589 acc: 58.61 time: 6.12
# [42,   200] loss: 1.589 acc: 58.77 time: 5.91
# [42,   300] loss: 1.583 acc: 58.88 time: 6.13
# TESTING:
# Accuracy of the network on the 10000 test images: 59.78 %
# Average loss on the 10000 test images: 1.564
# [43,   100] loss: 1.598 acc: 58.11 time: 5.80
# [43,   200] loss: 1.597 acc: 57.79 time: 5.90
# [43,   300] loss: 1.580 acc: 59.09 time: 6.17
# TESTING:
# Accuracy of the network on the 10000 test images: 59.88 %
# Average loss on the 10000 test images: 1.564
# [44,   100] loss: 1.598 acc: 58.01 time: 6.23
# [44,   200] loss: 1.584 acc: 58.95 time: 6.02
# [44,   300] loss: 1.593 acc: 58.23 time: 6.11
# TESTING:
# Accuracy of the network on the 10000 test images: 59.66 %
# Average loss on the 10000 test images: 1.566
# [45,   100] loss: 1.600 acc: 57.58 time: 6.38
# [45,   200] loss: 1.584 acc: 59.06 time: 5.75
# [45,   300] loss: 1.592 acc: 58.43 time: 6.09
# TESTING:
# Accuracy of the network on the 10000 test images: 59.77 %
# Average loss on the 10000 test images: 1.564
# [46,   100] loss: 1.586 acc: 58.32 time: 5.88
# [46,   200] loss: 1.598 acc: 57.76 time: 5.88
# [46,   300] loss: 1.594 acc: 58.07 time: 6.16
# TESTING:
# Accuracy of the network on the 10000 test images: 59.58 %
# Average loss on the 10000 test images: 1.565
# [47,   100] loss: 1.597 acc: 57.70 time: 6.50
# [47,   200] loss: 1.579 acc: 59.06 time: 6.57
# [47,   300] loss: 1.594 acc: 58.38 time: 6.03
# TESTING:
# Accuracy of the network on the 10000 test images: 59.83 %
# Average loss on the 10000 test images: 1.562
# [48,   100] loss: 1.594 acc: 57.95 time: 6.09
# [48,   200] loss: 1.590 acc: 58.18 time: 5.92
# [48,   300] loss: 1.597 acc: 57.78 time: 5.98
# TESTING:
# Accuracy of the network on the 10000 test images: 60.03 %
# Average loss on the 10000 test images: 1.564
# [49,   100] loss: 1.592 acc: 57.94 time: 6.06
# [49,   200] loss: 1.587 acc: 58.04 time: 6.18
# [49,   300] loss: 1.594 acc: 58.02 time: 6.13
# TESTING:
# Accuracy of the network on the 10000 test images: 59.95 %
# Average loss on the 10000 test images: 1.565
# [50,   100] loss: 1.589 acc: 58.15 time: 6.02
# [50,   200] loss: 1.593 acc: 57.88 time: 6.30
# [50,   300] loss: 1.589 acc: 58.27 time: 5.99
# TESTING:
# Accuracy of the network on the 10000 test images: 59.72 %
# Average loss on the 10000 test images: 1.566
# Finished Training

# %% [markdown]
# ## Fine-tuning on the randomly initialized model (9 points)
# In this section, we will randomly initialize a ResNet18 model and fine-tune on the classification task. We will freeze all previous layers except for the 'layer4' block and 'fc' layer.

# %%
import torch.nn as nn
import torch.nn.functional as F

from torchvision.models import resnet18
#################################################
# TODO: Randomly initialize a ResNet18 model    #
#################################################
# Randomly initialize a ResNet18 model
net = resnet18(pretrained=False)
#################################################
#              End of your code                 #
#################################################

# %%
#################################################################################################
# TODO: Freeze all previous layers; only keep the 'layer4' block and 'fc' layer trainable       #
# To do this, you should set requires_grad=False for the frozen layers.                         #
#################################################################################################
# Adjusting the fully connected layer for 10 classes
net.fc = nn.Linear(net.fc.in_features, 10)

# Freeze all layers in the randomly initialized model
net.requires_grad_(False)

# Unfreeze the last block (layer4) and the fully connected (fc) layer
net.layer4.requires_grad_(True)
net.fc.requires_grad_(True)

# Move the model to the device
net.to(device)
#################################################################################################
#                                          End of your code                                     #
#################################################################################################
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
# Print all the trainable parameters
params_to_update = net.parameters()
print("Params to learn:")
params_to_update = []
for name,param in net.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name)
# Out:
# Params to learn:
# 	 layer4.0.conv1.weight
# 	 layer4.0.bn1.weight
# 	 layer4.0.bn1.bias
# 	 layer4.0.conv2.weight
# 	 layer4.0.bn2.weight
# 	 layer4.0.bn2.bias
# 	 layer4.0.downsample.0.weight
# 	 layer4.0.downsample.1.weight
# 	 layer4.0.downsample.1.bias
# 	 layer4.1.conv1.weight
# 	 layer4.1.bn1.weight
# 	 layer4.1.bn1.bias
# 	 layer4.1.conv2.weight
# 	 layer4.1.bn2.weight
# 	 layer4.1.bn2.bias
# 	 fc.weight
# 	 fc.bias

# %%
# TODO: Define criterion and optimizer
# Note that your optimizer only needs to update the parameters that are trainable.
criterion = nn.CrossEntropyLoss(label_smoothing=label_smoothing)

# Optimizer: Update only the parameters of layer4 and fc
optimizer = optim.Adam([
    {'params': net.layer4.parameters()},
    {'params': net.fc.parameters()}
], lr=0.001)

criterion.to(device)
# Out:
# CrossEntropyLoss()

# %%
train(net, criterion, optimizer, num_epochs=50, decay_epochs=10, init_lr=0.01, task='classification', experiment_type='Fine-tuning Randomly Initialized Model')
# Out:
# [1,   100] loss: 2.358 acc: 24.64 time: 6.29
# [1,   200] loss: 2.076 acc: 31.12 time: 6.19
# [1,   300] loss: 2.040 acc: 33.46 time: 6.24
# TESTING:
# Accuracy of the network on the 10000 test images: 35.59 %
# Average loss on the 10000 test images: 1.984
# [2,   100] loss: 1.998 acc: 34.98 time: 6.17
# [2,   200] loss: 1.982 acc: 35.56 time: 5.93
# [2,   300] loss: 1.979 acc: 36.31 time: 5.97
# TESTING:
# Accuracy of the network on the 10000 test images: 38.91 %
# Average loss on the 10000 test images: 1.929
# [3,   100] loss: 1.961 acc: 36.86 time: 5.92
# [3,   200] loss: 1.968 acc: 36.70 time: 5.92
# [3,   300] loss: 1.951 acc: 37.22 time: 6.10
# TESTING:
# Accuracy of the network on the 10000 test images: 41.14 %
# Average loss on the 10000 test images: 1.899
# [4,   100] loss: 1.946 acc: 37.95 time: 6.21
# [4,   200] loss: 1.941 acc: 38.36 time: 6.12
# [4,   300] loss: 1.939 acc: 38.44 time: 5.99
# TESTING:
# Accuracy of the network on the 10000 test images: 41.38 %
# Average loss on the 10000 test images: 1.891
# [5,   100] loss: 1.937 acc: 39.10 time: 6.09
# [5,   200] loss: 1.933 acc: 38.78 time: 6.08
# [5,   300] loss: 1.924 acc: 39.48 time: 5.90
# TESTING:
# Accuracy of the network on the 10000 test images: 42.51 %
# Average loss on the 10000 test images: 1.877
# [6,   100] loss: 1.911 acc: 40.02 time: 6.55
# [6,   200] loss: 1.920 acc: 39.33 time: 6.09
# [6,   300] loss: 1.919 acc: 39.81 time: 5.96
# TESTING:
# Accuracy of the network on the 10000 test images: 43.24 %
# Average loss on the 10000 test images: 1.866
# [7,   100] loss: 1.919 acc: 39.68 time: 5.86
# [7,   200] loss: 1.909 acc: 39.59 time: 5.79
# [7,   300] loss: 1.907 acc: 40.23 time: 5.93
# TESTING:
# Accuracy of the network on the 10000 test images: 43.07 %
# Average loss on the 10000 test images: 1.871
# [8,   100] loss: 1.906 acc: 40.02 time: 5.98
# [8,   200] loss: 1.912 acc: 40.34 time: 5.67
# [8,   300] loss: 1.901 acc: 40.16 time: 5.86
# TESTING:
# Accuracy of the network on the 10000 test images: 42.92 %
# Average loss on the 10000 test images: 1.871
# [9,   100] loss: 1.903 acc: 40.73 time: 5.93
# [9,   200] loss: 1.893 acc: 41.30 time: 6.09
# [9,   300] loss: 1.903 acc: 41.10 time: 6.86
# TESTING:
# Accuracy of the network on the 10000 test images: 43.69 %
# Average loss on the 10000 test images: 1.854
# [10,   100] loss: 1.888 acc: 41.66 time: 6.00
# [10,   200] loss: 1.891 acc: 41.53 time: 5.95
# [10,   300] loss: 1.892 acc: 41.34 time: 6.15
# TESTING:
# Accuracy of the network on the 10000 test images: 44.15 %
# Average loss on the 10000 test images: 1.850
# [11,   100] loss: 1.878 acc: 42.02 time: 5.85
# [11,   200] loss: 1.869 acc: 42.73 time: 6.29
# [11,   300] loss: 1.854 acc: 43.53 time: 5.87
# TESTING:
# Accuracy of the network on the 10000 test images: 44.89 %
# Average loss on the 10000 test images: 1.830
# [12,   100] loss: 1.854 acc: 43.67 time: 6.15
# [12,   200] loss: 1.853 acc: 44.26 time: 5.78
# [12,   300] loss: 1.860 acc: 43.47 time: 5.92
# TESTING:
# Accuracy of the network on the 10000 test images: 45.45 %
# Average loss on the 10000 test images: 1.823
# [13,   100] loss: 1.850 acc: 43.67 time: 6.03
# [13,   200] loss: 1.847 acc: 43.73 time: 6.06
# [13,   300] loss: 1.847 acc: 43.52 time: 6.01
# TESTING:
# Accuracy of the network on the 10000 test images: 45.69 %
# Average loss on the 10000 test images: 1.817
# [14,   100] loss: 1.842 acc: 44.45 time: 6.48
# [14,   200] loss: 1.844 acc: 44.02 time: 6.00
# [14,   300] loss: 1.841 acc: 44.14 time: 5.81
# TESTING:
# Accuracy of the network on the 10000 test images: 45.98 %
# Average loss on the 10000 test images: 1.814
# [15,   100] loss: 1.844 acc: 43.77 time: 5.65
# [15,   200] loss: 1.834 acc: 44.70 time: 5.76
# [15,   300] loss: 1.838 acc: 44.43 time: 5.87
# TESTING:
# Accuracy of the network on the 10000 test images: 46.15 %
# Average loss on the 10000 test images: 1.812
# [16,   100] loss: 1.830 acc: 45.19 time: 6.15
# [16,   200] loss: 1.836 acc: 44.69 time: 5.99
# [16,   300] loss: 1.828 acc: 45.05 time: 6.00
# TESTING:
# Accuracy of the network on the 10000 test images: 45.94 %
# Average loss on the 10000 test images: 1.812
# [17,   100] loss: 1.825 acc: 45.44 time: 6.25
# [17,   200] loss: 1.831 acc: 44.54 time: 6.10
# [17,   300] loss: 1.833 acc: 44.26 time: 5.87
# TESTING:
# Accuracy of the network on the 10000 test images: 46.05 %
# Average loss on the 10000 test images: 1.812
# [18,   100] loss: 1.835 acc: 44.42 time: 6.19
# [18,   200] loss: 1.829 acc: 45.09 time: 6.10
# [18,   300] loss: 1.831 acc: 45.20 time: 5.88
# TESTING:
# Accuracy of the network on the 10000 test images: 46.05 %
# Average loss on the 10000 test images: 1.808
# [19,   100] loss: 1.821 acc: 45.88 time: 6.10
# [19,   200] loss: 1.821 acc: 45.62 time: 6.11
# [19,   300] loss: 1.832 acc: 44.98 time: 5.73
# TESTING:
# Accuracy of the network on the 10000 test images: 46.29 %
# Average loss on the 10000 test images: 1.806
# [20,   100] loss: 1.832 acc: 44.87 time: 6.22
# [20,   200] loss: 1.824 acc: 45.53 time: 6.27
# [20,   300] loss: 1.827 acc: 44.75 time: 5.99
# TESTING:
# Accuracy of the network on the 10000 test images: 46.28 %
# Average loss on the 10000 test images: 1.805
# [21,   100] loss: 1.825 acc: 44.66 time: 5.88
# [21,   200] loss: 1.824 acc: 45.52 time: 5.87
# [21,   300] loss: 1.822 acc: 45.48 time: 6.18
# TESTING:
# Accuracy of the network on the 10000 test images: 46.13 %
# Average loss on the 10000 test images: 1.804
# [22,   100] loss: 1.816 acc: 45.81 time: 6.13
# [22,   200] loss: 1.821 acc: 45.27 time: 5.85
# [22,   300] loss: 1.814 acc: 45.71 time: 5.71
# TESTING:
# Accuracy of the network on the 10000 test images: 46.35 %
# Average loss on the 10000 test images: 1.802
# [23,   100] loss: 1.823 acc: 44.96 time: 5.90
# [23,   200] loss: 1.820 acc: 45.63 time: 5.84
# [23,   300] loss: 1.820 acc: 45.49 time: 6.20
# TESTING:
# Accuracy of the network on the 10000 test images: 45.88 %
# Average loss on the 10000 test images: 1.803
# [24,   100] loss: 1.828 acc: 44.87 time: 6.17
# [24,   200] loss: 1.821 acc: 45.35 time: 6.11
# [24,   300] loss: 1.811 acc: 45.98 time: 5.88
# TESTING:
# Accuracy of the network on the 10000 test images: 46.04 %
# Average loss on the 10000 test images: 1.802
# [25,   100] loss: 1.826 acc: 45.27 time: 6.03
# [25,   200] loss: 1.811 acc: 46.23 time: 6.00
# [25,   300] loss: 1.819 acc: 45.54 time: 5.85
# TESTING:
# Accuracy of the network on the 10000 test images: 46.27 %
# Average loss on the 10000 test images: 1.803
# [26,   100] loss: 1.820 acc: 45.77 time: 6.22
# [26,   200] loss: 1.823 acc: 45.61 time: 5.83
# [26,   300] loss: 1.817 acc: 45.74 time: 5.79
# TESTING:
# Accuracy of the network on the 10000 test images: 46.35 %
# Average loss on the 10000 test images: 1.801
# [27,   100] loss: 1.813 acc: 45.97 time: 6.01
# [27,   200] loss: 1.823 acc: 45.63 time: 6.01
# [27,   300] loss: 1.811 acc: 46.42 time: 6.01
# TESTING:
# Accuracy of the network on the 10000 test images: 46.48 %
# Average loss on the 10000 test images: 1.800
# [28,   100] loss: 1.824 acc: 45.08 time: 6.16
# [28,   200] loss: 1.817 acc: 45.54 time: 5.99
# [28,   300] loss: 1.815 acc: 46.02 time: 6.44
# TESTING:
# Accuracy of the network on the 10000 test images: 46.22 %
# Average loss on the 10000 test images: 1.802
# [29,   100] loss: 1.821 acc: 45.37 time: 6.07
# [29,   200] loss: 1.818 acc: 45.30 time: 5.83
# [29,   300] loss: 1.816 acc: 45.72 time: 6.28
# TESTING:
# Accuracy of the network on the 10000 test images: 46.09 %
# Average loss on the 10000 test images: 1.801
# [30,   100] loss: 1.815 acc: 45.78 time: 6.31
# [30,   200] loss: 1.816 acc: 46.23 time: 5.75
# [30,   300] loss: 1.812 acc: 46.21 time: 5.67
# TESTING:
# Accuracy of the network on the 10000 test images: 46.33 %
# Average loss on the 10000 test images: 1.800
# [31,   100] loss: 1.814 acc: 45.66 time: 6.42
# [31,   200] loss: 1.815 acc: 45.88 time: 6.09
# [31,   300] loss: 1.818 acc: 45.18 time: 6.19
# TESTING:
# Accuracy of the network on the 10000 test images: 46.21 %
# Average loss on the 10000 test images: 1.802
# [32,   100] loss: 1.816 acc: 46.54 time: 6.23
# [32,   200] loss: 1.807 acc: 46.43 time: 6.15
# [32,   300] loss: 1.816 acc: 45.20 time: 5.93
# TESTING:
# Accuracy of the network on the 10000 test images: 46.57 %
# Average loss on the 10000 test images: 1.801
# [33,   100] loss: 1.815 acc: 45.80 time: 5.99
# [33,   200] loss: 1.822 acc: 45.25 time: 6.75
# [33,   300] loss: 1.817 acc: 45.12 time: 6.08
# TESTING:
# Accuracy of the network on the 10000 test images: 46.73 %
# Average loss on the 10000 test images: 1.798
# [34,   100] loss: 1.810 acc: 46.49 time: 6.33
# [34,   200] loss: 1.820 acc: 45.37 time: 5.90
# [34,   300] loss: 1.812 acc: 45.95 time: 5.86
# TESTING:
# Accuracy of the network on the 10000 test images: 46.50 %
# Average loss on the 10000 test images: 1.800
# [35,   100] loss: 1.813 acc: 45.52 time: 12.76
# [35,   200] loss: 1.819 acc: 45.52 time: 17.96
# [35,   300] loss: 1.817 acc: 45.96 time: 6.12
# TESTING:
# Accuracy of the network on the 10000 test images: 46.31 %
# Average loss on the 10000 test images: 1.801
# [36,   100] loss: 1.823 acc: 44.90 time: 5.98
# [36,   200] loss: 1.823 acc: 44.95 time: 5.93
# [36,   300] loss: 1.814 acc: 45.83 time: 6.26
# TESTING:
# Accuracy of the network on the 10000 test images: 46.41 %
# Average loss on the 10000 test images: 1.800
# [37,   100] loss: 1.816 acc: 46.07 time: 6.01
# [37,   200] loss: 1.816 acc: 45.63 time: 6.28
# [37,   300] loss: 1.818 acc: 45.22 time: 6.01
# TESTING:
# Accuracy of the network on the 10000 test images: 46.51 %
# Average loss on the 10000 test images: 1.801
# [38,   100] loss: 1.814 acc: 45.22 time: 5.96
# [38,   200] loss: 1.810 acc: 46.55 time: 6.12
# [38,   300] loss: 1.811 acc: 45.88 time: 5.91
# TESTING:
# Accuracy of the network on the 10000 test images: 46.14 %
# Average loss on the 10000 test images: 1.801
# [39,   100] loss: 1.812 acc: 45.66 time: 5.87
# [39,   200] loss: 1.814 acc: 46.08 time: 6.21
# [39,   300] loss: 1.813 acc: 45.89 time: 6.19
# TESTING:
# Accuracy of the network on the 10000 test images: 46.14 %
# Average loss on the 10000 test images: 1.801
# [40,   100] loss: 1.816 acc: 45.49 time: 5.82
# [40,   200] loss: 1.823 acc: 45.17 time: 6.00
# [40,   300] loss: 1.815 acc: 45.32 time: 10.91
# TESTING:
# Accuracy of the network on the 10000 test images: 46.37 %
# Average loss on the 10000 test images: 1.800
# [41,   100] loss: 1.813 acc: 45.68 time: 5.79
# [41,   200] loss: 1.817 acc: 45.61 time: 6.25
# [41,   300] loss: 1.812 acc: 45.86 time: 6.15
# TESTING:
# Accuracy of the network on the 10000 test images: 46.49 %
# Average loss on the 10000 test images: 1.800
# [42,   100] loss: 1.821 acc: 45.45 time: 5.88
# [42,   200] loss: 1.812 acc: 45.71 time: 6.15
# [42,   300] loss: 1.815 acc: 45.90 time: 6.04
# TESTING:
# Accuracy of the network on the 10000 test images: 46.30 %
# Average loss on the 10000 test images: 1.800
# [43,   100] loss: 1.806 acc: 46.13 time: 6.13
# [43,   200] loss: 1.805 acc: 46.52 time: 6.09
# [43,   300] loss: 1.829 acc: 45.06 time: 6.32
# TESTING:
# Accuracy of the network on the 10000 test images: 46.23 %
# Average loss on the 10000 test images: 1.801
# [44,   100] loss: 1.818 acc: 45.27 time: 6.05
# [44,   200] loss: 1.818 acc: 45.85 time: 6.38
# [44,   300] loss: 1.807 acc: 45.89 time: 5.83
# TESTING:
# Accuracy of the network on the 10000 test images: 46.11 %
# Average loss on the 10000 test images: 1.801
# [45,   100] loss: 1.820 acc: 45.22 time: 6.14
# [45,   200] loss: 1.813 acc: 45.68 time: 5.90
# [45,   300] loss: 1.811 acc: 46.30 time: 5.77
# TESTING:
# Accuracy of the network on the 10000 test images: 46.20 %
# Average loss on the 10000 test images: 1.801
# [46,   100] loss: 1.823 acc: 45.09 time: 6.57
# [46,   200] loss: 1.810 acc: 45.96 time: 6.52
# [46,   300] loss: 1.815 acc: 46.05 time: 6.23
# TESTING:
# Accuracy of the network on the 10000 test images: 46.30 %
# Average loss on the 10000 test images: 1.800
# [47,   100] loss: 1.815 acc: 45.71 time: 6.12
# [47,   200] loss: 1.818 acc: 45.81 time: 6.08
# [47,   300] loss: 1.816 acc: 45.53 time: 5.86
# TESTING:
# Accuracy of the network on the 10000 test images: 46.30 %
# Average loss on the 10000 test images: 1.799
# [48,   100] loss: 1.817 acc: 45.52 time: 6.37
# [48,   200] loss: 1.814 acc: 45.60 time: 6.23
# [48,   300] loss: 1.811 acc: 45.91 time: 6.06
# TESTING:
# Accuracy of the network on the 10000 test images: 46.28 %
# Average loss on the 10000 test images: 1.801
# [49,   100] loss: 1.815 acc: 45.92 time: 6.04
# [49,   200] loss: 1.821 acc: 45.12 time: 5.99
# [49,   300] loss: 1.811 acc: 45.92 time: 6.07
# TESTING:
# Accuracy of the network on the 10000 test images: 46.33 %
# Average loss on the 10000 test images: 1.799
# [50,   100] loss: 1.817 acc: 45.21 time: 6.00
# [50,   200] loss: 1.815 acc: 46.13 time: 6.17
# [50,   300] loss: 1.813 acc: 45.41 time: 6.04
# TESTING:
# Accuracy of the network on the 10000 test images: 46.48 %
# Average loss on the 10000 test images: 1.799
# Finished Training

# %% [markdown]
# ## Supervised training on the pre-trained model (9 points)
# In this section, we will load the ResNet18 model pre-trained on the rotation task and re-train the whole model on the classification task.
#
# **Then we will use the trained model from rotation task as the pretrained weights. Notice, you should not use the pretrained weights from ImageNet.**

# %%
import torch.nn as nn
import torch.nn.functional as F

from torchvision.models import resnet18

#####################################################
#     TODO: Load the pre-trained ResNet18 model     #  
#####################################################
# load the trained classifier weights
net = resnet18(weights=None, num_classes=4)
ckpt = torch.load(f"model_2023-11-02-23-22-09.pth")
net.load_state_dict(ckpt)

# Adjusting the fully connected layer for 10 classes
net.fc = nn.Linear(net.fc.in_features, 10)
net = net.to(device)
#####################################################
#                End of your code                   #   
#####################################################

# %%
# TODO: Define criterion and optimizer
criterion = nn.CrossEntropyLoss(label_smoothing=label_smoothing)

# Optimizer: Update only the parameters of layer4 and fc
optimizer = optim.Adam(lr=0.001, params=net.parameters())

criterion.to(device)
# Out:
# CrossEntropyLoss()

# %%
train(net, criterion, optimizer, num_epochs=50, decay_epochs=10, init_lr=0.01, task='classification', experiment_type='Supervised Pre-trained Model')
# Out:
# [1,   100] loss: 1.776 acc: 47.21 time: 10.71
# [1,   200] loss: 1.579 acc: 59.95 time: 7.29
# [1,   300] loss: 1.510 acc: 63.72 time: 7.00
# TESTING:
# Accuracy of the network on the 10000 test images: 67.72 %
# Average loss on the 10000 test images: 1.452
# [2,   100] loss: 1.439 acc: 68.27 time: 6.98
# [2,   200] loss: 1.421 acc: 69.29 time: 7.14
# [2,   300] loss: 1.399 acc: 70.84 time: 6.59
# TESTING:
# Accuracy of the network on the 10000 test images: 73.44 %
# Average loss on the 10000 test images: 1.348
# [3,   100] loss: 1.357 acc: 73.12 time: 7.01
# [3,   200] loss: 1.359 acc: 73.06 time: 7.06
# [3,   300] loss: 1.344 acc: 73.55 time: 6.89
# TESTING:
# Accuracy of the network on the 10000 test images: 74.93 %
# Average loss on the 10000 test images: 1.318
# [4,   100] loss: 1.315 acc: 75.29 time: 6.80
# [4,   200] loss: 1.321 acc: 75.15 time: 6.85
# [4,   300] loss: 1.299 acc: 76.16 time: 6.73
# TESTING:
# Accuracy of the network on the 10000 test images: 76.22 %
# Average loss on the 10000 test images: 1.301
# [5,   100] loss: 1.286 acc: 77.12 time: 7.47
# [5,   200] loss: 1.281 acc: 77.40 time: 7.45
# [5,   300] loss: 1.283 acc: 77.46 time: 7.06
# TESTING:
# Accuracy of the network on the 10000 test images: 78.54 %
# Average loss on the 10000 test images: 1.257
# [6,   100] loss: 1.256 acc: 79.21 time: 7.11
# [6,   200] loss: 1.264 acc: 78.11 time: 7.07
# [6,   300] loss: 1.268 acc: 78.27 time: 7.40
# TESTING:
# Accuracy of the network on the 10000 test images: 78.62 %
# Average loss on the 10000 test images: 1.258
# [7,   100] loss: 1.234 acc: 79.94 time: 6.94
# [7,   200] loss: 1.232 acc: 79.91 time: 7.57
# [7,   300] loss: 1.238 acc: 79.51 time: 8.05
# TESTING:
# Accuracy of the network on the 10000 test images: 77.62 %
# Average loss on the 10000 test images: 1.277
# [8,   100] loss: 1.227 acc: 80.57 time: 7.53
# [8,   200] loss: 1.219 acc: 81.16 time: 7.55
# [8,   300] loss: 1.221 acc: 80.60 time: 7.52
# TESTING:
# Accuracy of the network on the 10000 test images: 79.11 %
# Average loss on the 10000 test images: 1.245
# [9,   100] loss: 1.206 acc: 81.39 time: 7.32
# [9,   200] loss: 1.210 acc: 81.43 time: 7.44
# [9,   300] loss: 1.210 acc: 81.38 time: 8.06
# TESTING:
# Accuracy of the network on the 10000 test images: 78.65 %
# Average loss on the 10000 test images: 1.257
# [10,   100] loss: 1.202 acc: 81.66 time: 7.44
# [10,   200] loss: 1.196 acc: 82.19 time: 7.16
# [10,   300] loss: 1.193 acc: 82.49 time: 8.36
# TESTING:
# Accuracy of the network on the 10000 test images: 80.23 %
# Average loss on the 10000 test images: 1.231
# [11,   100] loss: 1.156 acc: 84.15 time: 7.31
# [11,   200] loss: 1.130 acc: 85.63 time: 8.19
# [11,   300] loss: 1.128 acc: 85.69 time: 7.12
# TESTING:
# Accuracy of the network on the 10000 test images: 83.14 %
# Average loss on the 10000 test images: 1.170
# [12,   100] loss: 1.114 acc: 86.35 time: 7.45
# [12,   200] loss: 1.126 acc: 85.95 time: 7.81
# [12,   300] loss: 1.119 acc: 86.06 time: 7.11
# TESTING:
# Accuracy of the network on the 10000 test images: 83.83 %
# Average loss on the 10000 test images: 1.164
# [13,   100] loss: 1.115 acc: 86.37 time: 10.92
# [13,   200] loss: 1.111 acc: 86.53 time: 8.04
# [13,   300] loss: 1.114 acc: 86.60 time: 7.17
# TESTING:
# Accuracy of the network on the 10000 test images: 83.97 %
# Average loss on the 10000 test images: 1.162
# [14,   100] loss: 1.099 acc: 87.17 time: 7.04
# [14,   200] loss: 1.107 acc: 86.99 time: 7.64
# [14,   300] loss: 1.102 acc: 87.20 time: 6.88
# TESTING:
# Accuracy of the network on the 10000 test images: 84.12 %
# Average loss on the 10000 test images: 1.160
# [15,   100] loss: 1.109 acc: 86.44 time: 7.59
# [15,   200] loss: 1.093 acc: 87.59 time: 11.65
# [15,   300] loss: 1.107 acc: 87.00 time: 7.44
# TESTING:
# Accuracy of the network on the 10000 test images: 83.88 %
# Average loss on the 10000 test images: 1.163
# [16,   100] loss: 1.094 acc: 87.55 time: 7.04
# [16,   200] loss: 1.092 acc: 87.78 time: 7.35
# [16,   300] loss: 1.094 acc: 87.73 time: 7.50
# TESTING:
# Accuracy of the network on the 10000 test images: 83.93 %
# Average loss on the 10000 test images: 1.160
# [17,   100] loss: 1.096 acc: 87.67 time: 7.47
# [17,   200] loss: 1.091 acc: 87.68 time: 7.37
# [17,   300] loss: 1.088 acc: 87.91 time: 7.93
# TESTING:
# Accuracy of the network on the 10000 test images: 83.85 %
# Average loss on the 10000 test images: 1.160
# [18,   100] loss: 1.091 acc: 87.89 time: 7.09
# [18,   200] loss: 1.079 acc: 88.38 time: 7.24
# [18,   300] loss: 1.090 acc: 87.73 time: 7.50
# TESTING:
# Accuracy of the network on the 10000 test images: 83.94 %
# Average loss on the 10000 test images: 1.158
# [19,   100] loss: 1.082 acc: 88.39 time: 7.82
# [19,   200] loss: 1.090 acc: 87.91 time: 7.26
# [19,   300] loss: 1.083 acc: 87.98 time: 7.80
# TESTING:
# Accuracy of the network on the 10000 test images: 84.27 %
# Average loss on the 10000 test images: 1.157
# [20,   100] loss: 1.078 acc: 88.45 time: 7.67
# [20,   200] loss: 1.077 acc: 88.35 time: 7.66
# [20,   300] loss: 1.087 acc: 88.16 time: 6.92
# TESTING:
# Accuracy of the network on the 10000 test images: 84.07 %
# Average loss on the 10000 test images: 1.158
# [21,   100] loss: 1.070 acc: 88.90 time: 8.19
# [21,   200] loss: 1.069 acc: 88.89 time: 7.64
# [21,   300] loss: 1.076 acc: 88.38 time: 8.24
# TESTING:
# Accuracy of the network on the 10000 test images: 84.20 %
# Average loss on the 10000 test images: 1.155
# [22,   100] loss: 1.072 acc: 88.60 time: 7.23
# [22,   200] loss: 1.076 acc: 88.55 time: 7.94
# [22,   300] loss: 1.076 acc: 88.74 time: 7.09
# TESTING:
# Accuracy of the network on the 10000 test images: 84.21 %
# Average loss on the 10000 test images: 1.154
# [23,   100] loss: 1.071 acc: 88.80 time: 7.66
# [23,   200] loss: 1.072 acc: 88.84 time: 6.93
# [23,   300] loss: 1.072 acc: 88.85 time: 7.03
# TESTING:
# Accuracy of the network on the 10000 test images: 84.28 %
# Average loss on the 10000 test images: 1.154
# [24,   100] loss: 1.071 acc: 88.74 time: 7.91
# [24,   200] loss: 1.069 acc: 89.02 time: 7.70
# [24,   300] loss: 1.074 acc: 88.50 time: 7.40
# TESTING:
# Accuracy of the network on the 10000 test images: 84.26 %
# Average loss on the 10000 test images: 1.154
# [25,   100] loss: 1.076 acc: 88.52 time: 7.33
# [25,   200] loss: 1.072 acc: 88.79 time: 7.77
# [25,   300] loss: 1.070 acc: 88.81 time: 8.30
# TESTING:
# Accuracy of the network on the 10000 test images: 84.30 %
# Average loss on the 10000 test images: 1.154
# [26,   100] loss: 1.068 acc: 89.06 time: 7.08
# [26,   200] loss: 1.068 acc: 89.13 time: 7.65
# [26,   300] loss: 1.072 acc: 88.74 time: 8.19
# TESTING:
# Accuracy of the network on the 10000 test images: 84.31 %
# Average loss on the 10000 test images: 1.154
# [27,   100] loss: 1.066 acc: 88.84 time: 7.36
# [27,   200] loss: 1.067 acc: 89.05 time: 7.35
# [27,   300] loss: 1.075 acc: 88.67 time: 7.09
# TESTING:
# Accuracy of the network on the 10000 test images: 84.41 %
# Average loss on the 10000 test images: 1.154
# [28,   100] loss: 1.076 acc: 88.70 time: 7.59
# [28,   200] loss: 1.062 acc: 89.39 time: 7.72
# [28,   300] loss: 1.067 acc: 89.07 time: 7.60
# TESTING:
# Accuracy of the network on the 10000 test images: 84.27 %
# Average loss on the 10000 test images: 1.154
# [29,   100] loss: 1.067 acc: 89.24 time: 7.07
# [29,   200] loss: 1.069 acc: 88.88 time: 7.35
# [29,   300] loss: 1.070 acc: 88.92 time: 7.49
# TESTING:
# Accuracy of the network on the 10000 test images: 84.33 %
# Average loss on the 10000 test images: 1.155
# [30,   100] loss: 1.067 acc: 89.05 time: 7.37
# [30,   200] loss: 1.068 acc: 89.01 time: 7.25
# [30,   300] loss: 1.071 acc: 88.77 time: 11.25
# TESTING:
# Accuracy of the network on the 10000 test images: 84.38 %
# Average loss on the 10000 test images: 1.155
# [31,   100] loss: 1.066 acc: 89.16 time: 8.33
# [31,   200] loss: 1.069 acc: 89.03 time: 7.16
# [31,   300] loss: 1.059 acc: 89.50 time: 7.22
# TESTING:
# Accuracy of the network on the 10000 test images: 84.37 %
# Average loss on the 10000 test images: 1.153
# [32,   100] loss: 1.066 acc: 89.29 time: 7.45
# [32,   200] loss: 1.065 acc: 89.26 time: 7.29
# [32,   300] loss: 1.066 acc: 89.11 time: 7.21
# TESTING:
# Accuracy of the network on the 10000 test images: 84.29 %
# Average loss on the 10000 test images: 1.154
# [33,   100] loss: 1.070 acc: 89.38 time: 7.00
# [33,   200] loss: 1.070 acc: 89.16 time: 6.86
# [33,   300] loss: 1.062 acc: 89.30 time: 7.01
# TESTING:
# Accuracy of the network on the 10000 test images: 84.37 %
# Average loss on the 10000 test images: 1.154
# [34,   100] loss: 1.062 acc: 89.42 time: 7.75
# [34,   200] loss: 1.068 acc: 89.17 time: 7.54
# [34,   300] loss: 1.069 acc: 89.21 time: 8.07
# TESTING:
# Accuracy of the network on the 10000 test images: 84.30 %
# Average loss on the 10000 test images: 1.154
# [35,   100] loss: 1.069 acc: 88.96 time: 7.12
# [35,   200] loss: 1.063 acc: 89.38 time: 7.36
# [35,   300] loss: 1.067 acc: 89.16 time: 6.93
# TESTING:
# Accuracy of the network on the 10000 test images: 84.42 %
# Average loss on the 10000 test images: 1.154
# [36,   100] loss: 1.069 acc: 89.05 time: 6.97
# [36,   200] loss: 1.058 acc: 89.69 time: 6.96
# [36,   300] loss: 1.065 acc: 89.17 time: 7.24
# TESTING:
# Accuracy of the network on the 10000 test images: 84.39 %
# Average loss on the 10000 test images: 1.154
# [37,   100] loss: 1.070 acc: 88.84 time: 7.61
# [37,   200] loss: 1.069 acc: 89.01 time: 7.76
# [37,   300] loss: 1.065 acc: 89.20 time: 7.80
# TESTING:
# Accuracy of the network on the 10000 test images: 84.52 %
# Average loss on the 10000 test images: 1.155
# [38,   100] loss: 1.062 acc: 89.35 time: 7.08
# [38,   200] loss: 1.064 acc: 89.25 time: 8.45
# [38,   300] loss: 1.074 acc: 88.92 time: 7.85
# TESTING:
# Accuracy of the network on the 10000 test images: 84.48 %
# Average loss on the 10000 test images: 1.154
# [39,   100] loss: 1.065 acc: 89.40 time: 7.24
# [39,   200] loss: 1.072 acc: 88.83 time: 7.60
# [39,   300] loss: 1.066 acc: 88.91 time: 7.07
# TESTING:
# Accuracy of the network on the 10000 test images: 84.45 %
# Average loss on the 10000 test images: 1.153
# [40,   100] loss: 1.065 acc: 89.30 time: 7.60
# [40,   200] loss: 1.066 acc: 89.05 time: 7.52
# [40,   300] loss: 1.072 acc: 88.48 time: 7.46
# TESTING:
# Accuracy of the network on the 10000 test images: 84.30 %
# Average loss on the 10000 test images: 1.153
# [41,   100] loss: 1.063 acc: 89.27 time: 7.58
# [41,   200] loss: 1.067 acc: 88.88 time: 7.77
# [41,   300] loss: 1.061 acc: 89.51 time: 7.82
# TESTING:
# Accuracy of the network on the 10000 test images: 84.34 %
# Average loss on the 10000 test images: 1.153
# [42,   100] loss: 1.072 acc: 88.98 time: 7.45
# [42,   200] loss: 1.064 acc: 89.28 time: 7.39
# [42,   300] loss: 1.066 acc: 89.21 time: 7.40
# TESTING:
# Accuracy of the network on the 10000 test images: 84.43 %
# Average loss on the 10000 test images: 1.156
# [43,   100] loss: 1.072 acc: 88.93 time: 7.40
# [43,   200] loss: 1.062 acc: 89.38 time: 8.09
# [43,   300] loss: 1.065 acc: 89.46 time: 7.67
# TESTING:
# Accuracy of the network on the 10000 test images: 84.33 %
# Average loss on the 10000 test images: 1.154
# [44,   100] loss: 1.069 acc: 89.02 time: 7.32
# [44,   200] loss: 1.064 acc: 89.35 time: 7.65
# [44,   300] loss: 1.068 acc: 89.15 time: 7.87
# TESTING:
# Accuracy of the network on the 10000 test images: 84.54 %
# Average loss on the 10000 test images: 1.153
# [45,   100] loss: 1.056 acc: 89.80 time: 6.92
# [45,   200] loss: 1.077 acc: 88.36 time: 7.34
# [45,   300] loss: 1.055 acc: 89.66 time: 6.97
# TESTING:
# Accuracy of the network on the 10000 test images: 84.40 %
# Average loss on the 10000 test images: 1.153
# [46,   100] loss: 1.072 acc: 88.82 time: 8.07
# [46,   200] loss: 1.067 acc: 89.12 time: 8.23
# [46,   300] loss: 1.064 acc: 89.44 time: 7.99
# TESTING:
# Accuracy of the network on the 10000 test images: 84.38 %
# Average loss on the 10000 test images: 1.154
# [47,   100] loss: 1.076 acc: 88.62 time: 7.53
# [47,   200] loss: 1.064 acc: 89.40 time: 7.43
# [47,   300] loss: 1.064 acc: 89.43 time: 7.04
# TESTING:
# Accuracy of the network on the 10000 test images: 84.37 %
# Average loss on the 10000 test images: 1.154
# [48,   100] loss: 1.069 acc: 88.97 time: 7.06
# [48,   200] loss: 1.064 acc: 89.41 time: 7.19
# [48,   300] loss: 1.068 acc: 89.11 time: 6.81
# TESTING:
# Accuracy of the network on the 10000 test images: 84.30 %
# Average loss on the 10000 test images: 1.154
# [49,   100] loss: 1.065 acc: 88.97 time: 7.42
# [49,   200] loss: 1.068 acc: 88.98 time: 7.93
# [49,   300] loss: 1.059 acc: 89.51 time: 7.05
# TESTING:
# Accuracy of the network on the 10000 test images: 84.52 %
# Average loss on the 10000 test images: 1.154
# [50,   100] loss: 1.069 acc: 89.22 time: 7.01
# [50,   200] loss: 1.063 acc: 89.08 time: 6.87
# [50,   300] loss: 1.069 acc: 89.10 time: 7.50
# TESTING:
# Accuracy of the network on the 10000 test images: 84.50 %
# Average loss on the 10000 test images: 1.154
# Finished Training

# %% [markdown]
# ## Supervised training on the randomly initialized model (9 points)
# In this section, we will randomly initialize a ResNet18 model and re-train the whole model on the classification task.

# %%
import torch.nn as nn
import torch.nn.functional as F

from torchvision.models import resnet18

#################################################
# TODO: Randomly initialize a ResNet18 model    #
#################################################
net = resnet18(weights=None, num_classes=10)
net = net.to(device)
#################################################
#              End of your code                 #
#################################################

# %%
# TODO: Define criterion and optimizer
criterion = nn.CrossEntropyLoss(label_smoothing=label_smoothing)

# Optimizer: Update only the parameters of layer4 and fc
optimizer = optim.Adam(lr=0.001, params=net.parameters())

criterion.to(device)
# Out:
# CrossEntropyLoss()

# %%
train(net, criterion, optimizer, num_epochs=50, decay_epochs=10, init_lr=0.01, task='classification', experiment_type='Supervised Randomly Initialized Model')
# Out:
# [1,   100] loss: 2.431 acc: 20.38 time: 7.15
# [1,   200] loss: 2.040 acc: 32.63 time: 7.00
# [1,   300] loss: 1.946 acc: 37.62 time: 7.24
# TESTING:
# Accuracy of the network on the 10000 test images: 38.39 %
# Average loss on the 10000 test images: 2.382
# [2,   100] loss: 1.849 acc: 44.14 time: 7.07
# [2,   200] loss: 1.781 acc: 47.30 time: 7.86
# [2,   300] loss: 1.732 acc: 50.17 time: 6.87
# TESTING:
# Accuracy of the network on the 10000 test images: 52.98 %
# Average loss on the 10000 test images: 1.698
# [3,   100] loss: 1.638 acc: 55.87 time: 6.95
# [3,   200] loss: 1.623 acc: 57.09 time: 7.43
# [3,   300] loss: 1.591 acc: 59.01 time: 7.19
# TESTING:
# Accuracy of the network on the 10000 test images: 60.96 %
# Average loss on the 10000 test images: 1.600
# [4,   100] loss: 1.522 acc: 63.22 time: 6.86
# [4,   200] loss: 1.520 acc: 63.18 time: 6.76
# [4,   300] loss: 1.496 acc: 64.68 time: 7.73
# TESTING:
# Accuracy of the network on the 10000 test images: 66.18 %
# Average loss on the 10000 test images: 1.471
# [5,   100] loss: 1.467 acc: 66.45 time: 7.15
# [5,   200] loss: 1.454 acc: 67.37 time: 7.12
# [5,   300] loss: 1.444 acc: 67.95 time: 7.51
# TESTING:
# Accuracy of the network on the 10000 test images: 69.63 %
# Average loss on the 10000 test images: 1.416
# [6,   100] loss: 1.411 acc: 69.62 time: 7.07
# [6,   200] loss: 1.399 acc: 70.24 time: 6.91
# [6,   300] loss: 1.390 acc: 71.39 time: 7.32
# TESTING:
# Accuracy of the network on the 10000 test images: 71.53 %
# Average loss on the 10000 test images: 1.396
# [7,   100] loss: 1.371 acc: 71.80 time: 6.95
# [7,   200] loss: 1.362 acc: 72.70 time: 7.70
# [7,   300] loss: 1.375 acc: 72.38 time: 7.35
# TESTING:
# Accuracy of the network on the 10000 test images: 72.45 %
# Average loss on the 10000 test images: 1.372
# [8,   100] loss: 1.345 acc: 73.62 time: 6.73
# [8,   200] loss: 1.338 acc: 73.84 time: 7.07
# [8,   300] loss: 1.341 acc: 73.52 time: 7.03
# TESTING:
# Accuracy of the network on the 10000 test images: 74.31 %
# Average loss on the 10000 test images: 1.336
# [9,   100] loss: 1.311 acc: 75.34 time: 7.06
# [9,   200] loss: 1.327 acc: 74.66 time: 7.64
# [9,   300] loss: 1.305 acc: 76.05 time: 6.92
# TESTING:
# Accuracy of the network on the 10000 test images: 74.12 %
# Average loss on the 10000 test images: 1.347
# [10,   100] loss: 1.297 acc: 76.09 time: 7.31
# [10,   200] loss: 1.285 acc: 76.88 time: 7.05
# [10,   300] loss: 1.295 acc: 76.74 time: 7.12
# TESTING:
# Accuracy of the network on the 10000 test images: 76.08 %
# Average loss on the 10000 test images: 1.301
# [11,   100] loss: 1.231 acc: 79.87 time: 7.37
# [11,   200] loss: 1.220 acc: 80.49 time: 7.29
# [11,   300] loss: 1.206 acc: 81.20 time: 6.97
# TESTING:
# Accuracy of the network on the 10000 test images: 81.03 %
# Average loss on the 10000 test images: 1.219
# [12,   100] loss: 1.196 acc: 81.46 time: 7.22
# [12,   200] loss: 1.189 acc: 82.26 time: 7.08
# [12,   300] loss: 1.183 acc: 82.78 time: 6.90
# TESTING:
# Accuracy of the network on the 10000 test images: 81.30 %
# Average loss on the 10000 test images: 1.211
# [13,   100] loss: 1.174 acc: 82.95 time: 7.24
# [13,   200] loss: 1.179 acc: 82.77 time: 7.75
# [13,   300] loss: 1.176 acc: 82.77 time: 6.83
# TESTING:
# Accuracy of the network on the 10000 test images: 81.56 %
# Average loss on the 10000 test images: 1.208
# [14,   100] loss: 1.172 acc: 82.93 time: 7.00
# [14,   200] loss: 1.168 acc: 83.12 time: 7.13
# [14,   300] loss: 1.160 acc: 83.77 time: 7.12
# TESTING:
# Accuracy of the network on the 10000 test images: 81.74 %
# Average loss on the 10000 test images: 1.200
# [15,   100] loss: 1.166 acc: 83.62 time: 6.84
# [15,   200] loss: 1.164 acc: 83.52 time: 7.31
# [15,   300] loss: 1.158 acc: 84.22 time: 6.80
# TESTING:
# Accuracy of the network on the 10000 test images: 82.37 %
# Average loss on the 10000 test images: 1.195
# [16,   100] loss: 1.155 acc: 84.05 time: 7.47
# [16,   200] loss: 1.157 acc: 84.15 time: 6.76
# [16,   300] loss: 1.147 acc: 84.68 time: 6.96
# TESTING:
# Accuracy of the network on the 10000 test images: 82.19 %
# Average loss on the 10000 test images: 1.195
# [17,   100] loss: 1.148 acc: 84.58 time: 7.50
# [17,   200] loss: 1.148 acc: 84.53 time: 7.45
# [17,   300] loss: 1.149 acc: 84.77 time: 7.80
# TESTING:
# Accuracy of the network on the 10000 test images: 82.03 %
# Average loss on the 10000 test images: 1.197
# [18,   100] loss: 1.142 acc: 85.29 time: 6.93
# [18,   200] loss: 1.138 acc: 84.97 time: 6.73
# [18,   300] loss: 1.138 acc: 85.27 time: 7.07
# TESTING:
# Accuracy of the network on the 10000 test images: 82.46 %
# Average loss on the 10000 test images: 1.186
# [19,   100] loss: 1.137 acc: 85.37 time: 7.15
# [19,   200] loss: 1.132 acc: 85.54 time: 6.88
# [19,   300] loss: 1.140 acc: 85.16 time: 6.86
# TESTING:
# Accuracy of the network on the 10000 test images: 82.65 %
# Average loss on the 10000 test images: 1.185
# [20,   100] loss: 1.134 acc: 85.38 time: 7.58
# [20,   200] loss: 1.127 acc: 86.12 time: 6.90
# [20,   300] loss: 1.137 acc: 85.16 time: 7.85
# TESTING:
# Accuracy of the network on the 10000 test images: 82.72 %
# Average loss on the 10000 test images: 1.182
# [21,   100] loss: 1.121 acc: 86.31 time: 6.98
# [21,   200] loss: 1.117 acc: 86.23 time: 8.11
# [21,   300] loss: 1.116 acc: 86.55 time: 6.77
# TESTING:
# Accuracy of the network on the 10000 test images: 83.22 %
# Average loss on the 10000 test images: 1.178
# [22,   100] loss: 1.114 acc: 86.30 time: 7.36
# [22,   200] loss: 1.109 acc: 86.97 time: 6.89
# [22,   300] loss: 1.116 acc: 86.44 time: 8.03
# TESTING:
# Accuracy of the network on the 10000 test images: 83.26 %
# Average loss on the 10000 test images: 1.177
# [23,   100] loss: 1.117 acc: 86.14 time: 7.20
# [23,   200] loss: 1.111 acc: 86.94 time: 7.76
# [23,   300] loss: 1.108 acc: 87.01 time: 7.93
# TESTING:
# Accuracy of the network on the 10000 test images: 83.22 %
# Average loss on the 10000 test images: 1.174
# [24,   100] loss: 1.115 acc: 86.39 time: 8.34
# [24,   200] loss: 1.109 acc: 86.65 time: 7.02
# [24,   300] loss: 1.104 acc: 86.88 time: 7.79
# TESTING:
# Accuracy of the network on the 10000 test images: 83.32 %
# Average loss on the 10000 test images: 1.174
# [25,   100] loss: 1.108 acc: 86.80 time: 6.97
# [25,   200] loss: 1.105 acc: 86.87 time: 6.71
# [25,   300] loss: 1.113 acc: 86.43 time: 6.86
# TESTING:
# Accuracy of the network on the 10000 test images: 83.19 %
# Average loss on the 10000 test images: 1.175
# [26,   100] loss: 1.110 acc: 86.70 time: 7.09
# [26,   200] loss: 1.106 acc: 87.16 time: 7.59
# [26,   300] loss: 1.104 acc: 86.92 time: 6.99
# TESTING:
# Accuracy of the network on the 10000 test images: 83.37 %
# Average loss on the 10000 test images: 1.175
# [27,   100] loss: 1.100 acc: 87.22 time: 6.89
# [27,   200] loss: 1.110 acc: 86.56 time: 7.65
# [27,   300] loss: 1.109 acc: 86.87 time: 7.39
# TESTING:
# Accuracy of the network on the 10000 test images: 83.40 %
# Average loss on the 10000 test images: 1.173
# [28,   100] loss: 1.103 acc: 86.99 time: 6.81
# [28,   200] loss: 1.103 acc: 86.85 time: 7.09
# [28,   300] loss: 1.108 acc: 86.73 time: 7.89
# TESTING:
# Accuracy of the network on the 10000 test images: 83.39 %
# Average loss on the 10000 test images: 1.173
# [29,   100] loss: 1.103 acc: 86.98 time: 7.16
# [29,   200] loss: 1.104 acc: 87.16 time: 6.74
# [29,   300] loss: 1.099 acc: 87.17 time: 6.79
# TESTING:
# Accuracy of the network on the 10000 test images: 83.37 %
# Average loss on the 10000 test images: 1.173
# [30,   100] loss: 1.101 acc: 87.45 time: 7.13
# [30,   200] loss: 1.113 acc: 86.38 time: 7.64
# [30,   300] loss: 1.103 acc: 87.12 time: 6.89
# TESTING:
# Accuracy of the network on the 10000 test images: 83.53 %
# Average loss on the 10000 test images: 1.174
# [31,   100] loss: 1.108 acc: 86.89 time: 6.77
# [31,   200] loss: 1.103 acc: 87.10 time: 6.83
# [31,   300] loss: 1.102 acc: 87.15 time: 7.46
# TESTING:
# Accuracy of the network on the 10000 test images: 83.23 %
# Average loss on the 10000 test images: 1.174
# [32,   100] loss: 1.101 acc: 87.33 time: 7.30
# [32,   200] loss: 1.100 acc: 87.20 time: 7.13
# [32,   300] loss: 1.100 acc: 87.29 time: 7.25
# TESTING:
# Accuracy of the network on the 10000 test images: 83.38 %
# Average loss on the 10000 test images: 1.173
# [33,   100] loss: 1.104 acc: 87.07 time: 6.78
# [33,   200] loss: 1.104 acc: 87.18 time: 7.33
# [33,   300] loss: 1.100 acc: 87.26 time: 7.43
# TESTING:
# Accuracy of the network on the 10000 test images: 83.57 %
# Average loss on the 10000 test images: 1.172
# [34,   100] loss: 1.109 acc: 86.64 time: 7.18
# [34,   200] loss: 1.098 acc: 87.55 time: 7.36
# [34,   300] loss: 1.105 acc: 87.01 time: 6.84
# TESTING:
# Accuracy of the network on the 10000 test images: 83.53 %
# Average loss on the 10000 test images: 1.173
# [35,   100] loss: 1.103 acc: 87.01 time: 7.30
# [35,   200] loss: 1.104 acc: 86.78 time: 7.55
# [35,   300] loss: 1.098 acc: 87.73 time: 7.74
# TESTING:
# Accuracy of the network on the 10000 test images: 83.51 %
# Average loss on the 10000 test images: 1.173
# [36,   100] loss: 1.099 acc: 87.59 time: 7.20
# [36,   200] loss: 1.098 acc: 87.36 time: 7.70
# [36,   300] loss: 1.107 acc: 86.68 time: 7.00
# TESTING:
# Accuracy of the network on the 10000 test images: 83.54 %
# Average loss on the 10000 test images: 1.172
# [37,   100] loss: 1.099 acc: 87.30 time: 7.02
# [37,   200] loss: 1.105 acc: 87.00 time: 6.83
# [37,   300] loss: 1.105 acc: 86.91 time: 6.91
# TESTING:
# Accuracy of the network on the 10000 test images: 83.55 %
# Average loss on the 10000 test images: 1.172
# [38,   100] loss: 1.108 acc: 86.62 time: 7.16
# [38,   200] loss: 1.096 acc: 87.45 time: 7.15
# [38,   300] loss: 1.102 acc: 87.02 time: 7.51
# TESTING:
# Accuracy of the network on the 10000 test images: 83.41 %
# Average loss on the 10000 test images: 1.173
# [39,   100] loss: 1.106 acc: 87.13 time: 7.05
# [39,   200] loss: 1.099 acc: 87.41 time: 6.75
# [39,   300] loss: 1.102 acc: 87.16 time: 6.88
# TESTING:
# Accuracy of the network on the 10000 test images: 83.36 %
# Average loss on the 10000 test images: 1.172
# [40,   100] loss: 1.099 acc: 86.96 time: 6.75
# [40,   200] loss: 1.098 acc: 87.31 time: 7.03
# [40,   300] loss: 1.104 acc: 86.83 time: 7.04
# TESTING:
# Accuracy of the network on the 10000 test images: 83.41 %
# Average loss on the 10000 test images: 1.173
# [41,   100] loss: 1.101 acc: 86.98 time: 7.83
# [41,   200] loss: 1.101 acc: 87.13 time: 6.91
# [41,   300] loss: 1.095 acc: 87.52 time: 7.37
# TESTING:
# Accuracy of the network on the 10000 test images: 83.54 %
# Average loss on the 10000 test images: 1.175
# [42,   100] loss: 1.103 acc: 86.91 time: 7.92
# [42,   200] loss: 1.100 acc: 87.41 time: 8.32
# [42,   300] loss: 1.098 acc: 87.38 time: 6.66
# TESTING:
# Accuracy of the network on the 10000 test images: 83.23 %
# Average loss on the 10000 test images: 1.175
# [43,   100] loss: 1.096 acc: 87.55 time: 7.54
# [43,   200] loss: 1.098 acc: 87.47 time: 6.60
# [43,   300] loss: 1.102 acc: 87.36 time: 6.86
# TESTING:
# Accuracy of the network on the 10000 test images: 83.52 %
# Average loss on the 10000 test images: 1.172
# [44,   100] loss: 1.107 acc: 86.93 time: 6.88
# [44,   200] loss: 1.094 acc: 87.48 time: 8.08
# [44,   300] loss: 1.102 acc: 87.09 time: 7.06
# TESTING:
# Accuracy of the network on the 10000 test images: 83.49 %
# Average loss on the 10000 test images: 1.173
# [45,   100] loss: 1.099 acc: 87.29 time: 6.93
# [45,   200] loss: 1.105 acc: 86.86 time: 7.21
# [45,   300] loss: 1.097 acc: 87.42 time: 7.35
# TESTING:
# Accuracy of the network on the 10000 test images: 83.40 %
# Average loss on the 10000 test images: 1.173
# [46,   100] loss: 1.101 acc: 87.20 time: 7.40
# [46,   200] loss: 1.095 acc: 87.51 time: 7.66
# [46,   300] loss: 1.110 acc: 86.68 time: 7.74
# TESTING:
# Accuracy of the network on the 10000 test images: 83.34 %
# Average loss on the 10000 test images: 1.173
# [47,   100] loss: 1.098 acc: 87.34 time: 7.52
# [47,   200] loss: 1.102 acc: 87.26 time: 7.06
# [47,   300] loss: 1.094 acc: 87.49 time: 7.46
# TESTING:
# Accuracy of the network on the 10000 test images: 83.60 %
# Average loss on the 10000 test images: 1.173
# [48,   100] loss: 1.106 acc: 87.12 time: 7.85
# [48,   200] loss: 1.102 acc: 87.02 time: 7.19
# [48,   300] loss: 1.097 acc: 87.61 time: 6.97
# TESTING:
# Accuracy of the network on the 10000 test images: 83.40 %
# Average loss on the 10000 test images: 1.173
# [49,   100] loss: 1.099 acc: 87.06 time: 6.79
# [49,   200] loss: 1.101 acc: 87.10 time: 7.01
# [49,   300] loss: 1.101 acc: 87.02 time: 7.72
# TESTING:
# Accuracy of the network on the 10000 test images: 83.29 %
# Average loss on the 10000 test images: 1.173
# [50,   100] loss: 1.101 acc: 87.21 time: 13.11
# [50,   200] loss: 1.101 acc: 87.25 time: 12.04
# [50,   300] loss: 1.099 acc: 87.23 time: 6.09
# TESTING:
# Accuracy of the network on the 10000 test images: 83.45 %
# Average loss on the 10000 test images: 1.173
# Finished Training

# %% [markdown]
# # Write report (37 points)
#
# 本次作業主要有3個tasks需要大家完成，在A4.pdf中有希望大家達成的baseline **(不能低於baseline最多2%，沒有達到不會給全部分數)**，report的撰寫就希望大家可以透過去調整不同的訓練方法、損失函數、優化器，或者是調整凍結不同的層來進行這次的實驗，就請大家將嘗試的結果寫在report裡，祝大家順利！
#
# - Rotation task (13 points)
# - Fine-tuning the specified layers of the pre-trained model (12 points)
# - Fine-tuning the whole pre-trained model (12 points)

# %% [markdown]
# # Extra Credit (13 points)
#
# 上面基本的code跟report最高可以拿到87分，這個加分部分並沒有要求同學們一定要做，若同學們想要獲得更高的分數可以根據以下的加分要求來獲得加分。
#
# - In Figure 5(b) from the Gidaris et al. paper, the authors show a plot of CIFAR10 classification performance vs. number of training examples per category for a supervised CIFAR10 model vs. a RotNet model with the final layers fine-tuned on CIFAR10. The plot shows that pre-training on the Rotation task can be advantageous when only a small amount of labeled data is available. Using your RotNet fine-tuning code and supervised CIFAR10 training code from the main assignment, try to create a similar plot by performing supervised fine-tuning/training on only a subset of CIFAR10.
# - Use a more advanced model than ResNet18 to try to get higher accuracy on the rotation prediction task, as well as for transfer to supervised CIFAR10 classification.
#
# - If you have a good amount of compute at your disposal, try to train a rotation prediction model on the larger ImageNette dataset (still smaller than ImageNet, though).
