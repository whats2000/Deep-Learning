# %% [markdown]
# # MIS 583 Assignment 4: Self-supervised and transfer learning on CIFAR10

# %% [markdown]
# Before we start, please put your name and SID in following format: <br>
# : LASTNAME Firstname, ?00000000   //   e.g.) 李晨愷 M114020035

# %% [markdown]
# **Your Answer:**
# Hi I'm 鄔仁迪, B104020009.

# %%
import pandas as pd

experience_name = 'label_smoothing_1'
label_smoothing = 0.1

# Define columns for the DataFrame
columns = ['Experiment Type', 'Epoch', 'Train Accuracy', 'Train Loss', 'Valid Accuracy', 'Valid Loss']

# Initialize an empty DataFrame with these columns
experience_report = pd.DataFrame(columns=columns)

experience_report
# Out:
# Empty DataFrame
# Columns: [Experiment Type, Epoch, Train Accuracy, Train Loss, Valid Accuracy, Valid Loss]
# Index: []

# %% [markdown]
# ## Google Colab Setup
# Next we need to run a few commands to set up our environment on Google Colab. If you are running this notebook on a local machine you can skip this section.
#
# Run the following cell to mount your Google Drive. Follow the link, sign in to your Google account (the same account you used to store this notebook!) and copy the authorization code into the text box that appears below.

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# fill in the path in your Google Drive in the string below. Note: do not escape slashes or spaces
# import os
# datadir = "C:/Users/eddie/GitHub/Deep-Learning/PyTorch/Class/pytorch104"
# if not os.path.exists(datadir):
#  !ln -s "/content/drive/My Drive/Your/A4/path/" $datadir # TODO: Fill your A3 path
# os.chdir(datadir)
# !pwd

# %% [markdown]
# # Data Setup (5 points)
#
# The first thing to do is implement a dataset class to load rotated CIFAR10 images with matching labels. Since there is already a CIFAR10 dataset class implemented in `torchvision`, we will extend this class and modify the `__get_item__` method appropriately to load rotated images.
#
# Each rotation label should be an integer in the set {0, 1, 2, 3} which correspond to rotations of 0, 90, 180, or 270 degrees respectively.

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import random


def rotate_img(img, rot):
    if rot == 0: # 0 degrees rotation
        return img
    #######################################################################
    #        TODO: Implement rotate_img() - return the rotated img        #                           
    #######################################################################
    angles = {0: 0, 1: 90, 2: 180, 3: 270}
    if rot in angles:
        return transforms.functional.rotate(img, angles[rot])
    else:
        raise ValueError('rotation should be 0, 90, 180, or 270 degrees')

    #######################################################################
    #                           End of your code                          #
    #######################################################################

class CIFAR10Rotation(torchvision.datasets.CIFAR10):

    def __init__(self, root, train, download, transform) -> None:
        super().__init__(root=root, train=train, download=download, transform=transform)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index: int):
        image, cls_label = super().__getitem__(index)

        # randomly select image rotation
        rotation_label = random.choice([0, 1, 2, 3])
        image_rotated = rotate_img(image, rotation_label)

        rotation_label = torch.tensor(rotation_label).long()
        return image, image_rotated, rotation_label, torch.tensor(cls_label).long()

# %%
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

batch_size = 128

trainset = CIFAR10Rotation(root='data', train=True,
                                        download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=0)

testset = CIFAR10Rotation(root='data', train=False,
                                       download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=0)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# Show some example images and rotated images with labels:

# %%
import matplotlib.pyplot as plt

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

rot_classes = ('0', '90', '180', '270')


def imshow(img):
    # unnormalize
    img = transforms.Normalize((0, 0, 0), (1/0.2023, 1/0.1994, 1/0.2010))(img)
    img = transforms.Normalize((-0.4914, -0.4822, -0.4465), (1, 1, 1))(img)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


dataiter = iter(trainloader)
images, rot_images, rot_labels, labels = next(dataiter)

# print images and rotated images
img_grid = imshow(torchvision.utils.make_grid(images[:4], padding=0))
print('Class labels: ', ' '.join(f'{classes[labels[j]]:5s}' for j in range(4)))
img_grid = imshow(torchvision.utils.make_grid(rot_images[:4], padding=0))
print('Rotation labels: ', ' '.join(f'{rot_classes[rot_labels[j]]:5s}' for j in range(4)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Class labels:  dog   car   deer  car
# Rotation labels:  180   90    270   180

# %% [markdown]
# # Evaluation code

# %%
import time

def run_test(net, testloader, criterion, task):
    correct = 0
    total = 0
    avg_test_loss = 0.0
    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for images, images_rotated, labels, cls_labels in testloader:
            if task == 'rotation':
              images, labels = images_rotated.to(device), labels.to(device)
            elif task == 'classification':
              images, labels = images.to(device), cls_labels.to(device)
            #######################################################################
            # TODO: Calculate outputs by running images through the network       #
            # The class with the highest energy is what we choose as prediction   #
            #######################################################################
            # Calculate outputs by running images through the network
            outputs = net(images)

            # The class with the highest score is what we choose as our prediction
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            #######################################################################
            #                           End of your code                          #
            #######################################################################
            avg_test_loss += criterion(outputs, labels)  / len(testloader)
    print('TESTING:')
    print(f'Accuracy of the network on the 10000 test images: {100 * correct / total:.2f} %')
    print(f'Average loss on the 10000 test images: {avg_test_loss:.3f}')

    return avg_test_loss, 100 * correct / total

# %%
def adjust_learning_rate(optimizer, epoch, init_lr, decay_epochs=30):
    """Sets the learning rate to the initial LR decayed by 10 every 30 epochs"""
    lr = init_lr * (0.1 ** (epoch // decay_epochs))
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %% [markdown]
# # Train a ResNet18 on the rotation task (9 points)
#
# In this section, we will train a ResNet18 model **from scratch** on the rotation task. The input is a rotated image and the model predicts the rotation label. See the Data Setup section for details.

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %% [markdown]
# ### Notice: You should not use pretrained weights from ImageNet.

# %%
import torch.nn as nn
import torch.nn.functional as F

from torchvision.models import resnet18

net = resnet18(weights = None, num_classes=4) # Do not modify this line.
net = net.to(device)

# %%
import torch.nn as nn
import torch.optim as optim
################################################################################
# TODO: Define loss and optmizer functions                                     #
# Try any loss or optimizer function and learning rate to get better result    #
# hint: torch.nn and torch.optim                                               #
################################################################################
# Loss and optimizer
criterion = nn.CrossEntropyLoss(label_smoothing=label_smoothing)
learning_rate = 0.001
optimizer = optim.Adam(net.parameters(), lr=learning_rate)
################################################################################
#                               End of your code                               #
################################################################################
criterion = criterion.to(device)

# %%
# Both the self-supervised rotation task and supervised CIFAR10 classification are
# trained with the CrossEntropyLoss, so we can use the training loop code.

def train(net, criterion, optimizer, num_epochs, decay_epochs, init_lr, task, experiment_type=None):
    global experience_report
    for epoch in range(num_epochs):  # loop over the dataset multiple times
        # Initialize epoch variables
        total_loss = 0.0
        total_correct = 0.0
        total_samples = 0.0

        running_loss = 0.0
        running_correct = 0.0
        running_total = 0.0
        start_time = time.time()

        net.train()

        for i, (imgs, imgs_rotated, rotation_label, cls_label) in enumerate(trainloader, 0):
            adjust_learning_rate(optimizer, epoch, init_lr, decay_epochs)
            ######################################################################################################
            # TODO: Set the data to the correct device; Different task will use different inputs and labels      #  
            # TODO: Zero the parameter gradients                                                                 #
            # TODO: forward + backward + optimize                                                                #
            # TODO: Get predicted results                                                                        #
            ######################################################################################################
            # Set data to the correct device
            if task == 'rotation':
                inputs, labels = imgs_rotated.to(device), rotation_label.to(device)
            elif task == 'classification':
                inputs, labels = imgs.to(device), cls_label.to(device)

            optimizer.zero_grad()  # Zero the parameter gradients

            # Forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # Get predicted results for accuracy calculation
            _, predicted = torch.max(outputs.data, 1)
            ######################################################################################################
            #                               End of your code                                                     #
            ######################################################################################################

            # print statistics
            print_freq = 100
            running_loss += loss.item()

            # calc acc
            running_total += labels.size(0)
            running_correct += (predicted == labels).sum().item()

            # Update total counts for epoch averages
            total_loss += loss.item()
            total_samples += labels.size(0)
            total_correct += (predicted == labels).sum().item()

            if i % print_freq == (print_freq - 1):    # print every 2000 mini-batches
                print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / print_freq:.3f} acc: {100*running_correct / running_total:.2f} time: {time.time() - start_time:.2f}')
                running_loss, running_correct, running_total = 0.0, 0.0, 0.0
                start_time = time.time()
        ######################################################################################################
        # TODO: Run the run_test() function after each epoch; Set the model to the evaluation mode.          #
        ######################################################################################################
        # Calculate average training loss and accuracy for the epoch
        avg_train_loss = total_loss / len(trainloader)
        avg_train_acc = 100 * total_correct / total_samples

        # Evaluate the model after each epoch
        net.eval()
        test_loss, test_acc = run_test(net, testloader, criterion, task)

        # Append the epoch's results to the report DataFrame
        if experience_report is not None and experiment_type is not None:
            new_row = pd.DataFrame({
                'Experiment Type': [experiment_type],
                'Epoch': [epoch + 1],
                'Train Accuracy': [avg_train_acc.cpu().numpy()] if torch.is_tensor(avg_train_acc) else [avg_train_acc],
                'Train Loss': [avg_train_loss.cpu().numpy()] if torch.is_tensor(avg_train_loss) else [avg_train_loss],
                'Valid Accuracy': [test_acc.cpu().numpy()] if torch.is_tensor(test_acc) else [test_acc],
                'Valid Loss': [test_loss.cpu().numpy()] if torch.is_tensor(test_loss) else [test_loss]
            })
            experience_report = pd.concat([experience_report, new_row], ignore_index=True)
        ######################################################################################################
        #                               End of your code                                                     #
        ######################################################################################################

    # Save the report DataFrame after the experiment
    if experience_report is not None and experiment_type is not None:
        experience_report.to_csv(f'{experience_name}.csv', index=False)

    print('Finished Training')

# %%
from datetime import datetime

train(net, criterion, optimizer, num_epochs=45, decay_epochs=15, init_lr=0.01, task='rotation', experiment_type='Self-Supervise Rotation Model')
################################
#     TODO: Save the model     #  
################################
# Get current date and time
# Save the model
model_path = f"{experience_name}.pth"
torch.save(net.state_dict(), model_path)
################################
#      End of your code        #  
################################
# Out:
# [1,   100] loss: 1.556 acc: 29.55 time: 59.03
# [1,   200] loss: 1.306 acc: 42.19 time: 8.28
# [1,   300] loss: 1.256 acc: 44.70 time: 7.16
# TESTING:
# Accuracy of the network on the 10000 test images: 51.32 %
# Average loss on the 10000 test images: 1.163
# [2,   100] loss: 1.180 acc: 51.09 time: 6.82
# [2,   200] loss: 1.177 acc: 51.01 time: 7.36
# [2,   300] loss: 1.146 acc: 53.28 time: 12.14
# TESTING:
# Accuracy of the network on the 10000 test images: 56.04 %
# Average loss on the 10000 test images: 1.106
# [3,   100] loss: 1.130 acc: 54.12 time: 16.04
# [3,   200] loss: 1.120 acc: 55.16 time: 12.93
# [3,   300] loss: 1.093 acc: 56.81 time: 20.97
# TESTING:
# Accuracy of the network on the 10000 test images: 58.62 %
# Average loss on the 10000 test images: 1.071
# [4,   100] loss: 1.085 acc: 57.45 time: 12.46
# [4,   200] loss: 1.083 acc: 58.00 time: 6.65
# [4,   300] loss: 1.073 acc: 57.69 time: 6.69
# TESTING:
# Accuracy of the network on the 10000 test images: 59.61 %
# Average loss on the 10000 test images: 1.049
# [5,   100] loss: 1.051 acc: 60.45 time: 6.55
# [5,   200] loss: 1.052 acc: 59.66 time: 6.64
# [5,   300] loss: 1.035 acc: 60.82 time: 7.14
# TESTING:
# Accuracy of the network on the 10000 test images: 62.30 %
# Average loss on the 10000 test images: 1.019
# [6,   100] loss: 1.032 acc: 61.54 time: 6.70
# [6,   200] loss: 1.019 acc: 62.11 time: 7.45
# [6,   300] loss: 1.014 acc: 62.63 time: 7.18
# TESTING:
# Accuracy of the network on the 10000 test images: 62.77 %
# Average loss on the 10000 test images: 1.013
# [7,   100] loss: 1.000 acc: 63.09 time: 6.93
# [7,   200] loss: 1.005 acc: 62.81 time: 7.78
# [7,   300] loss: 0.990 acc: 64.02 time: 7.33
# TESTING:
# Accuracy of the network on the 10000 test images: 65.28 %
# Average loss on the 10000 test images: 0.957
# [8,   100] loss: 0.984 acc: 64.36 time: 6.39
# [8,   200] loss: 0.987 acc: 63.72 time: 6.92
# [8,   300] loss: 0.982 acc: 64.25 time: 6.83
# TESTING:
# Accuracy of the network on the 10000 test images: 63.31 %
# Average loss on the 10000 test images: 1.005
# [9,   100] loss: 0.963 acc: 65.50 time: 6.80
# [9,   200] loss: 0.970 acc: 64.92 time: 8.20
# [9,   300] loss: 0.964 acc: 65.61 time: 7.57
# TESTING:
# Accuracy of the network on the 10000 test images: 64.94 %
# Average loss on the 10000 test images: 0.967
# [10,   100] loss: 0.962 acc: 65.15 time: 6.74
# [10,   200] loss: 0.950 acc: 65.96 time: 6.98
# [10,   300] loss: 0.944 acc: 66.95 time: 7.25
# TESTING:
# Accuracy of the network on the 10000 test images: 67.28 %
# Average loss on the 10000 test images: 0.932
# [11,   100] loss: 0.944 acc: 66.99 time: 7.07
# [11,   200] loss: 0.932 acc: 67.63 time: 6.46
# [11,   300] loss: 0.941 acc: 66.67 time: 6.82
# TESTING:
# Accuracy of the network on the 10000 test images: 68.25 %
# Average loss on the 10000 test images: 0.917
# [12,   100] loss: 0.920 acc: 68.28 time: 6.67
# [12,   200] loss: 0.915 acc: 68.30 time: 6.52
# [12,   300] loss: 0.919 acc: 68.35 time: 7.39
# TESTING:
# Accuracy of the network on the 10000 test images: 68.30 %
# Average loss on the 10000 test images: 0.944
# [13,   100] loss: 0.911 acc: 68.82 time: 7.20
# [13,   200] loss: 0.905 acc: 68.84 time: 6.85
# [13,   300] loss: 0.900 acc: 68.93 time: 7.96
# TESTING:
# Accuracy of the network on the 10000 test images: 70.30 %
# Average loss on the 10000 test images: 0.880
# [14,   100] loss: 0.893 acc: 69.70 time: 6.61
# [14,   200] loss: 0.899 acc: 69.63 time: 7.49
# [14,   300] loss: 0.878 acc: 70.73 time: 6.61
# TESTING:
# Accuracy of the network on the 10000 test images: 71.87 %
# Average loss on the 10000 test images: 0.854
# [15,   100] loss: 0.871 acc: 71.19 time: 6.88
# [15,   200] loss: 0.884 acc: 70.77 time: 6.58
# [15,   300] loss: 0.871 acc: 71.14 time: 7.74
# TESTING:
# Accuracy of the network on the 10000 test images: 70.04 %
# Average loss on the 10000 test images: 0.896
# [16,   100] loss: 0.828 acc: 73.68 time: 6.80
# [16,   200] loss: 0.824 acc: 74.21 time: 6.78
# [16,   300] loss: 0.814 acc: 74.47 time: 6.56
# TESTING:
# Accuracy of the network on the 10000 test images: 75.47 %
# Average loss on the 10000 test images: 0.793
# [17,   100] loss: 0.808 acc: 74.95 time: 6.79
# [17,   200] loss: 0.809 acc: 74.73 time: 6.88
# [17,   300] loss: 0.805 acc: 75.29 time: 6.78
# TESTING:
# Accuracy of the network on the 10000 test images: 76.51 %
# Average loss on the 10000 test images: 0.781
# [18,   100] loss: 0.791 acc: 75.72 time: 7.57
# [18,   200] loss: 0.794 acc: 75.59 time: 7.42
# [18,   300] loss: 0.802 acc: 75.16 time: 7.02
# TESTING:
# Accuracy of the network on the 10000 test images: 76.82 %
# Average loss on the 10000 test images: 0.775
# [19,   100] loss: 0.793 acc: 75.38 time: 7.05
# [19,   200] loss: 0.792 acc: 75.70 time: 7.19
# [19,   300] loss: 0.782 acc: 76.40 time: 7.45
# TESTING:
# Accuracy of the network on the 10000 test images: 76.53 %
# Average loss on the 10000 test images: 0.775
# [20,   100] loss: 0.783 acc: 76.37 time: 7.05
# [20,   200] loss: 0.792 acc: 75.95 time: 7.08
# [20,   300] loss: 0.784 acc: 75.99 time: 7.07
# TESTING:
# Accuracy of the network on the 10000 test images: 77.45 %
# Average loss on the 10000 test images: 0.767
# [21,   100] loss: 0.782 acc: 76.16 time: 7.19
# [21,   200] loss: 0.780 acc: 76.70 time: 7.45
# [21,   300] loss: 0.775 acc: 76.58 time: 7.13
# TESTING:
# Accuracy of the network on the 10000 test images: 76.74 %
# Average loss on the 10000 test images: 0.770
# [22,   100] loss: 0.781 acc: 76.23 time: 7.14
# [22,   200] loss: 0.767 acc: 77.20 time: 6.89
# [22,   300] loss: 0.772 acc: 76.94 time: 6.56
# TESTING:
# Accuracy of the network on the 10000 test images: 77.61 %
# Average loss on the 10000 test images: 0.762
# [23,   100] loss: 0.771 acc: 77.26 time: 7.06
# [23,   200] loss: 0.764 acc: 77.13 time: 6.96
# [23,   300] loss: 0.779 acc: 76.47 time: 7.73
# TESTING:
# Accuracy of the network on the 10000 test images: 77.58 %
# Average loss on the 10000 test images: 0.760
# [24,   100] loss: 0.766 acc: 77.66 time: 7.59
# [24,   200] loss: 0.768 acc: 77.18 time: 7.20
# [24,   300] loss: 0.774 acc: 77.21 time: 7.42
# TESTING:
# Accuracy of the network on the 10000 test images: 77.70 %
# Average loss on the 10000 test images: 0.760
# [25,   100] loss: 0.771 acc: 77.05 time: 6.82
# [25,   200] loss: 0.770 acc: 77.14 time: 6.63
# [25,   300] loss: 0.762 acc: 77.80 time: 7.23
# TESTING:
# Accuracy of the network on the 10000 test images: 78.34 %
# Average loss on the 10000 test images: 0.754
# [26,   100] loss: 0.768 acc: 77.24 time: 7.00
# [26,   200] loss: 0.760 acc: 77.41 time: 6.69
# [26,   300] loss: 0.765 acc: 77.80 time: 6.61
# TESTING:
# Accuracy of the network on the 10000 test images: 77.83 %
# Average loss on the 10000 test images: 0.757
# [27,   100] loss: 0.753 acc: 78.22 time: 7.16
# [27,   200] loss: 0.757 acc: 77.80 time: 7.61
# [27,   300] loss: 0.759 acc: 77.54 time: 7.13
# TESTING:
# Accuracy of the network on the 10000 test images: 78.28 %
# Average loss on the 10000 test images: 0.748
# [28,   100] loss: 0.755 acc: 77.59 time: 7.35
# [28,   200] loss: 0.749 acc: 78.73 time: 7.35
# [28,   300] loss: 0.760 acc: 77.81 time: 8.00
# TESTING:
# Accuracy of the network on the 10000 test images: 78.21 %
# Average loss on the 10000 test images: 0.748
# [29,   100] loss: 0.755 acc: 77.98 time: 6.82
# [29,   200] loss: 0.746 acc: 78.40 time: 7.36
# [29,   300] loss: 0.751 acc: 78.40 time: 7.55
# TESTING:
# Accuracy of the network on the 10000 test images: 78.75 %
# Average loss on the 10000 test images: 0.744
# [30,   100] loss: 0.751 acc: 78.34 time: 6.93
# [30,   200] loss: 0.751 acc: 77.79 time: 7.27
# [30,   300] loss: 0.749 acc: 78.23 time: 7.81
# TESTING:
# Accuracy of the network on the 10000 test images: 78.56 %
# Average loss on the 10000 test images: 0.746
# [31,   100] loss: 0.746 acc: 78.73 time: 7.48
# [31,   200] loss: 0.748 acc: 78.35 time: 7.54
# [31,   300] loss: 0.735 acc: 79.18 time: 6.96
# TESTING:
# Accuracy of the network on the 10000 test images: 78.67 %
# Average loss on the 10000 test images: 0.737
# [32,   100] loss: 0.742 acc: 78.58 time: 7.37
# [32,   200] loss: 0.740 acc: 78.73 time: 6.80
# [32,   300] loss: 0.741 acc: 78.63 time: 6.85
# TESTING:
# Accuracy of the network on the 10000 test images: 79.02 %
# Average loss on the 10000 test images: 0.735
# [33,   100] loss: 0.733 acc: 79.23 time: 6.82
# [33,   200] loss: 0.739 acc: 78.85 time: 6.89
# [33,   300] loss: 0.747 acc: 78.51 time: 7.12
# TESTING:
# Accuracy of the network on the 10000 test images: 79.00 %
# Average loss on the 10000 test images: 0.731
# [34,   100] loss: 0.737 acc: 79.16 time: 7.82
# [34,   200] loss: 0.738 acc: 78.62 time: 6.85
# [34,   300] loss: 0.743 acc: 78.73 time: 7.49
# TESTING:
# Accuracy of the network on the 10000 test images: 79.25 %
# Average loss on the 10000 test images: 0.734
# [35,   100] loss: 0.737 acc: 78.95 time: 7.64
# [35,   200] loss: 0.738 acc: 79.18 time: 6.72
# [35,   300] loss: 0.739 acc: 79.16 time: 7.11
# TESTING:
# Accuracy of the network on the 10000 test images: 79.48 %
# Average loss on the 10000 test images: 0.731
# [36,   100] loss: 0.730 acc: 79.39 time: 7.42
# [36,   200] loss: 0.735 acc: 79.23 time: 7.14
# [36,   300] loss: 0.735 acc: 79.06 time: 6.97
# TESTING:
# Accuracy of the network on the 10000 test images: 79.55 %
# Average loss on the 10000 test images: 0.729
# [37,   100] loss: 0.735 acc: 78.88 time: 7.95
# [37,   200] loss: 0.740 acc: 78.72 time: 7.01
# [37,   300] loss: 0.733 acc: 79.32 time: 6.72
# TESTING:
# Accuracy of the network on the 10000 test images: 79.14 %
# Average loss on the 10000 test images: 0.731
# [38,   100] loss: 0.737 acc: 78.88 time: 6.87
# [38,   200] loss: 0.741 acc: 78.77 time: 6.61
# [38,   300] loss: 0.735 acc: 79.04 time: 7.03
# TESTING:
# Accuracy of the network on the 10000 test images: 79.42 %
# Average loss on the 10000 test images: 0.733
# [39,   100] loss: 0.731 acc: 79.21 time: 7.14
# [39,   200] loss: 0.730 acc: 79.27 time: 7.06
# [39,   300] loss: 0.736 acc: 78.97 time: 7.21
# TESTING:
# Accuracy of the network on the 10000 test images: 78.88 %
# Average loss on the 10000 test images: 0.734
# [40,   100] loss: 0.739 acc: 79.02 time: 7.35
# [40,   200] loss: 0.734 acc: 79.12 time: 6.96
# [40,   300] loss: 0.731 acc: 79.28 time: 8.02
# TESTING:
# Accuracy of the network on the 10000 test images: 79.06 %
# Average loss on the 10000 test images: 0.733
# [41,   100] loss: 0.734 acc: 79.10 time: 7.61
# [41,   200] loss: 0.734 acc: 78.75 time: 7.94
# [41,   300] loss: 0.735 acc: 79.03 time: 7.48
# TESTING:
# Accuracy of the network on the 10000 test images: 79.28 %
# Average loss on the 10000 test images: 0.733
# [42,   100] loss: 0.722 acc: 79.80 time: 7.70
# [42,   200] loss: 0.731 acc: 79.27 time: 7.31
# [42,   300] loss: 0.741 acc: 78.95 time: 7.09
# TESTING:
# Accuracy of the network on the 10000 test images: 79.28 %
# Average loss on the 10000 test images: 0.728
# [43,   100] loss: 0.722 acc: 79.89 time: 7.81
# [43,   200] loss: 0.730 acc: 79.77 time: 7.25
# [43,   300] loss: 0.738 acc: 78.74 time: 6.94
# TESTING:
# Accuracy of the network on the 10000 test images: 78.92 %
# Average loss on the 10000 test images: 0.732
# [44,   100] loss: 0.729 acc: 79.36 time: 7.46
# [44,   200] loss: 0.741 acc: 78.55 time: 7.37
# [44,   300] loss: 0.731 acc: 79.25 time: 6.63
# TESTING:
# Accuracy of the network on the 10000 test images: 79.21 %
# Average loss on the 10000 test images: 0.734
# [45,   100] loss: 0.734 acc: 79.05 time: 6.97
# [45,   200] loss: 0.734 acc: 79.51 time: 7.62
# [45,   300] loss: 0.730 acc: 79.64 time: 7.51
# TESTING:
# Accuracy of the network on the 10000 test images: 79.10 %
# Average loss on the 10000 test images: 0.734
# Finished Training

# %% [markdown]
# ## Fine-tuning on the pre-trained model (9 points)
#
# In this section, we will load the ResNet18 model pre-trained on the rotation task and fine-tune on the classification task. We will freeze all previous layers except for the 'layer4' block and 'fc' layer.
#
# **Then we will use the trained model from rotation task as the pretrained weights. Notice, you should not use the pretrained weights from ImageNet.**

# %%
import torch.nn as nn
import torch.nn.functional as F

from torchvision.models import resnet18

#####################################################
#     TODO: Load the pre-trained ResNet18 model     #  
#####################################################
# load the trained classifier weights
ckpt = torch.load(f"model_2023-11-02-23-22-09.pth")
net.load_state_dict(ckpt)
####################################################
#                End of your code                  #   
####################################################
# Out:
# <All keys matched successfully>

# %%
#################################################################################################
#   TODO: Freeze all previous layers; only keep the 'layer4' block and 'fc' layer trainable     #
#################################################################################################
# Freeze all parameters
net.requires_grad_(False)

# Adjusting the fully connected layer to have 10 outputs for 10 classes
net.fc = nn.Linear(net.fc.in_features, 10)  # Re-define the fc layer

# Unfreeze the last block (layer4) and the fully connected (fc) layer
net.layer4.requires_grad_(True)
net.fc.requires_grad_(True)

# Make sure to move the model to the device after modifying it
net.to(device)
#################################################################################################
#                                          End of your code                                     #
#################################################################################################
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
# Print all the trainable parameters
params_to_update = net.parameters()
print("Params to learn:")
params_to_update = []
for name,param in net.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name)
# Out:
# Params to learn:
# 	 layer4.0.conv1.weight
# 	 layer4.0.bn1.weight
# 	 layer4.0.bn1.bias
# 	 layer4.0.conv2.weight
# 	 layer4.0.bn2.weight
# 	 layer4.0.bn2.bias
# 	 layer4.0.downsample.0.weight
# 	 layer4.0.downsample.1.weight
# 	 layer4.0.downsample.1.bias
# 	 layer4.1.conv1.weight
# 	 layer4.1.bn1.weight
# 	 layer4.1.bn1.bias
# 	 layer4.1.conv2.weight
# 	 layer4.1.bn2.weight
# 	 layer4.1.bn2.bias
# 	 fc.weight
# 	 fc.bias

# %%
# TODO: Define criterion and optimizer
# Note that your optimizer only needs to update the parameters that are trainable.
criterion = nn.CrossEntropyLoss(label_smoothing=label_smoothing)

# Optimizer: Update only the parameters of layer4 and fc
optimizer = optim.Adam([
    {'params': net.layer4.parameters()},
    {'params': net.fc.parameters()}
], lr=0.001)

criterion.to(device)
# Out:
# CrossEntropyLoss()

# %%
train(net, criterion, optimizer, num_epochs=50, decay_epochs=10, init_lr=0.01, task='classification', experiment_type='Fine-tuning Pre-trained Model')
# Out:
# [1,   100] loss: 1.957 acc: 29.51 time: 6.76
# [1,   200] loss: 1.749 acc: 41.28 time: 6.62
# [1,   300] loss: 1.682 acc: 44.94 time: 6.66
# TESTING:
# Accuracy of the network on the 10000 test images: 49.13 %
# Average loss on the 10000 test images: 1.586
# [2,   100] loss: 1.626 acc: 47.26 time: 6.56
# [2,   200] loss: 1.625 acc: 47.28 time: 6.40
# [2,   300] loss: 1.589 acc: 49.48 time: 6.13
# TESTING:
# Accuracy of the network on the 10000 test images: 52.44 %
# Average loss on the 10000 test images: 1.528
# [3,   100] loss: 1.572 acc: 49.97 time: 6.62
# [3,   200] loss: 1.568 acc: 50.22 time: 6.00
# [3,   300] loss: 1.553 acc: 50.88 time: 6.37
# TESTING:
# Accuracy of the network on the 10000 test images: 54.09 %
# Average loss on the 10000 test images: 1.489
# [4,   100] loss: 1.539 acc: 51.94 time: 5.99
# [4,   200] loss: 1.549 acc: 51.69 time: 6.21
# [4,   300] loss: 1.545 acc: 51.34 time: 6.49
# TESTING:
# Accuracy of the network on the 10000 test images: 53.93 %
# Average loss on the 10000 test images: 1.503
# [5,   100] loss: 1.538 acc: 51.54 time: 5.97
# [5,   200] loss: 1.522 acc: 52.53 time: 6.28
# [5,   300] loss: 1.530 acc: 52.69 time: 6.22
# TESTING:
# Accuracy of the network on the 10000 test images: 53.24 %
# Average loss on the 10000 test images: 1.514
# [6,   100] loss: 1.506 acc: 53.31 time: 6.00
# [6,   200] loss: 1.528 acc: 52.25 time: 6.28
# [6,   300] loss: 1.515 acc: 52.53 time: 6.24
# TESTING:
# Accuracy of the network on the 10000 test images: 54.52 %
# Average loss on the 10000 test images: 1.482
# [7,   100] loss: 1.509 acc: 53.07 time: 6.08
# [7,   200] loss: 1.497 acc: 53.95 time: 5.98
# [7,   300] loss: 1.509 acc: 53.70 time: 6.14
# TESTING:
# Accuracy of the network on the 10000 test images: 55.02 %
# Average loss on the 10000 test images: 1.479
# [8,   100] loss: 1.509 acc: 53.32 time: 6.36
# [8,   200] loss: 1.505 acc: 53.18 time: 6.20
# [8,   300] loss: 1.493 acc: 53.89 time: 5.79
# TESTING:
# Accuracy of the network on the 10000 test images: 55.42 %
# Average loss on the 10000 test images: 1.461
# [9,   100] loss: 1.500 acc: 54.36 time: 11.48
# [9,   200] loss: 1.494 acc: 53.54 time: 10.89
# [9,   300] loss: 1.492 acc: 54.18 time: 6.65
# TESTING:
# Accuracy of the network on the 10000 test images: 56.22 %
# Average loss on the 10000 test images: 1.451
# [10,   100] loss: 1.482 acc: 54.47 time: 6.54
# [10,   200] loss: 1.492 acc: 53.91 time: 5.99
# [10,   300] loss: 1.484 acc: 54.52 time: 5.74
# TESTING:
# Accuracy of the network on the 10000 test images: 54.49 %
# Average loss on the 10000 test images: 1.485
# [11,   100] loss: 1.447 acc: 56.77 time: 5.90
# [11,   200] loss: 1.432 acc: 56.37 time: 6.20
# [11,   300] loss: 1.446 acc: 56.33 time: 6.39
# TESTING:
# Accuracy of the network on the 10000 test images: 58.89 %
# Average loss on the 10000 test images: 1.394
# [12,   100] loss: 1.427 acc: 57.29 time: 6.29
# [12,   200] loss: 1.444 acc: 56.27 time: 6.21
# [12,   300] loss: 1.433 acc: 56.74 time: 6.45
# TESTING:
# Accuracy of the network on the 10000 test images: 58.87 %
# Average loss on the 10000 test images: 1.392
# [13,   100] loss: 1.424 acc: 57.14 time: 6.34
# [13,   200] loss: 1.436 acc: 56.95 time: 6.02
# [13,   300] loss: 1.424 acc: 57.50 time: 5.96
# TESTING:
# Accuracy of the network on the 10000 test images: 59.44 %
# Average loss on the 10000 test images: 1.381
# [14,   100] loss: 1.431 acc: 56.80 time: 6.38
# [14,   200] loss: 1.422 acc: 56.95 time: 5.79
# [14,   300] loss: 1.409 acc: 57.54 time: 5.91
# TESTING:
# Accuracy of the network on the 10000 test images: 59.25 %
# Average loss on the 10000 test images: 1.381
# [15,   100] loss: 1.415 acc: 57.52 time: 13.15
# [15,   200] loss: 1.422 acc: 57.45 time: 11.85
# [15,   300] loss: 1.420 acc: 57.34 time: 8.17
# TESTING:
# Accuracy of the network on the 10000 test images: 59.27 %
# Average loss on the 10000 test images: 1.382
# [16,   100] loss: 1.413 acc: 57.91 time: 6.98
# [16,   200] loss: 1.424 acc: 57.09 time: 6.54
# [16,   300] loss: 1.428 acc: 56.87 time: 6.86
# TESTING:
# Accuracy of the network on the 10000 test images: 59.27 %
# Average loss on the 10000 test images: 1.378
# [17,   100] loss: 1.430 acc: 56.98 time: 7.91
# [17,   200] loss: 1.407 acc: 58.22 time: 8.30
# [17,   300] loss: 1.416 acc: 57.48 time: 6.71
# TESTING:
# Accuracy of the network on the 10000 test images: 59.38 %
# Average loss on the 10000 test images: 1.378
# [18,   100] loss: 1.412 acc: 57.67 time: 6.39
# [18,   200] loss: 1.421 acc: 56.70 time: 6.36
# [18,   300] loss: 1.414 acc: 57.37 time: 6.86
# TESTING:
# Accuracy of the network on the 10000 test images: 59.54 %
# Average loss on the 10000 test images: 1.375
# [19,   100] loss: 1.407 acc: 57.90 time: 6.08
# [19,   200] loss: 1.407 acc: 57.62 time: 6.15
# [19,   300] loss: 1.416 acc: 58.08 time: 5.90
# TESTING:
# Accuracy of the network on the 10000 test images: 59.65 %
# Average loss on the 10000 test images: 1.376
# [20,   100] loss: 1.417 acc: 57.55 time: 5.95
# [20,   200] loss: 1.408 acc: 57.77 time: 5.87
# [20,   300] loss: 1.413 acc: 57.91 time: 6.05
# TESTING:
# Accuracy of the network on the 10000 test images: 59.67 %
# Average loss on the 10000 test images: 1.377
# [21,   100] loss: 1.406 acc: 58.13 time: 6.03
# [21,   200] loss: 1.410 acc: 57.80 time: 6.00
# [21,   300] loss: 1.410 acc: 57.80 time: 5.94
# TESTING:
# Accuracy of the network on the 10000 test images: 59.81 %
# Average loss on the 10000 test images: 1.372
# [22,   100] loss: 1.406 acc: 58.02 time: 6.14
# [22,   200] loss: 1.403 acc: 58.43 time: 6.38
# [22,   300] loss: 1.404 acc: 57.95 time: 5.89
# TESTING:
# Accuracy of the network on the 10000 test images: 59.63 %
# Average loss on the 10000 test images: 1.370
# [23,   100] loss: 1.409 acc: 57.81 time: 5.93
# [23,   200] loss: 1.409 acc: 58.07 time: 6.05
# [23,   300] loss: 1.402 acc: 58.33 time: 5.82
# TESTING:
# Accuracy of the network on the 10000 test images: 59.90 %
# Average loss on the 10000 test images: 1.372
# [24,   100] loss: 1.401 acc: 58.16 time: 5.99
# [24,   200] loss: 1.397 acc: 58.61 time: 6.30
# [24,   300] loss: 1.419 acc: 57.59 time: 5.97
# TESTING:
# Accuracy of the network on the 10000 test images: 59.81 %
# Average loss on the 10000 test images: 1.373
# [25,   100] loss: 1.407 acc: 58.05 time: 6.30
# [25,   200] loss: 1.402 acc: 58.46 time: 6.24
# [25,   300] loss: 1.405 acc: 58.14 time: 6.40
# TESTING:
# Accuracy of the network on the 10000 test images: 59.92 %
# Average loss on the 10000 test images: 1.370
# [26,   100] loss: 1.393 acc: 58.57 time: 6.17
# [26,   200] loss: 1.407 acc: 58.09 time: 6.62
# [26,   300] loss: 1.403 acc: 58.12 time: 7.04
# TESTING:
# Accuracy of the network on the 10000 test images: 59.57 %
# Average loss on the 10000 test images: 1.371
# [27,   100] loss: 1.405 acc: 57.52 time: 6.07
# [27,   200] loss: 1.409 acc: 57.66 time: 6.19
# [27,   300] loss: 1.389 acc: 58.97 time: 5.80
# TESTING:
# Accuracy of the network on the 10000 test images: 60.12 %
# Average loss on the 10000 test images: 1.369
# [28,   100] loss: 1.405 acc: 57.80 time: 6.13
# [28,   200] loss: 1.406 acc: 58.01 time: 6.35
# [28,   300] loss: 1.403 acc: 58.25 time: 6.03
# TESTING:
# Accuracy of the network on the 10000 test images: 59.72 %
# Average loss on the 10000 test images: 1.371
# [29,   100] loss: 1.407 acc: 57.87 time: 6.06
# [29,   200] loss: 1.404 acc: 58.44 time: 6.10
# [29,   300] loss: 1.401 acc: 58.26 time: 5.91
# TESTING:
# Accuracy of the network on the 10000 test images: 59.85 %
# Average loss on the 10000 test images: 1.371
# [30,   100] loss: 1.405 acc: 58.19 time: 6.13
# [30,   200] loss: 1.399 acc: 57.81 time: 6.04
# [30,   300] loss: 1.402 acc: 58.44 time: 6.21
# TESTING:
# Accuracy of the network on the 10000 test images: 59.94 %
# Average loss on the 10000 test images: 1.370
# [31,   100] loss: 1.399 acc: 58.16 time: 6.35
# [31,   200] loss: 1.406 acc: 58.05 time: 6.34
# [31,   300] loss: 1.412 acc: 57.74 time: 6.07
# TESTING:
# Accuracy of the network on the 10000 test images: 59.97 %
# Average loss on the 10000 test images: 1.368
# [32,   100] loss: 1.403 acc: 57.95 time: 6.08
# [32,   200] loss: 1.405 acc: 57.99 time: 6.24
# [32,   300] loss: 1.399 acc: 58.24 time: 6.24
# TESTING:
# Accuracy of the network on the 10000 test images: 59.85 %
# Average loss on the 10000 test images: 1.368
# [33,   100] loss: 1.407 acc: 58.27 time: 6.80
# [33,   200] loss: 1.402 acc: 58.20 time: 5.86
# [33,   300] loss: 1.405 acc: 57.98 time: 6.03
# TESTING:
# Accuracy of the network on the 10000 test images: 59.82 %
# Average loss on the 10000 test images: 1.371
# [34,   100] loss: 1.405 acc: 58.12 time: 5.99
# [34,   200] loss: 1.401 acc: 58.09 time: 5.97
# [34,   300] loss: 1.403 acc: 58.50 time: 6.26
# TESTING:
# Accuracy of the network on the 10000 test images: 59.73 %
# Average loss on the 10000 test images: 1.369
# [35,   100] loss: 1.405 acc: 57.71 time: 6.32
# [35,   200] loss: 1.405 acc: 58.03 time: 6.31
# [35,   300] loss: 1.396 acc: 58.54 time: 5.86
# TESTING:
# Accuracy of the network on the 10000 test images: 59.53 %
# Average loss on the 10000 test images: 1.374
# [36,   100] loss: 1.404 acc: 57.85 time: 6.17
# [36,   200] loss: 1.401 acc: 58.25 time: 5.93
# [36,   300] loss: 1.400 acc: 57.88 time: 6.23
# TESTING:
# Accuracy of the network on the 10000 test images: 59.97 %
# Average loss on the 10000 test images: 1.369
# [37,   100] loss: 1.402 acc: 58.27 time: 6.14
# [37,   200] loss: 1.401 acc: 58.20 time: 6.02
# [37,   300] loss: 1.397 acc: 58.31 time: 6.08
# TESTING:
# Accuracy of the network on the 10000 test images: 59.75 %
# Average loss on the 10000 test images: 1.371
# [38,   100] loss: 1.409 acc: 57.86 time: 6.24
# [38,   200] loss: 1.397 acc: 58.28 time: 6.11
# [38,   300] loss: 1.407 acc: 58.33 time: 6.12
# TESTING:
# Accuracy of the network on the 10000 test images: 60.14 %
# Average loss on the 10000 test images: 1.366
# [39,   100] loss: 1.396 acc: 58.66 time: 6.15
# [39,   200] loss: 1.409 acc: 57.77 time: 6.23
# [39,   300] loss: 1.405 acc: 58.21 time: 6.07
# TESTING:
# Accuracy of the network on the 10000 test images: 59.94 %
# Average loss on the 10000 test images: 1.369
# [40,   100] loss: 1.397 acc: 58.66 time: 6.02
# [40,   200] loss: 1.392 acc: 58.48 time: 6.15
# [40,   300] loss: 1.410 acc: 57.71 time: 6.21
# TESTING:
# Accuracy of the network on the 10000 test images: 59.78 %
# Average loss on the 10000 test images: 1.371
# [41,   100] loss: 1.404 acc: 58.20 time: 6.26
# [41,   200] loss: 1.398 acc: 58.38 time: 5.89
# [41,   300] loss: 1.410 acc: 57.48 time: 5.80
# TESTING:
# Accuracy of the network on the 10000 test images: 59.75 %
# Average loss on the 10000 test images: 1.373
# [42,   100] loss: 1.407 acc: 58.34 time: 6.02
# [42,   200] loss: 1.405 acc: 58.04 time: 6.04
# [42,   300] loss: 1.409 acc: 57.80 time: 5.92
# TESTING:
# Accuracy of the network on the 10000 test images: 59.71 %
# Average loss on the 10000 test images: 1.371
# [43,   100] loss: 1.412 acc: 58.09 time: 6.02
# [43,   200] loss: 1.393 acc: 58.67 time: 5.70
# [43,   300] loss: 1.402 acc: 58.20 time: 6.01
# TESTING:
# Accuracy of the network on the 10000 test images: 59.58 %
# Average loss on the 10000 test images: 1.372
# [44,   100] loss: 1.407 acc: 58.13 time: 6.13
# [44,   200] loss: 1.412 acc: 58.09 time: 6.14
# [44,   300] loss: 1.400 acc: 58.16 time: 5.92
# TESTING:
# Accuracy of the network on the 10000 test images: 60.00 %
# Average loss on the 10000 test images: 1.367
# [45,   100] loss: 1.408 acc: 57.46 time: 6.03
# [45,   200] loss: 1.424 acc: 57.65 time: 6.19
# [45,   300] loss: 1.405 acc: 58.14 time: 6.16
# TESTING:
# Accuracy of the network on the 10000 test images: 59.57 %
# Average loss on the 10000 test images: 1.372
# [46,   100] loss: 1.406 acc: 58.16 time: 5.83
# [46,   200] loss: 1.395 acc: 58.57 time: 5.98
# [46,   300] loss: 1.403 acc: 58.27 time: 5.77
# TESTING:
# Accuracy of the network on the 10000 test images: 60.30 %
# Average loss on the 10000 test images: 1.364
# [47,   100] loss: 1.396 acc: 58.38 time: 6.47
# [47,   200] loss: 1.408 acc: 57.75 time: 6.33
# [47,   300] loss: 1.402 acc: 58.04 time: 6.40
# TESTING:
# Accuracy of the network on the 10000 test images: 60.07 %
# Average loss on the 10000 test images: 1.369
# [48,   100] loss: 1.402 acc: 58.16 time: 6.19
# [48,   200] loss: 1.406 acc: 57.70 time: 6.04
# [48,   300] loss: 1.400 acc: 58.65 time: 5.84
# TESTING:
# Accuracy of the network on the 10000 test images: 59.87 %
# Average loss on the 10000 test images: 1.371
# [49,   100] loss: 1.395 acc: 58.41 time: 5.98
# [49,   200] loss: 1.401 acc: 57.88 time: 5.97
# [49,   300] loss: 1.414 acc: 57.57 time: 6.30
# TESTING:
# Accuracy of the network on the 10000 test images: 60.05 %
# Average loss on the 10000 test images: 1.367
# [50,   100] loss: 1.403 acc: 58.43 time: 5.90
# [50,   200] loss: 1.410 acc: 57.58 time: 6.11
# [50,   300] loss: 1.390 acc: 58.52 time: 6.24
# TESTING:
# Accuracy of the network on the 10000 test images: 59.88 %
# Average loss on the 10000 test images: 1.371
# Finished Training

# %% [markdown]
# ## Fine-tuning on the randomly initialized model (9 points)
# In this section, we will randomly initialize a ResNet18 model and fine-tune on the classification task. We will freeze all previous layers except for the 'layer4' block and 'fc' layer.

# %%
import torch.nn as nn
import torch.nn.functional as F

from torchvision.models import resnet18
#################################################
# TODO: Randomly initialize a ResNet18 model    #
#################################################
# Randomly initialize a ResNet18 model
net = resnet18(pretrained=False)
#################################################
#              End of your code                 #
#################################################

# %%
#################################################################################################
# TODO: Freeze all previous layers; only keep the 'layer4' block and 'fc' layer trainable       #
# To do this, you should set requires_grad=False for the frozen layers.                         #
#################################################################################################
# Adjusting the fully connected layer for 10 classes
net.fc = nn.Linear(net.fc.in_features, 10)

# Freeze all layers in the randomly initialized model
net.requires_grad_(False)

# Unfreeze the last block (layer4) and the fully connected (fc) layer
net.layer4.requires_grad_(True)
net.fc.requires_grad_(True)

# Move the model to the device
net.to(device)
#################################################################################################
#                                          End of your code                                     #
#################################################################################################
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
# Print all the trainable parameters
params_to_update = net.parameters()
print("Params to learn:")
params_to_update = []
for name,param in net.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)
        print("\t",name)
# Out:
# Params to learn:
# 	 layer4.0.conv1.weight
# 	 layer4.0.bn1.weight
# 	 layer4.0.bn1.bias
# 	 layer4.0.conv2.weight
# 	 layer4.0.bn2.weight
# 	 layer4.0.bn2.bias
# 	 layer4.0.downsample.0.weight
# 	 layer4.0.downsample.1.weight
# 	 layer4.0.downsample.1.bias
# 	 layer4.1.conv1.weight
# 	 layer4.1.bn1.weight
# 	 layer4.1.bn1.bias
# 	 layer4.1.conv2.weight
# 	 layer4.1.bn2.weight
# 	 layer4.1.bn2.bias
# 	 fc.weight
# 	 fc.bias

# %%
# TODO: Define criterion and optimizer
# Note that your optimizer only needs to update the parameters that are trainable.
criterion = nn.CrossEntropyLoss(label_smoothing=label_smoothing)

# Optimizer: Update only the parameters of layer4 and fc
optimizer = optim.Adam([
    {'params': net.layer4.parameters()},
    {'params': net.fc.parameters()}
], lr=0.001)

criterion.to(device)
# Out:
# CrossEntropyLoss()

# %%
train(net, criterion, optimizer, num_epochs=50, decay_epochs=10, init_lr=0.01, task='classification', experiment_type='Fine-tuning Randomly Initialized Model')
# Out:
# [1,   100] loss: 2.337 acc: 23.89 time: 6.15
# [1,   200] loss: 2.036 acc: 29.86 time: 6.21
# [1,   300] loss: 1.979 acc: 32.23 time: 6.14
# TESTING:
# Accuracy of the network on the 10000 test images: 36.44 %
# Average loss on the 10000 test images: 1.883
# [2,   100] loss: 1.932 acc: 33.49 time: 6.00
# [2,   200] loss: 1.912 acc: 35.24 time: 5.94
# [2,   300] loss: 1.896 acc: 35.17 time: 5.74
# TESTING:
# Accuracy of the network on the 10000 test images: 39.48 %
# Average loss on the 10000 test images: 1.817
# [3,   100] loss: 1.884 acc: 36.27 time: 5.94
# [3,   200] loss: 1.875 acc: 36.62 time: 5.99
# [3,   300] loss: 1.876 acc: 36.19 time: 5.95
# TESTING:
# Accuracy of the network on the 10000 test images: 38.40 %
# Average loss on the 10000 test images: 1.821
# [4,   100] loss: 1.858 acc: 37.34 time: 6.34
# [4,   200] loss: 1.853 acc: 37.48 time: 6.18
# [4,   300] loss: 1.858 acc: 37.33 time: 6.15
# TESTING:
# Accuracy of the network on the 10000 test images: 40.37 %
# Average loss on the 10000 test images: 1.780
# [5,   100] loss: 1.846 acc: 37.99 time: 6.17
# [5,   200] loss: 1.850 acc: 37.66 time: 6.09
# [5,   300] loss: 1.841 acc: 38.30 time: 6.05
# TESTING:
# Accuracy of the network on the 10000 test images: 41.53 %
# Average loss on the 10000 test images: 1.769
# [6,   100] loss: 1.832 acc: 38.84 time: 6.11
# [6,   200] loss: 1.826 acc: 38.36 time: 6.27
# [6,   300] loss: 1.828 acc: 38.65 time: 6.10
# TESTING:
# Accuracy of the network on the 10000 test images: 41.82 %
# Average loss on the 10000 test images: 1.768
# [7,   100] loss: 1.821 acc: 39.57 time: 5.94
# [7,   200] loss: 1.821 acc: 38.75 time: 5.64
# [7,   300] loss: 1.829 acc: 39.34 time: 5.86
# TESTING:
# Accuracy of the network on the 10000 test images: 41.58 %
# Average loss on the 10000 test images: 1.763
# [8,   100] loss: 1.812 acc: 38.99 time: 6.16
# [8,   200] loss: 1.811 acc: 39.95 time: 5.80
# [8,   300] loss: 1.793 acc: 40.44 time: 5.66
# TESTING:
# Accuracy of the network on the 10000 test images: 41.15 %
# Average loss on the 10000 test images: 1.765
# [9,   100] loss: 1.804 acc: 39.92 time: 5.85
# [9,   200] loss: 1.793 acc: 40.99 time: 5.77
# [9,   300] loss: 1.791 acc: 41.08 time: 6.40
# TESTING:
# Accuracy of the network on the 10000 test images: 42.39 %
# Average loss on the 10000 test images: 1.752
# [10,   100] loss: 1.796 acc: 40.32 time: 6.12
# [10,   200] loss: 1.790 acc: 40.76 time: 5.95
# [10,   300] loss: 1.791 acc: 40.77 time: 5.86
# TESTING:
# Accuracy of the network on the 10000 test images: 43.07 %
# Average loss on the 10000 test images: 1.737
# [11,   100] loss: 1.771 acc: 41.66 time: 5.86
# [11,   200] loss: 1.760 acc: 42.12 time: 5.96
# [11,   300] loss: 1.756 acc: 42.25 time: 6.09
# TESTING:
# Accuracy of the network on the 10000 test images: 43.92 %
# Average loss on the 10000 test images: 1.717
# [12,   100] loss: 1.754 acc: 41.95 time: 6.13
# [12,   200] loss: 1.746 acc: 42.52 time: 5.87
# [12,   300] loss: 1.743 acc: 43.05 time: 5.79
# TESTING:
# Accuracy of the network on the 10000 test images: 43.84 %
# Average loss on the 10000 test images: 1.710
# [13,   100] loss: 1.738 acc: 42.89 time: 6.12
# [13,   200] loss: 1.743 acc: 43.08 time: 5.97
# [13,   300] loss: 1.737 acc: 43.52 time: 5.96
# TESTING:
# Accuracy of the network on the 10000 test images: 44.28 %
# Average loss on the 10000 test images: 1.709
# [14,   100] loss: 1.733 acc: 43.66 time: 6.17
# [14,   200] loss: 1.736 acc: 43.23 time: 6.36
# [14,   300] loss: 1.745 acc: 42.51 time: 6.08
# TESTING:
# Accuracy of the network on the 10000 test images: 44.74 %
# Average loss on the 10000 test images: 1.700
# [15,   100] loss: 1.738 acc: 43.46 time: 6.16
# [15,   200] loss: 1.738 acc: 42.75 time: 5.63
# [15,   300] loss: 1.733 acc: 43.72 time: 5.75
# TESTING:
# Accuracy of the network on the 10000 test images: 44.70 %
# Average loss on the 10000 test images: 1.698
# [16,   100] loss: 1.727 acc: 43.55 time: 6.41
# [16,   200] loss: 1.721 acc: 43.92 time: 5.87
# [16,   300] loss: 1.736 acc: 43.60 time: 6.03
# TESTING:
# Accuracy of the network on the 10000 test images: 45.24 %
# Average loss on the 10000 test images: 1.689
# [17,   100] loss: 1.728 acc: 43.48 time: 5.98
# [17,   200] loss: 1.715 acc: 44.38 time: 6.05
# [17,   300] loss: 1.734 acc: 44.07 time: 6.19
# TESTING:
# Accuracy of the network on the 10000 test images: 45.03 %
# Average loss on the 10000 test images: 1.685
# [18,   100] loss: 1.722 acc: 43.74 time: 6.07
# [18,   200] loss: 1.719 acc: 43.98 time: 5.85
# [18,   300] loss: 1.722 acc: 43.73 time: 6.19
# TESTING:
# Accuracy of the network on the 10000 test images: 44.74 %
# Average loss on the 10000 test images: 1.690
# [19,   100] loss: 1.709 acc: 44.23 time: 6.06
# [19,   200] loss: 1.712 acc: 44.43 time: 6.35
# [19,   300] loss: 1.713 acc: 44.23 time: 5.76
# TESTING:
# Accuracy of the network on the 10000 test images: 45.51 %
# Average loss on the 10000 test images: 1.684
# [20,   100] loss: 1.705 acc: 44.84 time: 6.03
# [20,   200] loss: 1.720 acc: 43.59 time: 6.37
# [20,   300] loss: 1.716 acc: 44.19 time: 6.26
# TESTING:
# Accuracy of the network on the 10000 test images: 45.36 %
# Average loss on the 10000 test images: 1.682
# [21,   100] loss: 1.713 acc: 44.45 time: 5.92
# [21,   200] loss: 1.701 acc: 45.55 time: 5.88
# [21,   300] loss: 1.708 acc: 44.06 time: 5.98
# TESTING:
# Accuracy of the network on the 10000 test images: 45.35 %
# Average loss on the 10000 test images: 1.682
# [22,   100] loss: 1.715 acc: 44.51 time: 6.09
# [22,   200] loss: 1.701 acc: 44.66 time: 6.07
# [22,   300] loss: 1.696 acc: 44.77 time: 5.93
# TESTING:
# Accuracy of the network on the 10000 test images: 45.49 %
# Average loss on the 10000 test images: 1.678
# [23,   100] loss: 1.701 acc: 44.72 time: 6.19
# [23,   200] loss: 1.716 acc: 44.05 time: 5.78
# [23,   300] loss: 1.714 acc: 43.84 time: 6.21
# TESTING:
# Accuracy of the network on the 10000 test images: 45.37 %
# Average loss on the 10000 test images: 1.678
# [24,   100] loss: 1.705 acc: 44.89 time: 6.15
# [24,   200] loss: 1.697 acc: 44.91 time: 5.94
# [24,   300] loss: 1.708 acc: 44.34 time: 6.05
# TESTING:
# Accuracy of the network on the 10000 test images: 45.59 %
# Average loss on the 10000 test images: 1.679
# [25,   100] loss: 1.695 acc: 45.34 time: 5.88
# [25,   200] loss: 1.707 acc: 45.21 time: 6.11
# [25,   300] loss: 1.702 acc: 44.69 time: 6.05
# TESTING:
# Accuracy of the network on the 10000 test images: 45.42 %
# Average loss on the 10000 test images: 1.679
# [26,   100] loss: 1.702 acc: 44.30 time: 5.87
# [26,   200] loss: 1.708 acc: 44.28 time: 6.03
# [26,   300] loss: 1.706 acc: 44.18 time: 5.84
# TESTING:
# Accuracy of the network on the 10000 test images: 45.30 %
# Average loss on the 10000 test images: 1.680
# [27,   100] loss: 1.709 acc: 44.77 time: 6.15
# [27,   200] loss: 1.713 acc: 44.15 time: 5.84
# [27,   300] loss: 1.705 acc: 44.99 time: 6.28
# TESTING:
# Accuracy of the network on the 10000 test images: 45.67 %
# Average loss on the 10000 test images: 1.678
# [28,   100] loss: 1.701 acc: 44.62 time: 6.20
# [28,   200] loss: 1.701 acc: 44.96 time: 6.05
# [28,   300] loss: 1.714 acc: 44.17 time: 6.10
# TESTING:
# Accuracy of the network on the 10000 test images: 45.53 %
# Average loss on the 10000 test images: 1.677
# [29,   100] loss: 1.698 acc: 45.26 time: 6.17
# [29,   200] loss: 1.720 acc: 43.62 time: 5.96
# [29,   300] loss: 1.703 acc: 44.15 time: 5.96
# TESTING:
# Accuracy of the network on the 10000 test images: 45.62 %
# Average loss on the 10000 test images: 1.676
# [30,   100] loss: 1.694 acc: 45.46 time: 5.94
# [30,   200] loss: 1.702 acc: 44.54 time: 6.27
# [30,   300] loss: 1.704 acc: 44.66 time: 5.64
# TESTING:
# Accuracy of the network on the 10000 test images: 45.57 %
# Average loss on the 10000 test images: 1.676
# [31,   100] loss: 1.712 acc: 44.03 time: 6.17
# [31,   200] loss: 1.706 acc: 44.87 time: 6.20
# [31,   300] loss: 1.700 acc: 44.80 time: 6.04
# TESTING:
# Accuracy of the network on the 10000 test images: 45.42 %
# Average loss on the 10000 test images: 1.678
# [32,   100] loss: 1.706 acc: 44.40 time: 5.94
# [32,   200] loss: 1.706 acc: 44.98 time: 6.22
# [32,   300] loss: 1.698 acc: 44.80 time: 6.14
# TESTING:
# Accuracy of the network on the 10000 test images: 45.65 %
# Average loss on the 10000 test images: 1.677
# [33,   100] loss: 1.714 acc: 43.95 time: 6.10
# [33,   200] loss: 1.704 acc: 44.50 time: 6.30
# [33,   300] loss: 1.691 acc: 45.89 time: 6.34
# TESTING:
# Accuracy of the network on the 10000 test images: 45.43 %
# Average loss on the 10000 test images: 1.676
# [34,   100] loss: 1.704 acc: 44.63 time: 5.98
# [34,   200] loss: 1.705 acc: 44.88 time: 6.16
# [34,   300] loss: 1.705 acc: 44.18 time: 5.87
# TESTING:
# Accuracy of the network on the 10000 test images: 45.59 %
# Average loss on the 10000 test images: 1.676
# [35,   100] loss: 1.701 acc: 44.49 time: 6.02
# [35,   200] loss: 1.696 acc: 44.77 time: 16.23
# [35,   300] loss: 1.705 acc: 45.06 time: 14.12
# TESTING:
# Accuracy of the network on the 10000 test images: 45.78 %
# Average loss on the 10000 test images: 1.675
# [36,   100] loss: 1.691 acc: 45.11 time: 6.02
# [36,   200] loss: 1.700 acc: 44.75 time: 6.03
# [36,   300] loss: 1.702 acc: 45.29 time: 5.90
# TESTING:
# Accuracy of the network on the 10000 test images: 45.73 %
# Average loss on the 10000 test images: 1.676
# [37,   100] loss: 1.700 acc: 44.70 time: 5.95
# [37,   200] loss: 1.701 acc: 44.89 time: 5.98
# [37,   300] loss: 1.700 acc: 45.04 time: 6.34
# TESTING:
# Accuracy of the network on the 10000 test images: 45.75 %
# Average loss on the 10000 test images: 1.675
# [38,   100] loss: 1.701 acc: 44.91 time: 6.18
# [38,   200] loss: 1.707 acc: 44.47 time: 5.99
# [38,   300] loss: 1.703 acc: 44.58 time: 5.77
# TESTING:
# Accuracy of the network on the 10000 test images: 45.65 %
# Average loss on the 10000 test images: 1.677
# [39,   100] loss: 1.695 acc: 45.37 time: 6.44
# [39,   200] loss: 1.705 acc: 44.52 time: 5.83
# [39,   300] loss: 1.708 acc: 44.16 time: 6.11
# TESTING:
# Accuracy of the network on the 10000 test images: 45.59 %
# Average loss on the 10000 test images: 1.678
# [40,   100] loss: 1.708 acc: 44.45 time: 6.05
# [40,   200] loss: 1.700 acc: 44.78 time: 5.89
# [40,   300] loss: 1.696 acc: 44.95 time: 6.21
# TESTING:
# Accuracy of the network on the 10000 test images: 45.76 %
# Average loss on the 10000 test images: 1.676
# [41,   100] loss: 1.704 acc: 44.99 time: 9.83
# [41,   200] loss: 1.695 acc: 45.44 time: 5.85
# [41,   300] loss: 1.706 acc: 44.60 time: 6.18
# TESTING:
# Accuracy of the network on the 10000 test images: 45.55 %
# Average loss on the 10000 test images: 1.677
# [42,   100] loss: 1.703 acc: 44.98 time: 6.14
# [42,   200] loss: 1.690 acc: 45.52 time: 5.82
# [42,   300] loss: 1.691 acc: 45.40 time: 6.14
# TESTING:
# Accuracy of the network on the 10000 test images: 45.62 %
# Average loss on the 10000 test images: 1.677
# [43,   100] loss: 1.708 acc: 44.43 time: 6.16
# [43,   200] loss: 1.700 acc: 44.62 time: 6.01
# [43,   300] loss: 1.699 acc: 45.34 time: 6.13
# TESTING:
# Accuracy of the network on the 10000 test images: 45.58 %
# Average loss on the 10000 test images: 1.675
# [44,   100] loss: 1.708 acc: 44.74 time: 6.23
# [44,   200] loss: 1.700 acc: 44.92 time: 6.07
# [44,   300] loss: 1.689 acc: 45.16 time: 6.38
# TESTING:
# Accuracy of the network on the 10000 test images: 45.72 %
# Average loss on the 10000 test images: 1.676
# [45,   100] loss: 1.702 acc: 45.06 time: 6.19
# [45,   200] loss: 1.714 acc: 44.10 time: 6.11
# [45,   300] loss: 1.709 acc: 44.41 time: 5.98
# TESTING:
# Accuracy of the network on the 10000 test images: 45.67 %
# Average loss on the 10000 test images: 1.675
# [46,   100] loss: 1.703 acc: 44.45 time: 6.27
# [46,   200] loss: 1.705 acc: 44.73 time: 6.56
# [46,   300] loss: 1.712 acc: 44.34 time: 6.34
# TESTING:
# Accuracy of the network on the 10000 test images: 45.68 %
# Average loss on the 10000 test images: 1.677
# [47,   100] loss: 1.698 acc: 45.62 time: 6.29
# [47,   200] loss: 1.699 acc: 44.83 time: 6.00
# [47,   300] loss: 1.697 acc: 44.56 time: 6.12
# TESTING:
# Accuracy of the network on the 10000 test images: 45.57 %
# Average loss on the 10000 test images: 1.676
# [48,   100] loss: 1.701 acc: 44.98 time: 6.18
# [48,   200] loss: 1.706 acc: 45.16 time: 6.34
# [48,   300] loss: 1.705 acc: 44.69 time: 6.17
# TESTING:
# Accuracy of the network on the 10000 test images: 45.62 %
# Average loss on the 10000 test images: 1.676
# [49,   100] loss: 1.702 acc: 44.40 time: 6.24
# [49,   200] loss: 1.690 acc: 45.31 time: 5.90
# [49,   300] loss: 1.702 acc: 45.37 time: 6.18
# TESTING:
# Accuracy of the network on the 10000 test images: 45.29 %
# Average loss on the 10000 test images: 1.679
# [50,   100] loss: 1.705 acc: 44.79 time: 6.00
# [50,   200] loss: 1.704 acc: 44.63 time: 6.17
# [50,   300] loss: 1.704 acc: 44.86 time: 5.96
# TESTING:
# Accuracy of the network on the 10000 test images: 45.57 %
# Average loss on the 10000 test images: 1.676
# Finished Training

# %% [markdown]
# ## Supervised training on the pre-trained model (9 points)
# In this section, we will load the ResNet18 model pre-trained on the rotation task and re-train the whole model on the classification task.
#
# **Then we will use the trained model from rotation task as the pretrained weights. Notice, you should not use the pretrained weights from ImageNet.**

# %%
import torch.nn as nn
import torch.nn.functional as F

from torchvision.models import resnet18

#####################################################
#     TODO: Load the pre-trained ResNet18 model     #  
#####################################################
# load the trained classifier weights
net = resnet18(weights=None, num_classes=4)
ckpt = torch.load(f"model_2023-11-02-23-22-09.pth")
net.load_state_dict(ckpt)

# Adjusting the fully connected layer for 10 classes
net.fc = nn.Linear(net.fc.in_features, 10)
net = net.to(device)
#####################################################
#                End of your code                   #   
#####################################################

# %%
# TODO: Define criterion and optimizer
criterion = nn.CrossEntropyLoss(label_smoothing=label_smoothing)

# Optimizer: Update only the parameters of layer4 and fc
optimizer = optim.Adam(lr=0.001, params=net.parameters())

criterion.to(device)
# Out:
# CrossEntropyLoss()

# %%
train(net, criterion, optimizer, num_epochs=50, decay_epochs=10, init_lr=0.01, task='classification', experiment_type='Supervised Pre-trained Model')
# Out:
# [1,   100] loss: 1.639 acc: 46.41 time: 22.32
# [1,   200] loss: 1.402 acc: 59.21 time: 6.74
# [1,   300] loss: 1.313 acc: 63.65 time: 6.88
# TESTING:
# Accuracy of the network on the 10000 test images: 67.95 %
# Average loss on the 10000 test images: 1.234
# [2,   100] loss: 1.219 acc: 68.01 time: 7.04
# [2,   200] loss: 1.186 acc: 69.30 time: 7.18
# [2,   300] loss: 1.159 acc: 70.71 time: 6.81
# TESTING:
# Accuracy of the network on the 10000 test images: 72.66 %
# Average loss on the 10000 test images: 1.128
# [3,   100] loss: 1.120 acc: 72.90 time: 7.15
# [3,   200] loss: 1.103 acc: 73.47 time: 6.60
# [3,   300] loss: 1.087 acc: 74.45 time: 6.96
# TESTING:
# Accuracy of the network on the 10000 test images: 72.97 %
# Average loss on the 10000 test images: 1.119
# [4,   100] loss: 1.057 acc: 75.28 time: 6.79
# [4,   200] loss: 1.041 acc: 76.12 time: 6.94
# [4,   300] loss: 1.054 acc: 75.82 time: 6.65
# TESTING:
# Accuracy of the network on the 10000 test images: 76.38 %
# Average loss on the 10000 test images: 1.030
# [5,   100] loss: 1.004 acc: 77.80 time: 7.32
# [5,   200] loss: 1.010 acc: 77.41 time: 7.00
# [5,   300] loss: 1.015 acc: 77.48 time: 7.64
# TESTING:
# Accuracy of the network on the 10000 test images: 77.85 %
# Average loss on the 10000 test images: 1.011
# [6,   100] loss: 0.974 acc: 79.04 time: 7.34
# [6,   200] loss: 0.988 acc: 78.39 time: 7.13
# [6,   300] loss: 0.987 acc: 78.41 time: 6.91
# TESTING:
# Accuracy of the network on the 10000 test images: 77.65 %
# Average loss on the 10000 test images: 1.010
# [7,   100] loss: 0.959 acc: 80.05 time: 6.98
# [7,   200] loss: 0.970 acc: 79.59 time: 7.00
# [7,   300] loss: 0.957 acc: 79.87 time: 7.68
# TESTING:
# Accuracy of the network on the 10000 test images: 78.92 %
# Average loss on the 10000 test images: 0.986
# [8,   100] loss: 0.938 acc: 80.65 time: 7.53
# [8,   200] loss: 0.937 acc: 80.79 time: 7.25
# [8,   300] loss: 0.937 acc: 80.88 time: 7.41
# TESTING:
# Accuracy of the network on the 10000 test images: 79.91 %
# Average loss on the 10000 test images: 0.954
# [9,   100] loss: 0.914 acc: 81.80 time: 7.27
# [9,   200] loss: 0.914 acc: 81.54 time: 7.25
# [9,   300] loss: 0.917 acc: 81.58 time: 7.80
# TESTING:
# Accuracy of the network on the 10000 test images: 80.82 %
# Average loss on the 10000 test images: 0.943
# [10,   100] loss: 0.899 acc: 82.33 time: 7.12
# [10,   200] loss: 0.900 acc: 82.13 time: 7.47
# [10,   300] loss: 0.911 acc: 82.13 time: 7.38
# TESTING:
# Accuracy of the network on the 10000 test images: 81.42 %
# Average loss on the 10000 test images: 0.932
# [11,   100] loss: 0.839 acc: 85.07 time: 7.05
# [11,   200] loss: 0.830 acc: 85.68 time: 7.37
# [11,   300] loss: 0.824 acc: 85.94 time: 7.96
# TESTING:
# Accuracy of the network on the 10000 test images: 83.45 %
# Average loss on the 10000 test images: 0.878
# [12,   100] loss: 0.818 acc: 85.87 time: 7.73
# [12,   200] loss: 0.796 acc: 87.07 time: 7.19
# [12,   300] loss: 0.805 acc: 86.53 time: 7.84
# TESTING:
# Accuracy of the network on the 10000 test images: 83.87 %
# Average loss on the 10000 test images: 0.870
# [13,   100] loss: 0.792 acc: 86.93 time: 25.27
# [13,   200] loss: 0.806 acc: 86.48 time: 7.85
# [13,   300] loss: 0.797 acc: 87.09 time: 7.78
# TESTING:
# Accuracy of the network on the 10000 test images: 84.07 %
# Average loss on the 10000 test images: 0.869
# [14,   100] loss: 0.793 acc: 86.89 time: 7.24
# [14,   200] loss: 0.798 acc: 86.91 time: 7.17
# [14,   300] loss: 0.786 acc: 87.27 time: 7.42
# TESTING:
# Accuracy of the network on the 10000 test images: 83.97 %
# Average loss on the 10000 test images: 0.869
# [15,   100] loss: 0.781 acc: 87.66 time: 7.61
# [15,   200] loss: 0.782 acc: 87.64 time: 8.42
# [15,   300] loss: 0.789 acc: 87.48 time: 10.58
# TESTING:
# Accuracy of the network on the 10000 test images: 83.90 %
# Average loss on the 10000 test images: 0.871
# [16,   100] loss: 0.780 acc: 87.55 time: 7.23
# [16,   200] loss: 0.777 acc: 87.67 time: 6.85
# [16,   300] loss: 0.787 acc: 87.38 time: 7.80
# TESTING:
# Accuracy of the network on the 10000 test images: 84.02 %
# Average loss on the 10000 test images: 0.870
# [17,   100] loss: 0.772 acc: 88.20 time: 7.39
# [17,   200] loss: 0.774 acc: 88.07 time: 7.23
# [17,   300] loss: 0.774 acc: 87.88 time: 7.70
# TESTING:
# Accuracy of the network on the 10000 test images: 84.44 %
# Average loss on the 10000 test images: 0.867
# [18,   100] loss: 0.761 acc: 88.54 time: 7.42
# [18,   200] loss: 0.776 acc: 87.69 time: 7.14
# [18,   300] loss: 0.770 acc: 88.10 time: 7.11
# TESTING:
# Accuracy of the network on the 10000 test images: 84.36 %
# Average loss on the 10000 test images: 0.866
# [19,   100] loss: 0.762 acc: 88.52 time: 7.31
# [19,   200] loss: 0.760 acc: 88.67 time: 7.85
# [19,   300] loss: 0.771 acc: 88.13 time: 7.06
# TESTING:
# Accuracy of the network on the 10000 test images: 84.55 %
# Average loss on the 10000 test images: 0.865
# [20,   100] loss: 0.757 acc: 88.85 time: 7.29
# [20,   200] loss: 0.762 acc: 88.62 time: 8.05
# [20,   300] loss: 0.768 acc: 88.08 time: 7.37
# TESTING:
# Accuracy of the network on the 10000 test images: 84.29 %
# Average loss on the 10000 test images: 0.864
# [21,   100] loss: 0.741 acc: 89.73 time: 7.17
# [21,   200] loss: 0.757 acc: 88.63 time: 8.25
# [21,   300] loss: 0.753 acc: 88.86 time: 7.54
# TESTING:
# Accuracy of the network on the 10000 test images: 84.42 %
# Average loss on the 10000 test images: 0.862
# [22,   100] loss: 0.752 acc: 88.98 time: 7.57
# [22,   200] loss: 0.766 acc: 88.51 time: 7.44
# [22,   300] loss: 0.753 acc: 88.65 time: 7.47
# TESTING:
# Accuracy of the network on the 10000 test images: 84.59 %
# Average loss on the 10000 test images: 0.861
# [23,   100] loss: 0.754 acc: 88.77 time: 7.79
# [23,   200] loss: 0.754 acc: 88.70 time: 7.59
# [23,   300] loss: 0.756 acc: 88.99 time: 6.89
# TESTING:
# Accuracy of the network on the 10000 test images: 84.55 %
# Average loss on the 10000 test images: 0.862
# [24,   100] loss: 0.751 acc: 88.69 time: 7.46
# [24,   200] loss: 0.749 acc: 89.18 time: 7.72
# [24,   300] loss: 0.750 acc: 89.27 time: 7.97
# TESTING:
# Accuracy of the network on the 10000 test images: 84.76 %
# Average loss on the 10000 test images: 0.862
# [25,   100] loss: 0.748 acc: 89.27 time: 7.27
# [25,   200] loss: 0.742 acc: 89.51 time: 7.42
# [25,   300] loss: 0.745 acc: 89.39 time: 8.06
# TESTING:
# Accuracy of the network on the 10000 test images: 84.71 %
# Average loss on the 10000 test images: 0.860
# [26,   100] loss: 0.748 acc: 89.35 time: 7.61
# [26,   200] loss: 0.745 acc: 89.38 time: 7.16
# [26,   300] loss: 0.747 acc: 89.20 time: 7.59
# TESTING:
# Accuracy of the network on the 10000 test images: 84.55 %
# Average loss on the 10000 test images: 0.862
# [27,   100] loss: 0.746 acc: 88.95 time: 7.98
# [27,   200] loss: 0.747 acc: 89.30 time: 7.09
# [27,   300] loss: 0.752 acc: 89.05 time: 7.33
# TESTING:
# Accuracy of the network on the 10000 test images: 84.60 %
# Average loss on the 10000 test images: 0.862
# [28,   100] loss: 0.747 acc: 89.09 time: 7.53
# [28,   200] loss: 0.739 acc: 89.34 time: 7.52
# [28,   300] loss: 0.742 acc: 89.20 time: 7.83
# TESTING:
# Accuracy of the network on the 10000 test images: 84.68 %
# Average loss on the 10000 test images: 0.862
# [29,   100] loss: 0.742 acc: 89.54 time: 7.20
# [29,   200] loss: 0.745 acc: 89.45 time: 7.03
# [29,   300] loss: 0.745 acc: 89.36 time: 7.59
# TESTING:
# Accuracy of the network on the 10000 test images: 84.72 %
# Average loss on the 10000 test images: 0.861
# [30,   100] loss: 0.745 acc: 89.17 time: 7.71
# [30,   200] loss: 0.748 acc: 88.89 time: 7.36
# [30,   300] loss: 0.745 acc: 89.09 time: 7.27
# TESTING:
# Accuracy of the network on the 10000 test images: 84.63 %
# Average loss on the 10000 test images: 0.860
# [31,   100] loss: 0.738 acc: 89.54 time: 12.74
# [31,   200] loss: 0.750 acc: 89.00 time: 7.92
# [31,   300] loss: 0.747 acc: 89.19 time: 7.33
# TESTING:
# Accuracy of the network on the 10000 test images: 84.82 %
# Average loss on the 10000 test images: 0.861
# [32,   100] loss: 0.746 acc: 89.21 time: 7.24
# [32,   200] loss: 0.746 acc: 89.38 time: 7.34
# [32,   300] loss: 0.753 acc: 89.06 time: 7.10
# TESTING:
# Accuracy of the network on the 10000 test images: 84.79 %
# Average loss on the 10000 test images: 0.859
# [33,   100] loss: 0.753 acc: 88.84 time: 7.99
# [33,   200] loss: 0.744 acc: 88.88 time: 6.99
# [33,   300] loss: 0.740 acc: 89.17 time: 6.83
# TESTING:
# Accuracy of the network on the 10000 test images: 84.75 %
# Average loss on the 10000 test images: 0.860
# [34,   100] loss: 0.746 acc: 89.18 time: 7.53
# [34,   200] loss: 0.751 acc: 88.95 time: 7.68
# [34,   300] loss: 0.748 acc: 88.95 time: 7.79
# TESTING:
# Accuracy of the network on the 10000 test images: 84.84 %
# Average loss on the 10000 test images: 0.860
# [35,   100] loss: 0.745 acc: 89.31 time: 7.20
# [35,   200] loss: 0.748 acc: 88.90 time: 7.06
# [35,   300] loss: 0.747 acc: 89.16 time: 7.41
# TESTING:
# Accuracy of the network on the 10000 test images: 84.78 %
# Average loss on the 10000 test images: 0.860
# [36,   100] loss: 0.738 acc: 89.34 time: 7.62
# [36,   200] loss: 0.747 acc: 89.12 time: 6.91
# [36,   300] loss: 0.752 acc: 88.81 time: 6.96
# TESTING:
# Accuracy of the network on the 10000 test images: 84.81 %
# Average loss on the 10000 test images: 0.860
# [37,   100] loss: 0.741 acc: 89.50 time: 7.31
# [37,   200] loss: 0.748 acc: 89.14 time: 7.46
# [37,   300] loss: 0.738 acc: 89.84 time: 7.66
# TESTING:
# Accuracy of the network on the 10000 test images: 84.72 %
# Average loss on the 10000 test images: 0.861
# [38,   100] loss: 0.749 acc: 89.05 time: 7.70
# [38,   200] loss: 0.745 acc: 89.23 time: 7.03
# [38,   300] loss: 0.738 acc: 89.71 time: 8.54
# TESTING:
# Accuracy of the network on the 10000 test images: 84.63 %
# Average loss on the 10000 test images: 0.860
# [39,   100] loss: 0.752 acc: 88.84 time: 7.34
# [39,   200] loss: 0.742 acc: 89.57 time: 7.27
# [39,   300] loss: 0.748 acc: 89.15 time: 7.40
# TESTING:
# Accuracy of the network on the 10000 test images: 84.64 %
# Average loss on the 10000 test images: 0.860
# [40,   100] loss: 0.742 acc: 89.51 time: 7.53
# [40,   200] loss: 0.752 acc: 88.84 time: 7.66
# [40,   300] loss: 0.743 acc: 89.41 time: 7.63
# TESTING:
# Accuracy of the network on the 10000 test images: 84.63 %
# Average loss on the 10000 test images: 0.861
# [41,   100] loss: 0.751 acc: 88.90 time: 7.46
# [41,   200] loss: 0.740 acc: 89.54 time: 7.56
# [41,   300] loss: 0.750 acc: 89.05 time: 7.69
# TESTING:
# Accuracy of the network on the 10000 test images: 84.72 %
# Average loss on the 10000 test images: 0.861
# [42,   100] loss: 0.742 acc: 89.38 time: 7.57
# [42,   200] loss: 0.743 acc: 89.23 time: 7.33
# [42,   300] loss: 0.745 acc: 89.26 time: 7.48
# TESTING:
# Accuracy of the network on the 10000 test images: 84.82 %
# Average loss on the 10000 test images: 0.861
# [43,   100] loss: 0.743 acc: 89.21 time: 7.53
# [43,   200] loss: 0.744 acc: 89.28 time: 7.36
# [43,   300] loss: 0.744 acc: 89.43 time: 7.96
# TESTING:
# Accuracy of the network on the 10000 test images: 84.66 %
# Average loss on the 10000 test images: 0.862
# [44,   100] loss: 0.739 acc: 89.30 time: 7.83
# [44,   200] loss: 0.745 acc: 88.97 time: 7.35
# [44,   300] loss: 0.743 acc: 89.30 time: 7.42
# TESTING:
# Accuracy of the network on the 10000 test images: 84.73 %
# Average loss on the 10000 test images: 0.863
# [45,   100] loss: 0.742 acc: 89.39 time: 7.09
# [45,   200] loss: 0.742 acc: 89.52 time: 6.94
# [45,   300] loss: 0.743 acc: 89.66 time: 7.22
# TESTING:
# Accuracy of the network on the 10000 test images: 84.85 %
# Average loss on the 10000 test images: 0.860
# [46,   100] loss: 0.758 acc: 88.51 time: 7.15
# [46,   200] loss: 0.745 acc: 89.38 time: 7.85
# [46,   300] loss: 0.742 acc: 89.10 time: 8.40
# TESTING:
# Accuracy of the network on the 10000 test images: 84.83 %
# Average loss on the 10000 test images: 0.859
# [47,   100] loss: 0.736 acc: 89.66 time: 7.40
# [47,   200] loss: 0.754 acc: 88.77 time: 7.61
# [47,   300] loss: 0.742 acc: 89.47 time: 7.43
# TESTING:
# Accuracy of the network on the 10000 test images: 84.69 %
# Average loss on the 10000 test images: 0.860
# [48,   100] loss: 0.745 acc: 89.26 time: 7.08
# [48,   200] loss: 0.748 acc: 89.05 time: 7.10
# [48,   300] loss: 0.748 acc: 89.02 time: 7.11
# TESTING:
# Accuracy of the network on the 10000 test images: 84.82 %
# Average loss on the 10000 test images: 0.860
# [49,   100] loss: 0.749 acc: 89.08 time: 7.02
# [49,   200] loss: 0.744 acc: 89.47 time: 7.22
# [49,   300] loss: 0.744 acc: 89.21 time: 7.85
# TESTING:
# Accuracy of the network on the 10000 test images: 84.66 %
# Average loss on the 10000 test images: 0.861
# [50,   100] loss: 0.747 acc: 89.12 time: 7.51
# [50,   200] loss: 0.744 acc: 89.38 time: 7.07
# [50,   300] loss: 0.746 acc: 89.45 time: 6.79
# TESTING:
# Accuracy of the network on the 10000 test images: 84.83 %
# Average loss on the 10000 test images: 0.861
# Finished Training

# %% [markdown]
# ## Supervised training on the randomly initialized model (9 points)
# In this section, we will randomly initialize a ResNet18 model and re-train the whole model on the classification task.

# %%
import torch.nn as nn
import torch.nn.functional as F

from torchvision.models import resnet18

#################################################
# TODO: Randomly initialize a ResNet18 model    #
#################################################
net = resnet18(weights=None, num_classes=10)
net = net.to(device)
#################################################
#              End of your code                 #
#################################################

# %%
# TODO: Define criterion and optimizer
criterion = nn.CrossEntropyLoss(label_smoothing=label_smoothing)

# Optimizer: Update only the parameters of layer4 and fc
optimizer = optim.Adam(lr=0.001, params=net.parameters())

criterion.to(device)
# Out:
# CrossEntropyLoss()

# %%
train(net, criterion, optimizer, num_epochs=50, decay_epochs=10, init_lr=0.01, task='classification', experiment_type='Supervised Randomly Initialized Model')
# Out:
# [1,   100] loss: 2.359 acc: 21.73 time: 7.04
# [1,   200] loss: 1.955 acc: 32.69 time: 7.26
# [1,   300] loss: 1.834 acc: 37.48 time: 6.97
# TESTING:
# Accuracy of the network on the 10000 test images: 45.25 %
# Average loss on the 10000 test images: 1.730
# [2,   100] loss: 1.696 acc: 44.05 time: 7.34
# [2,   200] loss: 1.624 acc: 47.59 time: 7.07
# [2,   300] loss: 1.564 acc: 51.22 time: 7.74
# TESTING:
# Accuracy of the network on the 10000 test images: 54.13 %
# Average loss on the 10000 test images: 1.506
# [3,   100] loss: 1.468 acc: 55.70 time: 7.06
# [3,   200] loss: 1.432 acc: 57.66 time: 6.89
# [3,   300] loss: 1.396 acc: 59.05 time: 7.67
# TESTING:
# Accuracy of the network on the 10000 test images: 61.22 %
# Average loss on the 10000 test images: 1.354
# [4,   100] loss: 1.338 acc: 61.88 time: 7.00
# [4,   200] loss: 1.313 acc: 63.09 time: 6.80
# [4,   300] loss: 1.290 acc: 64.20 time: 6.77
# TESTING:
# Accuracy of the network on the 10000 test images: 65.33 %
# Average loss on the 10000 test images: 1.308
# [5,   100] loss: 1.249 acc: 66.30 time: 7.40
# [5,   200] loss: 1.228 acc: 67.30 time: 7.16
# [5,   300] loss: 1.221 acc: 67.60 time: 7.03
# TESTING:
# Accuracy of the network on the 10000 test images: 67.08 %
# Average loss on the 10000 test images: 1.248
# [6,   100] loss: 1.191 acc: 69.34 time: 7.44
# [6,   200] loss: 1.183 acc: 69.10 time: 7.08
# [6,   300] loss: 1.164 acc: 70.33 time: 6.76
# TESTING:
# Accuracy of the network on the 10000 test images: 70.73 %
# Average loss on the 10000 test images: 1.159
# [7,   100] loss: 1.130 acc: 71.91 time: 6.99
# [7,   200] loss: 1.127 acc: 72.54 time: 6.88
# [7,   300] loss: 1.123 acc: 72.62 time: 7.53
# TESTING:
# Accuracy of the network on the 10000 test images: 73.26 %
# Average loss on the 10000 test images: 1.107
# [8,   100] loss: 1.103 acc: 73.51 time: 7.12
# [8,   200] loss: 1.090 acc: 73.98 time: 6.74
# [8,   300] loss: 1.086 acc: 74.12 time: 7.05
# TESTING:
# Accuracy of the network on the 10000 test images: 72.38 %
# Average loss on the 10000 test images: 1.135
# [9,   100] loss: 1.068 acc: 74.59 time: 7.51
# [9,   200] loss: 1.066 acc: 74.76 time: 7.19
# [9,   300] loss: 1.061 acc: 75.61 time: 7.76
# TESTING:
# Accuracy of the network on the 10000 test images: 75.33 %
# Average loss on the 10000 test images: 1.067
# [10,   100] loss: 1.027 acc: 77.20 time: 7.20
# [10,   200] loss: 1.032 acc: 76.40 time: 7.27
# [10,   300] loss: 1.050 acc: 75.73 time: 6.94
# TESTING:
# Accuracy of the network on the 10000 test images: 77.17 %
# Average loss on the 10000 test images: 1.024
# [11,   100] loss: 0.948 acc: 80.39 time: 6.98
# [11,   200] loss: 0.940 acc: 80.50 time: 7.30
# [11,   300] loss: 0.924 acc: 81.09 time: 7.09
# TESTING:
# Accuracy of the network on the 10000 test images: 80.89 %
# Average loss on the 10000 test images: 0.935
# [12,   100] loss: 0.918 acc: 81.62 time: 7.08
# [12,   200] loss: 0.901 acc: 82.16 time: 7.18
# [12,   300] loss: 0.899 acc: 82.51 time: 7.16
# TESTING:
# Accuracy of the network on the 10000 test images: 80.79 %
# Average loss on the 10000 test images: 0.931
# [13,   100] loss: 0.891 acc: 82.64 time: 6.96
# [13,   200] loss: 0.891 acc: 82.48 time: 7.28
# [13,   300] loss: 0.887 acc: 82.98 time: 8.01
# TESTING:
# Accuracy of the network on the 10000 test images: 81.30 %
# Average loss on the 10000 test images: 0.927
# [14,   100] loss: 0.875 acc: 83.12 time: 7.21
# [14,   200] loss: 0.881 acc: 83.03 time: 6.90
# [14,   300] loss: 0.887 acc: 82.75 time: 7.14
# TESTING:
# Accuracy of the network on the 10000 test images: 81.37 %
# Average loss on the 10000 test images: 0.921
# [15,   100] loss: 0.874 acc: 83.50 time: 6.87
# [15,   200] loss: 0.864 acc: 83.79 time: 6.88
# [15,   300] loss: 0.871 acc: 83.60 time: 7.39
# TESTING:
# Accuracy of the network on the 10000 test images: 81.77 %
# Average loss on the 10000 test images: 0.915
# [16,   100] loss: 0.855 acc: 84.16 time: 7.75
# [16,   200] loss: 0.855 acc: 84.38 time: 7.56
# [16,   300] loss: 0.870 acc: 83.43 time: 6.74
# TESTING:
# Accuracy of the network on the 10000 test images: 81.92 %
# Average loss on the 10000 test images: 0.915
# [17,   100] loss: 0.854 acc: 84.20 time: 7.35
# [17,   200] loss: 0.849 acc: 84.62 time: 7.36
# [17,   300] loss: 0.844 acc: 84.54 time: 7.56
# TESTING:
# Accuracy of the network on the 10000 test images: 82.09 %
# Average loss on the 10000 test images: 0.910
# [18,   100] loss: 0.839 acc: 85.30 time: 6.84
# [18,   200] loss: 0.845 acc: 84.60 time: 6.88
# [18,   300] loss: 0.852 acc: 84.52 time: 6.90
# TESTING:
# Accuracy of the network on the 10000 test images: 81.85 %
# Average loss on the 10000 test images: 0.909
# [19,   100] loss: 0.840 acc: 85.11 time: 7.47
# [19,   200] loss: 0.828 acc: 85.52 time: 7.15
# [19,   300] loss: 0.836 acc: 85.21 time: 6.94
# TESTING:
# Accuracy of the network on the 10000 test images: 81.91 %
# Average loss on the 10000 test images: 0.908
# [20,   100] loss: 0.834 acc: 85.05 time: 6.95
# [20,   200] loss: 0.832 acc: 85.38 time: 7.64
# [20,   300] loss: 0.835 acc: 85.47 time: 6.84
# TESTING:
# Accuracy of the network on the 10000 test images: 82.28 %
# Average loss on the 10000 test images: 0.903
# [21,   100] loss: 0.819 acc: 85.75 time: 7.32
# [21,   200] loss: 0.822 acc: 85.80 time: 6.93
# [21,   300] loss: 0.813 acc: 86.18 time: 7.97
# TESTING:
# Accuracy of the network on the 10000 test images: 82.73 %
# Average loss on the 10000 test images: 0.896
# [22,   100] loss: 0.810 acc: 86.37 time: 7.43
# [22,   200] loss: 0.806 acc: 86.51 time: 7.26
# [22,   300] loss: 0.811 acc: 86.25 time: 6.90
# TESTING:
# Accuracy of the network on the 10000 test images: 82.81 %
# Average loss on the 10000 test images: 0.897
# [23,   100] loss: 0.811 acc: 86.27 time: 7.45
# [23,   200] loss: 0.808 acc: 86.44 time: 7.20
# [23,   300] loss: 0.817 acc: 86.02 time: 7.61
# TESTING:
# Accuracy of the network on the 10000 test images: 82.85 %
# Average loss on the 10000 test images: 0.896
# [24,   100] loss: 0.808 acc: 86.47 time: 7.05
# [24,   200] loss: 0.803 acc: 86.35 time: 8.37
# [24,   300] loss: 0.804 acc: 86.16 time: 7.11
# TESTING:
# Accuracy of the network on the 10000 test images: 82.40 %
# Average loss on the 10000 test images: 0.908
# [25,   100] loss: 0.807 acc: 86.57 time: 7.52
# [25,   200] loss: 0.804 acc: 86.77 time: 6.89
# [25,   300] loss: 0.804 acc: 86.50 time: 6.69
# TESTING:
# Accuracy of the network on the 10000 test images: 82.47 %
# Average loss on the 10000 test images: 0.902
# [26,   100] loss: 0.805 acc: 86.21 time: 7.36
# [26,   200] loss: 0.802 acc: 86.42 time: 7.04
# [26,   300] loss: 0.809 acc: 86.39 time: 7.50
# TESTING:
# Accuracy of the network on the 10000 test images: 82.53 %
# Average loss on the 10000 test images: 0.903
# [27,   100] loss: 0.803 acc: 86.70 time: 6.89
# [27,   200] loss: 0.796 acc: 86.99 time: 6.86
# [27,   300] loss: 0.810 acc: 86.22 time: 7.75
# TESTING:
# Accuracy of the network on the 10000 test images: 82.57 %
# Average loss on the 10000 test images: 0.900
# [28,   100] loss: 0.809 acc: 86.08 time: 7.31
# [28,   200] loss: 0.801 acc: 86.58 time: 7.02
# [28,   300] loss: 0.796 acc: 86.76 time: 7.24
# TESTING:
# Accuracy of the network on the 10000 test images: 82.83 %
# Average loss on the 10000 test images: 0.901
# [29,   100] loss: 0.797 acc: 87.03 time: 7.17
# [29,   200] loss: 0.799 acc: 86.52 time: 7.18
# [29,   300] loss: 0.801 acc: 86.71 time: 6.75
# TESTING:
# Accuracy of the network on the 10000 test images: 82.80 %
# Average loss on the 10000 test images: 0.897
# [30,   100] loss: 0.801 acc: 86.88 time: 7.61
# [30,   200] loss: 0.796 acc: 87.02 time: 7.06
# [30,   300] loss: 0.804 acc: 86.18 time: 7.47
# TESTING:
# Accuracy of the network on the 10000 test images: 82.55 %
# Average loss on the 10000 test images: 0.903
# [31,   100] loss: 0.798 acc: 86.98 time: 6.99
# [31,   200] loss: 0.795 acc: 86.92 time: 6.71
# [31,   300] loss: 0.799 acc: 86.98 time: 7.07
# TESTING:
# Accuracy of the network on the 10000 test images: 82.64 %
# Average loss on the 10000 test images: 0.900
# [32,   100] loss: 0.795 acc: 86.77 time: 7.00
# [32,   200] loss: 0.789 acc: 87.05 time: 7.20
# [32,   300] loss: 0.797 acc: 86.94 time: 7.14
# TESTING:
# Accuracy of the network on the 10000 test images: 82.49 %
# Average loss on the 10000 test images: 0.902
# [33,   100] loss: 0.798 acc: 86.53 time: 7.17
# [33,   200] loss: 0.794 acc: 86.80 time: 6.74
# [33,   300] loss: 0.796 acc: 86.95 time: 7.16
# TESTING:
# Accuracy of the network on the 10000 test images: 82.76 %
# Average loss on the 10000 test images: 0.898
# [34,   100] loss: 0.786 acc: 87.19 time: 7.01
# [34,   200] loss: 0.806 acc: 86.55 time: 7.13
# [34,   300] loss: 0.792 acc: 87.38 time: 7.35
# TESTING:
# Accuracy of the network on the 10000 test images: 82.73 %
# Average loss on the 10000 test images: 0.895
# [35,   100] loss: 0.784 acc: 87.27 time: 6.93
# [35,   200] loss: 0.799 acc: 86.88 time: 7.21
# [35,   300] loss: 0.799 acc: 86.78 time: 7.49
# TESTING:
# Accuracy of the network on the 10000 test images: 82.38 %
# Average loss on the 10000 test images: 0.911
# [36,   100] loss: 0.795 acc: 86.64 time: 6.93
# [36,   200] loss: 0.796 acc: 86.73 time: 7.12
# [36,   300] loss: 0.796 acc: 86.90 time: 7.69
# TESTING:
# Accuracy of the network on the 10000 test images: 82.79 %
# Average loss on the 10000 test images: 0.898
# [37,   100] loss: 0.799 acc: 86.62 time: 7.01
# [37,   200] loss: 0.799 acc: 86.79 time: 7.04
# [37,   300] loss: 0.800 acc: 86.45 time: 6.98
# TESTING:
# Accuracy of the network on the 10000 test images: 82.57 %
# Average loss on the 10000 test images: 0.902
# [38,   100] loss: 0.790 acc: 86.94 time: 7.71
# [38,   200] loss: 0.803 acc: 86.77 time: 6.92
# [38,   300] loss: 0.790 acc: 87.02 time: 7.10
# TESTING:
# Accuracy of the network on the 10000 test images: 82.63 %
# Average loss on the 10000 test images: 0.904
# [39,   100] loss: 0.801 acc: 86.62 time: 7.13
# [39,   200] loss: 0.796 acc: 86.83 time: 6.96
# [39,   300] loss: 0.794 acc: 86.86 time: 6.74
# TESTING:
# Accuracy of the network on the 10000 test images: 82.20 %
# Average loss on the 10000 test images: 0.918
# [40,   100] loss: 0.793 acc: 87.12 time: 7.14
# [40,   200] loss: 0.798 acc: 87.08 time: 6.76
# [40,   300] loss: 0.794 acc: 86.96 time: 7.12
# TESTING:
# Accuracy of the network on the 10000 test images: 82.73 %
# Average loss on the 10000 test images: 0.898
# [41,   100] loss: 0.791 acc: 87.40 time: 7.20
# [41,   200] loss: 0.801 acc: 86.61 time: 7.47
# [41,   300] loss: 0.797 acc: 86.86 time: 7.08
# TESTING:
# Accuracy of the network on the 10000 test images: 82.80 %
# Average loss on the 10000 test images: 0.897
# [42,   100] loss: 0.795 acc: 87.06 time: 7.08
# [42,   200] loss: 0.792 acc: 87.11 time: 8.07
# [42,   300] loss: 0.804 acc: 86.30 time: 7.90
# TESTING:
# Accuracy of the network on the 10000 test images: 82.87 %
# Average loss on the 10000 test images: 0.895
# [43,   100] loss: 0.799 acc: 86.87 time: 7.05
# [43,   200] loss: 0.792 acc: 86.84 time: 7.53
# [43,   300] loss: 0.794 acc: 86.91 time: 6.61
# TESTING:
# Accuracy of the network on the 10000 test images: 82.64 %
# Average loss on the 10000 test images: 0.900
# [44,   100] loss: 0.794 acc: 87.03 time: 7.01
# [44,   200] loss: 0.795 acc: 87.09 time: 7.05
# [44,   300] loss: 0.795 acc: 86.91 time: 8.04
# TESTING:
# Accuracy of the network on the 10000 test images: 82.74 %
# Average loss on the 10000 test images: 0.899
# [45,   100] loss: 0.793 acc: 87.01 time: 7.12
# [45,   200] loss: 0.793 acc: 87.13 time: 6.94
# [45,   300] loss: 0.792 acc: 87.06 time: 7.09
# TESTING:
# Accuracy of the network on the 10000 test images: 82.67 %
# Average loss on the 10000 test images: 0.903
# [46,   100] loss: 0.793 acc: 86.95 time: 7.17
# [46,   200] loss: 0.795 acc: 86.78 time: 7.41
# [46,   300] loss: 0.800 acc: 86.76 time: 7.57
# TESTING:
# Accuracy of the network on the 10000 test images: 82.50 %
# Average loss on the 10000 test images: 0.899
# [47,   100] loss: 0.802 acc: 86.41 time: 7.00
# [47,   200] loss: 0.793 acc: 87.02 time: 7.64
# [47,   300] loss: 0.784 acc: 87.41 time: 6.95
# TESTING:
# Accuracy of the network on the 10000 test images: 82.89 %
# Average loss on the 10000 test images: 0.896
# [48,   100] loss: 0.789 acc: 87.23 time: 7.10
# [48,   200] loss: 0.792 acc: 87.17 time: 8.27
# [48,   300] loss: 0.799 acc: 86.84 time: 7.06
# TESTING:
# Accuracy of the network on the 10000 test images: 82.63 %
# Average loss on the 10000 test images: 0.901
# [49,   100] loss: 0.798 acc: 86.94 time: 7.13
# [49,   200] loss: 0.792 acc: 87.18 time: 6.77
# [49,   300] loss: 0.789 acc: 87.09 time: 7.12
# TESTING:
# Accuracy of the network on the 10000 test images: 82.84 %
# Average loss on the 10000 test images: 0.895
# [50,   100] loss: 0.798 acc: 86.77 time: 10.20
# [50,   200] loss: 0.796 acc: 86.82 time: 12.97
# [50,   300] loss: 0.794 acc: 87.02 time: 11.49
# TESTING:
# Accuracy of the network on the 10000 test images: 82.66 %
# Average loss on the 10000 test images: 0.899
# Finished Training

# %% [markdown]
# # Write report (37 points)
#
# 本次作業主要有3個tasks需要大家完成，在A4.pdf中有希望大家達成的baseline **(不能低於baseline最多2%，沒有達到不會給全部分數)**，report的撰寫就希望大家可以透過去調整不同的訓練方法、損失函數、優化器，或者是調整凍結不同的層來進行這次的實驗，就請大家將嘗試的結果寫在report裡，祝大家順利！
#
# - Rotation task (13 points)
# - Fine-tuning the specified layers of the pre-trained model (12 points)
# - Fine-tuning the whole pre-trained model (12 points)

# %% [markdown]
# # Extra Credit (13 points)
#
# 上面基本的code跟report最高可以拿到87分，這個加分部分並沒有要求同學們一定要做，若同學們想要獲得更高的分數可以根據以下的加分要求來獲得加分。
#
# - In Figure 5(b) from the Gidaris et al. paper, the authors show a plot of CIFAR10 classification performance vs. number of training examples per category for a supervised CIFAR10 model vs. a RotNet model with the final layers fine-tuned on CIFAR10. The plot shows that pre-training on the Rotation task can be advantageous when only a small amount of labeled data is available. Using your RotNet fine-tuning code and supervised CIFAR10 training code from the main assignment, try to create a similar plot by performing supervised fine-tuning/training on only a subset of CIFAR10.
# - Use a more advanced model than ResNet18 to try to get higher accuracy on the rotation prediction task, as well as for transfer to supervised CIFAR10 classification.
#
# - If you have a good amount of compute at your disposal, try to train a rotation prediction model on the larger ImageNette dataset (still smaller than ImageNet, though).
